# %% [markdown]
# # Analysing the redundancies of User Stories - Annotations and US Text

# %%
import locale
import os, json
from itertools import combinations

import pandas as pd
import tiktoken
from openpyxl import Workbook
from openpyxl.styles import Alignment, Font
from openpyxl.utils import get_column_letter as utils_get_column_letter

from prompt_structure.helper_prompt_composition import PromptHelperBuilder
from prompt_structure.prompt_builder import PromptBuilder
from support_functions.excel_helper import save_to_excel, formatter_ignored_items
from support_functions.load_data import load_datasets_with_annotations as loading
from support_functions.request_handler import process_user_stories, process_user_stories_parallel
from support_functions.data_transformations import convert_annotation_dataset
from support_functions.time_recorder import TimeRecorder
from support_functions.json_validator import validation, chat_gpt_schema_with_annotations

# %%
locale.setlocale(locale.LC_ALL, 'de_DE') 
MODEL_VERSION_NAME = os.getenv('MODEL_VERSION')
THREADING = bool(int(os.getenv('THREADING')))
print(f"Threading is used: {THREADING}")
print(f"Model Version: {MODEL_VERSION_NAME}")
print(f"Threads: {os.getenv("THREAD_MULTIPLICATOR")}")
print(f"Limit: {os.getenv("LIMIT")}")
# Out:
# Threading is used: True
# Model Version: gpt-3.5-turbo
# Threads: 1
# Limit: -1

# %%
time_recorders: dict = {}
time_recorder: TimeRecorder = None

# %% [markdown]
# ### Load all User Stories from the different packages
#
# We use here Text and it split and the annotations (formatted):
# - Text
# - Main Part
# - Benefit
# - Triggers
# - Targets
# - Contains
#
# We do not need:
# - POS
#
# Irgnored Files as they differer from the common structure [Ref](https://github.com/ace-design/nlp-stories/tree/main?tab=readme-ov-file#note):
# - g02-federal-funding
# - g13-planningpoker
# - g17-cask
# - g27-culrepo
#
# Ignored Files as they were used as trainings data
# - g05
# - g12
#
# Data sets to analyse:
# - 'g03', 'g04', 'g08', 'g10', 'g11', 'g14', 'g16', 'g18', 'g19', 'g21', 'g22', 'g23', 'g24', 'g25', 'g26', 'g28'
#
# Used Data:
# - "nlp" --> "nlp_outputs" --> "individual_backlog" --> "nlp_outputs_original" --> "pos_baseline"
#
# Highlighting words with #

# %%
not_processed_datasets: dict[str, list] = loading()
print(not_processed_datasets["g02"][0])
# Out:
# {'PID': '#G02#', 'Text': '#G02# As a Data user, I want to have the 12-19-2017 deletions processed.', 'Persona': ['Data user'], 'Action': {'Primary Action': ['have'], 'Secondary Action': ['processed']}, 'Entity': {'Primary Entity': ['12-19-2017 deletions'], 'Secondary Entity': ['']}, 'Benefit': '', 'Triggers': [['Data user', 'have']], 'Targets': [['processed', '12-19-2017 deletions'], ['have', '12-19-2017 deletions']], 'Contains': [], 'Persona POS': {'Persona POS tag': [['NOUN', 'NOUN']], 'Persona POS text': [['Data', 'user']]}, 'Action POS': {'Primary Action POS': {'Primary Action POS tag': [['VERB']], 'Primary Action POS text': [['have']]}, 'Secondary Action POS': {'Secondary Action POS tag': [['VERB']], 'Secondary Action POS text': [['processed']]}}, 'Entity POS': {'Primary Entity POS': {'Primary Entity POS tag': [['NUM', 'NOUN']], 'Primary Entity POS text': [['12-19-2017', 'deletions']]}, 'Secondary Entity POS': {'Secondary Entity POS tag': [[]], 'Secondary Entity POS text': [[]]}}}

# %% [markdown]
# ### Converting Data to used suited format

# %%
datasets, ignored_items = convert_annotation_dataset(not_processed_datasets)

# %%
datasets.keys()
# Out:
# dict_keys(['g02', 'g03', 'g04', 'g05', 'g08', 'g10', 'g11', 'g12', 'g13', 'g14', 'g16', 'g17', 'g18', 'g19', 'g21', 'g22', 'g23', 'g24', 'g25', 'g26', 'g27', 'g28'])

# %%
datasets["g22"]
# Out:
# [{'PID': '#G22#',
#   'USID': '1225',
#   'Text': 'As a PI, I want to properly record all metadata, so that I can ensure proper running of the project in case of staff changes.',
#   'Main Part': 'As a PI, I want to properly record all metadata',
#   'Benefit': 'I can ensure proper running of the project in case of staff changes',
#   'Triggers': {'Main Part': [['PI', 'properly record']], 'Benefit': []},
#   'Targets': {'Main Part': [['properly record', 'all metadata']],
#    'Benefit': [['ensure', 'proper running'], ['changes', 'staff']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1226',
#   'Text': 'As a researcher, I want to indicate where my data will be stored during the project and where after the project, so that it remains accessible during all stages of the data lifecycle.',
#   'Main Part': 'As a researcher, I want to indicate where my data will be stored during the project and where after the project',
#   'Benefit': 'it remains accessible during all stages of the data lifecycle',
#   'Triggers': {'Main Part': [['researcher', 'indicate']], 'Benefit': []},
#   'Targets': {'Main Part': [['indicate', 'where'], ['indicate', 'where']],
#    'Benefit': [['stored', 'data']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['where', 'data'],
#     ['project', 'data'],
#     ['data lifecycle', 'all stages'],
#     ['project', 'data']]}},
#  {'PID': '#G22#',
#   'USID': '1227',
#   'Text': 'As a researcher, I want to import metadata that I captured with a metadata tool, so that I do not have to capture it again in a DMP.',
#   'Main Part': 'As a researcher, I want to import metadata that I captured with a metadata tool',
#   'Benefit': 'I do not have to capture it again in a DMP',
#   'Triggers': {'Main Part': [['researcher', 'import']], 'Benefit': []},
#   'Targets': {'Main Part': [['import', 'metadata']], 'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1228',
#   'Text': 'As a data manager, I want to know how the data is used, so that I can develop more detailed usage and support scenarios with researchers.',
#   'Main Part': 'As a data manager, I want to know how the data is used',
#   'Benefit': 'I can develop more detailed usage and support scenarios with researchers',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how']],
#    'Benefit': [['used', 'data'],
#     ['develop', 'more detailed usage'],
#     ['support', 'scenarios']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1229',
#   'Text': 'As a repository owner, I want to be able to check the planned provenance of the data that will be submitted at the end of a project, so that I can calculate necessary submission fees and check whether it belongs to our target group.',
#   'Main Part': 'As a repository owner, I want to be able to check the planned provenance of the data that will be submitted at the end of a project',
#   'Benefit': 'I can calculate necessary submission fees and check whether it belongs to our target group',
#   'Triggers': {'Main Part': [['repository owner', 'check']], 'Benefit': []},
#   'Targets': {'Main Part': [['check', 'planned provenance']],
#    'Benefit': [['calculate', 'necessary submission fees']]},
#   'Contains': {'Main Part': [['data', 'planned provenance']],
#    'Benefit': [['project', 'data'], ['target group', 'data']]}},
#  {'PID': '#G22#',
#   'USID': '1230',
#   'Text': 'As an IT manager, I want to know about IT resource requirements early in the project lifecycle, so that I can enable resource acquisition planning.',
#   'Main Part': 'As an IT manager, I want to know about IT resource requirements early in the project lifecycle',
#   'Benefit': 'I can enable resource acquisition planning',
#   'Triggers': {'Main Part': [['IT manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'IT resource requirements']],
#    'Benefit': [['enable', 'resource acquisition planning']]},
#   'Contains': {'Main Part': [['project lifecycle',
#      'IT resource requirements']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1231',
#   'Text': 'As a PI, I want to plan what kind of data I want to record/store, so that I can ensure it will possible to store it.',
#   'Main Part': 'As a PI, I want to plan what kind of data I want to record/store',
#   'Benefit': 'I can ensure it will possible to store it',
#   'Triggers': {'Main Part': [['PI', 'plan']], 'Benefit': []},
#   'Targets': {'Main Part': [['plan', 'kind of data I want to record/store'],
#     ['store', 'kind of data I want to record/store']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1232',
#   'Text': 'As an IT staff member, I want to know the security requirements of the data, so that I know which kind of security measures to apply.',
#   'Main Part': 'As an IT staff member, I want to know the security requirements of the data',
#   'Benefit': 'I know which kind of security measures to apply',
#   'Triggers': {'Main Part': [['IT staff member', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'security requirements']],
#    'Benefit': [['know', ' kind of security measures'],
#     ['apply', ' kind of security measures']]},
#   'Contains': {'Main Part': [['data', 'security requirements']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1233',
#   'Text': 'As a data manager, I want to have the description of collected data sets that are used or updated throughout the project lifecycle, so that I can ensure the descriptions are current and add detail as the study proceeds.',
#   'Main Part': 'As a data manager, I want to have the description of collected data sets that are used or updated throughout the project lifecycle',
#   'Benefit': 'I can ensure the descriptions are current and add detail as the study proceeds',
#   'Triggers': {'Main Part': [['data manager', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'description']],
#    'Benefit': [['add', 'detail']]},
#   'Contains': {'Main Part': [['collected data sets', 'description'],
#     ['project lifecycle', 'description']],
#    'Benefit': [['descriptions', 'detail']]}},
#  {'PID': '#G22#',
#   'USID': '1234',
#   'Text': 'As a researcher, I want to know which topics are mandatory and similar in all DMPs, so that I can save time through quickly writing it.',
#   'Main Part': 'As a researcher, I want to know which topics are mandatory and similar in all DMPs',
#   'Benefit': 'I can save time through quickly writing it',
#   'Triggers': {'Main Part': [['researcher', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'topics']], 'Benefit': []},
#   'Contains': {'Main Part': [['all DMPs', 'topics']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1235',
#   'Text': 'As a data manager, I want to know what the content of the data is, so that I can decide to which collection or repository the data fits.',
#   'Main Part': 'As a data manager, I want to know what the content of the data is',
#   'Benefit': 'I can decide to which collection or repository the data fits',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'content']],
#    'Benefit': [['decide', 'collection'], ['decide', 'repository']]},
#   'Contains': {'Main Part': [['data', 'content']],
#    'Benefit': [['repository', 'data'], ['collection', 'data']]}},
#  {'PID': '#G22#',
#   'USID': '1236',
#   'Text': 'As a PI, I want to record information about my DMP, so that an Ethics Committee can review this for compliance with ethical standards.',
#   'Main Part': 'As a PI, I want to record information about my DMP',
#   'Benefit': 'an Ethics Committee can review this for compliance with ethical standards',
#   'Triggers': {'Main Part': [['PI', 'record']], 'Benefit': []},
#   'Targets': {'Main Part': [['record', 'information']], 'Benefit': []},
#   'Contains': {'Main Part': [['DMP', 'information']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1237',
#   'Text': 'As a legalofficer, I want to know about data sensitivity, so that I can establish sharing options.',
#   'Main Part': 'As a legalofficer, I want to know about data sensitivity',
#   'Benefit': 'I can establish sharing options',
#   'Triggers': {'Main Part': [['legalofficer', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'data sensitivity']],
#    'Benefit': [['establish', 'sharing options']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1238',
#   'Text': 'As a data librarian, I want to extract pointers from the DMP to metadata held in other systems, so that I can import this metadata into a data catalogue.',
#   'Main Part': 'As a data librarian, I want to extract pointers from the DMP to metadata held in other systems',
#   'Benefit': 'I can import this metadata into a data catalogue',
#   'Triggers': {'Main Part': [['data librarian', 'extract']], 'Benefit': []},
#   'Targets': {'Main Part': [['extract', 'pointers']],
#    'Benefit': [['import', 'metadata']]},
#   'Contains': {'Main Part': [['DMP', 'pointers'], ['metadata', 'pointers']],
#    'Benefit': [['other systems', 'metadata'],
#     ['data catalogue', 'metadata']]}},
#  {'PID': '#G22#',
#   'USID': '1239',
#   'Text': 'As an IT staff member, I want to have an estimate of the produced data volume, so that I can plan the overall storage consumption.',
#   'Main Part': 'As an IT staff member, I want to have an estimate of the produced data volume',
#   'Benefit': 'I can plan the overall storage consumption',
#   'Triggers': {'Main Part': [['IT staff member', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'estimate']],
#    'Benefit': [['plan', 'overall storage consumption']]},
#   'Contains': {'Main Part': [['produced data volume', 'estimate']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1240',
#   'Text': 'As an administrator, I want to know who funded the project and their requirements, so that I can track the funder specific obligations.',
#   'Main Part': 'As an administrator, I want to know who funded the project and their requirements',
#   'Benefit': 'I can track the funder specific obligations',
#   'Triggers': {'Main Part': [['administrator', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'who']],
#    'Benefit': [['funded', 'project'],
#     ['track', 'funder specific obligations']]},
#   'Contains': {'Main Part': [['who', 'requirements']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1241',
#   'Text': 'As an archivemanager, I want to know the legal status of data, so that I can apply the legal requirements accordingly.',
#   'Main Part': 'As an archivemanager, I want to know the legal status of data',
#   'Benefit': 'I can apply the legal requirements accordingly',
#   'Triggers': {'Main Part': [['archivemanager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'legal status']],
#    'Benefit': [['apply', 'legal requirements']]},
#   'Contains': {'Main Part': [['data', 'legal status']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1242',
#   'Text': 'As a data manager, I want to know which kind of data types will be produced or collected, so that I can determine what basic support services and functionalities are required.',
#   'Main Part': 'As a data manager, I want to know which kind of data types will be produced or collected',
#   'Benefit': 'I can determine what basic support services and functionalities are required',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'kind of data types'],
#     ['produced', 'kind of data types'],
#     ['collected', 'kind of data types']],
#    'Benefit': [['determine', 'basic support services'],
#     ['determine', 'functionalities']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1243',
#   'Text': 'As an IT staff member, I want to know which kind of data types will be produced or collected, so that I can determine what basic support services and functionalities are required.',
#   'Main Part': 'As an IT staff member, I want to know which kind of data types will be produced or collected',
#   'Benefit': 'I can determine what basic support services and functionalities are required',
#   'Triggers': {'Main Part': [['IT staff member', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'kind of data types'],
#     ['produced', 'kind of data types'],
#     ['collected', 'kind of data types']],
#    'Benefit': [['determine', 'basic support services'],
#     ['determine', 'functionalities']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1244',
#   'Text': 'As an archivemanager, I want to know in advance the conservation period of data, so that I can better organize the service by adapting the preservation actions.',
#   'Main Part': 'As an archivemanager, I want to know in advance the conservation period of data',
#   'Benefit': 'I can better organize the service by adapting the preservation actions',
#   'Triggers': {'Main Part': [['archivemanager', 'know in advance']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['know in advance', 'conservation period']],
#    'Benefit': [['better organize', 'service'],
#     ['adapting', 'preservation actions']]},
#   'Contains': {'Main Part': [['data', 'conservation period']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1245',
#   'Text': 'As a data manager, I want to document all rights necessary for managing the data, so that I can curate and preserve the data.',
#   'Main Part': 'As a data manager, I want to document all rights necessary for managing the data',
#   'Benefit': 'I can curate and preserve the data',
#   'Triggers': {'Main Part': [['data manager', 'document']], 'Benefit': []},
#   'Targets': {'Main Part': [['document', 'all rights']],
#    'Benefit': [['managing', 'data'],
#     ['curate', 'data'],
#     ['preserve', 'data']]},
#   'Contains': {'Main Part': [['data', 'all rights']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1246',
#   'Text': 'As a data manager, I want to know what the content of the data is, so that I can check whether the necessary expertise for maintaining intellectual reusability is available.',
#   'Main Part': 'As a data manager, I want to know what the content of the data is',
#   'Benefit': 'I can check whether the necessary expertise for maintaining intellectual reusability is available',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'content']],
#    'Benefit': [['maintaining', 'intellectual reusability'],
#     ['check', 'necessary expertise']]},
#   'Contains': {'Main Part': [['data', 'content']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1247',
#   'Text': 'As a research head, I want to access to the persistent identifiers of datasets provided in the DMP, so that I can check that the DMP has been implemented.',
#   'Main Part': 'As a research head, I want to access to the persistent identifiers of datasets provided in the DMP',
#   'Benefit': 'I can check that the DMP has been implemented',
#   'Triggers': {'Main Part': [['research head', 'access']], 'Benefit': []},
#   'Targets': {'Main Part': [['access', 'persistent identifiers']],
#    'Benefit': [['check', 'DMP'], ['implemented', 'DMP']]},
#   'Contains': {'Main Part': [['datasets', 'persistent identifiers'],
#     ['DMP', 'persistent identifiers']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1248',
#   'Text': 'As a funder, I want to be able to read the costs for data management from the DMP, so that I can check whether our policies work as intended.',
#   'Main Part': 'As a funder, I want to be able to read the costs for data management from the DMP',
#   'Benefit': 'I can check whether our policies work as intended',
#   'Triggers': {'Main Part': [['funder', 'read']], 'Benefit': []},
#   'Targets': {'Main Part': [['read', 'costs']],
#    'Benefit': [['check', 'policies']]},
#   'Contains': {'Main Part': [['data management', 'costs']],
#    'Benefit': [['DMP', 'data management']]}},
#  {'PID': '#G22#',
#   'USID': '1249',
#   'Text': 'As a researcher, I want the DMP to prepopulate information that I have already entered in other institutional systems, so that I do not have to re-enter information ensuring the DMP contains accurate and standardized information.',
#   'Main Part': 'As a researcher, I want the DMP to prepopulate information that I have already entered in other institutional systems',
#   'Benefit': 'I do not have to re-enter information ensuring the DMP contains accurate and standardized information',
#   'Triggers': {'Main Part': [['researcher', 'want']], 'Benefit': []},
#   'Targets': {'Main Part': [['want', 'DMP']],
#    'Benefit': [['prepopulate', 'information']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['institutional systems', 'information'],
#     ['DMP', 'accurate and standardized information']]}},
#  {'PID': '#G22#',
#   'USID': '1250',
#   'Text': 'As a stakeholder, I want to know when the data management plan was created or updated, so that I know how up-to-date the plan is or whether it needs to be updated.',
#   'Main Part': 'As a stakeholder, I want to know when the data management plan was created or updated',
#   'Benefit': 'I know how up-to-date the plan is or whether it needs to be updated',
#   'Triggers': {'Main Part': [['stakeholder', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'when']],
#    'Benefit': [['created', 'data management plan'],
#     ['updated', 'data management plan'],
#     ['know', 'how up-to-date'],
#     ['updated', 'data management plan']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1251',
#   'Text': 'As a stakeholder, I want to know who is responsible for the DMP, so that I can ask them about further details.',
#   'Main Part': 'As a stakeholder, I want to know who is responsible for the DMP',
#   'Benefit': 'I can ask them about further details',
#   'Triggers': {'Main Part': [['stakeholder', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'who is responsible']],
#    'Benefit': [['ask', 'further details']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1252',
#   'Text': 'As a stakeholder, I want to have references to the project proposal, so that I can look up further general information.',
#   'Main Part': 'As a stakeholder, I want to have references to the project proposal',
#   'Benefit': 'I can look up further general information',
#   'Triggers': {'Main Part': [['stakeholder', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'references']],
#    'Benefit': [['look up', 'further general information']]},
#   'Contains': {'Main Part': [['project proposal', 'references']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1253',
#   'Text': 'As a metadata manager, I want to have a short description of project, so that I can be informed about the metadata description.',
#   'Main Part': 'As a metadata manager, I want to have a short description of project',
#   'Benefit': 'I can be informed about the metadata description',
#   'Triggers': {'Main Part': [['metadata manager', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'short description']], 'Benefit': []},
#   'Contains': {'Main Part': [['project', 'short description']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1254',
#   'Text': 'As a rector, I want to know how many data will be stored, so that I can plan long term resources.',
#   'Main Part': 'As a rector, I want to know how many data will be stored',
#   'Benefit': 'I can plan long term resources',
#   'Triggers': {'Main Part': [['rector', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how many']],
#    'Benefit': [['stored', 'data'], ['plan', 'long term resources']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1255',
#   'Text': 'As a data manager, I want to know the time plan for collecting data, so that I can plan the data management.',
#   'Main Part': 'As a data manager, I want to know the time plan for collecting data',
#   'Benefit': 'I can plan the data management',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'time plan']],
#    'Benefit': [['collecting', 'data'], ['plan', 'data management']]},
#   'Contains': {'Main Part': [['data', 'time plan']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1256',
#   'Text': 'As a data librarian, I want to import administrative information regarding a project into DMP, so that I can prepopulate the DMP.',
#   'Main Part': 'As a data librarian, I want to import administrative information regarding a project into DMP',
#   'Benefit': 'I can prepopulate the DMP',
#   'Triggers': {'Main Part': [['data librarian', 'import']], 'Benefit': []},
#   'Targets': {'Main Part': [['import', 'administrative information']],
#    'Benefit': [['prepopulate', 'DMP']]},
#   'Contains': {'Main Part': [['DMP', 'administrative information'],
#     ['project', 'administrative information']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1257',
#   'Text': 'As a manager, I want to know about all resources and services used for the data, so that I can estimate the true cost of the project.',
#   'Main Part': 'As a manager, I want to know about all resources and services used for the data',
#   'Benefit': 'I can estimate the true cost of the project',
#   'Triggers': {'Main Part': [['manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'all resources'],
#     ['know', 'services used']],
#    'Benefit': [['estimate', 'true cost']]},
#   'Contains': {'Main Part': [], 'Benefit': [['project', 'true cost']]}},
#  {'PID': '#G22#',
#   'USID': '1258',
#   'Text': 'As an archivemanager, I want to reuse the information regarding file format, so that I can apply automated checks for the file validation.',
#   'Main Part': 'As an archivemanager, I want to reuse the information regarding file format',
#   'Benefit': 'I can apply automated checks for the file validation',
#   'Triggers': {'Main Part': [['archivemanager', 'reuse']], 'Benefit': []},
#   'Targets': {'Main Part': [['reuse', 'information']],
#    'Benefit': [['apply', 'automated checks']]},
#   'Contains': {'Main Part': [['file format', 'information']],
#    'Benefit': [['file validation', 'automated checks']]}},
#  {'PID': '#G22#',
#   'USID': '1259',
#   'Text': 'As a researcher, I want to know how many resources are needed during the project, so that I can calculate costs.',
#   'Main Part': 'As a researcher, I want to know how many resources are needed during the project',
#   'Benefit': 'I can calculate costs',
#   'Triggers': {'Main Part': [['researcher', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how many']],
#    'Benefit': [['calculate', 'costs']]},
#   'Contains': {'Main Part': [], 'Benefit': [['project', 'resources']]}},
#  {'PID': '#G22#',
#   'USID': '1260',
#   'Text': 'As a researcher, I want to extract the description of the data collected, so that I can reuse it for the writing of a data paper.',
#   'Main Part': 'As a researcher, I want to extract the description of the data collected',
#   'Benefit': 'I can reuse it for the writing of a data paper',
#   'Triggers': {'Main Part': [['researcher', 'extract']], 'Benefit': []},
#   'Targets': {'Main Part': [['extract', 'description']],
#    'Benefit': [['writing', 'data paper']]},
#   'Contains': {'Main Part': [['data collected', 'description']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1261',
#   'Text': 'As a researcher, I want to record research publications in the institutional repository or CRIS with DMP records, so that I can generate reports of research output resulting from a project.',
#   'Main Part': 'As a researcher, I want to record research publications in the institutional repository or CRIS with DMP records',
#   'Benefit': 'I can generate reports of research output resulting from a project',
#   'Triggers': {'Main Part': [['researcher', 'record']], 'Benefit': []},
#   'Targets': {'Main Part': [['record', 'research publications']],
#    'Benefit': [['generate', 'reports']]},
#   'Contains': {'Main Part': [['institutional repository',
#      'research publications'],
#     ['CRIS', 'research publications']],
#    'Benefit': [['project', 'research output'],
#     ['institutional repository', 'DMP records'],
#     ['CRIS', 'DMP records'],
#     ['reports', 'research output']]}},
#  {'PID': '#G22#',
#   'USID': '1262',
#   'Text': 'As a researcher, I want to link research publications in the institutional repository or CRIS with DMP records, so that I can generate reports of research output resulting from a project.',
#   'Main Part': 'As a researcher, I want to link research publications in the institutional repository or CRIS with DMP records',
#   'Benefit': 'I can generate reports of research output resulting from a project',
#   'Triggers': {'Main Part': [['researcher', 'link']], 'Benefit': []},
#   'Targets': {'Main Part': [['link', 'research publications']],
#    'Benefit': [['generate', 'reports']]},
#   'Contains': {'Main Part': [['institutional repository',
#      'research publications'],
#     ['CRIS', 'research publications']],
#    'Benefit': [['institutional repository', 'DMP records'],
#     ['CRIS', 'DMP records'],
#     ['project', 'research output'],
#     ['reports', 'research output']]}},
#  {'PID': '#G22#',
#   'USID': '1263',
#   'Text': 'As a researcher, I want to store agreements relating to third party data used in a project, so that the data can be cited, attributed and used correctly.',
#   'Main Part': 'As a researcher, I want to store agreements relating to third party data used in a project',
#   'Benefit': 'the data can be cited, attributed and used correctly',
#   'Triggers': {'Main Part': [['researcher', 'store']], 'Benefit': []},
#   'Targets': {'Main Part': [['store', 'agreements']],
#    'Benefit': [['cited', 'data'],
#     ['attributed', 'data'],
#     ['used correctly', 'data']]},
#   'Contains': {'Main Part': [], 'Benefit': [['project', 'third party data']]}},
#  {'PID': '#G22#',
#   'USID': '1264',
#   'Text': 'As an ethics manager, I want to be informed about the data, so that I can check for sensitivity of data.',
#   'Main Part': 'As an ethics manager, I want to be informed about the data',
#   'Benefit': 'I can check for sensitivity of data',
#   'Triggers': {'Main Part': [['ethics manager', 'be informed']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['be informed', 'data']],
#    'Benefit': [['check', 'sensitivity']]},
#   'Contains': {'Main Part': [], 'Benefit': [['data', 'sensitivity']]}},
#  {'PID': '#G22#',
#   'USID': '1265',
#   'Text': 'As a repository operator, I want to know about the kind of data, so that I can evaluate the storage size and system.',
#   'Main Part': 'As a repository operator, I want to know about the kind of data',
#   'Benefit': 'I can evaluate the storage size and system',
#   'Triggers': {'Main Part': [['repository operator', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'kind of data']],
#    'Benefit': [['evaluate', 'storage size'], ['evaluate', 'system']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1266',
#   'Text': 'As a researcher, I want to know about costs, so that I can plan my research.',
#   'Main Part': 'As a researcher, I want to know about costs',
#   'Benefit': 'I can plan my research',
#   'Triggers': {'Main Part': [['researcher', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'costs']],
#    'Benefit': [['plan', 'research']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1267',
#   'Text': 'As a repository manager, I need details on the type of data, so that I can check if the archiving can be arranged.',
#   'Main Part': 'As a repository manager, I need details on the type of data',
#   'Benefit': 'I can check if the archiving can be arranged',
#   'Triggers': {'Main Part': [['repository manager', 'need']], 'Benefit': []},
#   'Targets': {'Main Part': [['need', 'details']],
#    'Benefit': [['check', 'archiving'], ['arranged', 'archiving']]},
#   'Contains': {'Main Part': [['type of data', 'details']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1268',
#   'Text': 'As an IT officer, I want to know how secure data is, so that I can ensure legal compliance.',
#   'Main Part': 'As an IT officer, I want to know how secure data is',
#   'Benefit': 'I can ensure legal compliance',
#   'Triggers': {'Main Part': [['IT officer', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how secure']],
#    'Benefit': [['ensure', 'legal compliance']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1269',
#   'Text': 'As a funder, I want to know how secure data is, so that I can ensure legal compliance.',
#   'Main Part': 'As a funder, I want to know how secure data is',
#   'Benefit': 'I can ensure legal compliance',
#   'Triggers': {'Main Part': [['funder', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how secure']],
#    'Benefit': [['ensure', 'legal compliance']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1270',
#   'Text': 'As a Research Centre Director, I want to receive regular summary reports of research data, so that I understand trends in data use among staff and postgraduate students.',
#   'Main Part': 'As a Research Centre Director, I want to receive regular summary reports of research data',
#   'Benefit': 'I understand trends in data use among staff and postgraduate students',
#   'Triggers': {'Main Part': [['Research Centre Director', 'receive']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['receive', 'regular summary reports']],
#    'Benefit': [['understand', 'trends']]},
#   'Contains': {'Main Part': [['regular summary reports', 'research data']],
#    'Benefit': [['data use', 'trends']]}},
#  {'PID': '#G22#',
#   'USID': '1271',
#   'Text': 'As a Postgraduate Convenor, I want to receive regular summary reports of research data, so that I understand trends in data use among staff and postgraduate students.',
#   'Main Part': 'As a Postgraduate Convenor, I want to receive regular summary reports of research data',
#   'Benefit': 'I understand trends in data use among staff and postgraduate students',
#   'Triggers': {'Main Part': [['Postgraduate Convenor', 'receive']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['receive', 'regular summary reports']],
#    'Benefit': [['understand', 'trends']]},
#   'Contains': {'Main Part': [['research data', 'regular summary reports']],
#    'Benefit': [['data use', 'trends']]}},
#  {'PID': '#G22#',
#   'USID': '1272',
#   'Text': 'As a research support officer, I want to ensure compliance to the funders’ rules, so that I can ensure all costs will be accepted.',
#   'Main Part': 'As a research support officer, I want to ensure compliance to the funders’ rules',
#   'Benefit': 'I can ensure all costs will be accepted',
#   'Triggers': {'Main Part': [['research support officer', 'ensure']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['ensure', 'compliance ']],
#    'Benefit': [['accepted', 'all costs']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1273',
#   'Text': 'As a funder, I want to be able to check all the repositories mentioned in a DMP, so that I can verify whether the project has followed our funding rules.',
#   'Main Part': 'As a funder, I want to be able to check all the repositories mentioned in a DMP',
#   'Benefit': 'I can verify whether the project has followed our funding rules',
#   'Triggers': {'Main Part': [['funder', 'check']], 'Benefit': []},
#   'Targets': {'Main Part': [['check', 'repositories mentioned']],
#    'Benefit': [['followed', 'funding rules'], ['verify', 'project']]},
#   'Contains': {'Main Part': [['DMP', 'repositories mentioned']],
#    'Benefit': [['project', 'funding rules']]}},
#  {'PID': '#G22#',
#   'USID': '1274',
#   'Text': 'As a PI, I want to plan what kind of data I want to store, so that I can ensure it will be possible to store it.',
#   'Main Part': 'As a PI, I want to plan what kind of data I want to store',
#   'Benefit': 'I can ensure it will be possible to store it',
#   'Triggers': {'Main Part': [['PI', 'plan']], 'Benefit': []},
#   'Targets': {'Main Part': [['plan', 'kind of data I want to store'],
#     ['store', 'kind of data I want to store']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1275',
#   'Text': 'As a PI, I want to know how secure data is, so that I can ensure legal compliance.',
#   'Main Part': 'As a PI, I want to know how secure data is',
#   'Benefit': 'I can ensure legal compliance',
#   'Triggers': {'Main Part': [['PI', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how secure']],
#    'Benefit': [['ensure', 'legal compliance']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1276',
#   'Text': 'As a Director of Research Integrity, I want to access reports containing details of research projects in which data are classified as sensitive or highly sensitive, so that I can confirm security protocols are applied to these data.',
#   'Main Part': 'As a Director of Research Integrity, I want to access reports containing details of research projects in which data are classified as sensitive or highly sensitive',
#   'Benefit': 'I can confirm security protocols are applied to these data',
#   'Triggers': {'Main Part': [['Director of Research Integrity', 'access']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['access', 'reports']],
#    'Benefit': [['confirm', 'security protocols'],
#     ['applied', 'security protocols'],
#     ['classified', 'data']]},
#   'Contains': {'Main Part': [['reports', 'details']],
#    'Benefit': [['data', 'security protocols'],
#     ['research projects', 'details']]}},
#  {'PID': '#G22#',
#   'USID': '1277',
#   'Text': 'As an archive, I want to get information about the volume of data to preserve at an early stage, so that I can provide the adequate storage infrastructure.',
#   'Main Part': 'As an archive, I want to get information about the volume of data to preserve at an early stage',
#   'Benefit': 'I can provide the adequate storage infrastructure',
#   'Triggers': {'Main Part': [['archive', 'get']], 'Benefit': []},
#   'Targets': {'Main Part': [['get', 'information']],
#    'Benefit': [['provide', 'adequate storage infrastructure']]},
#   'Contains': {'Main Part': [['volume', 'information']],
#    'Benefit': [['data to preserve', 'volume']]}},
#  {'PID': '#G22#',
#   'USID': '1278',
#   'Text': 'As a researcher, I want to know how long it will take to archive, so that I can plan further steps.',
#   'Main Part': 'As a researcher, I want to know how long it will take to archive',
#   'Benefit': 'I can plan further steps',
#   'Triggers': {'Main Part': [['researcher', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how long']],
#    'Benefit': [['plan', 'further steps']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1279',
#   'Text': 'As a PI, I want to know who owns the data, so that I know what I am allowed to do with it.',
#   'Main Part': 'As a PI, I want to know who owns the data',
#   'Benefit': 'I know what I am allowed to do with it',
#   'Triggers': {'Main Part': [['PI', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'who']], 'Benefit': [['know', 'what']]},
#   'Contains': {'Main Part': [['who', 'data']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1280',
#   'Text': 'As a data manager, I want to have references to documentation of the data and its creation process, so that the data can be re-used and managed.',
#   'Main Part': 'As a data manager, I want to have references to documentation of the data and its creation process',
#   'Benefit': 'the data can be re-used and managed',
#   'Triggers': {'Main Part': [['data manager', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'references'],
#     ['have', 'creation process']],
#    'Benefit': [['re-used', 'data'], ['managed', 'data']]},
#   'Contains': {'Main Part': [['documentation', 'references'],
#     ['documentation', 'creation process']],
#    'Benefit': [['data', 'documentation']]}},
#  {'PID': '#G22#',
#   'USID': '1281',
#   'Text': 'As an archivemanager, I want to make sure that detailed metadata are associated to data so that it will be understandable by future users.',
#   'Main Part': 'As an archivemanager, I want to make sure that detailed metadata are associated to data',
#   'Benefit': 'it will be understandable by future users',
#   'Triggers': {'Main Part': [['archivemanager', 'make sure']], 'Benefit': []},
#   'Targets': {'Main Part': [],
#    'Benefit': [['associated', 'detailed metadata']]},
#   'Contains': {'Main Part': [], 'Benefit': [['data', 'detailed metadata']]}},
#  {'PID': '#G22#',
#   'USID': '1282',
#   'Text': 'As a data manager, I want to know which kind of data types will be produced or collected, so that I can ensure that the necessary technical resources and technical know-how is available.',
#   'Main Part': 'As a data manager, I want to know which kind of data types will be produced or collected',
#   'Benefit': 'I can ensure that the necessary technical resources and technical know-how is available',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'kind of data types'],
#     ['produced', 'kind of data types'],
#     ['collected', 'kind of data types']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1283',
#   'Text': 'As an IT staff member, I want to know which kind of data types will be produced or collected, so that I can ensure that the necessary technical resources and technical know-how is available.',
#   'Main Part': 'As an IT staff member, I want to know which kind of data types will be produced or collected',
#   'Benefit': 'I can ensure that the necessary technical resources and technical know-how is available',
#   'Triggers': {'Main Part': [['IT staff member', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'kind of data types'],
#     ['produced', 'kind of data types'],
#     ['collected', 'kind of data types']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1284',
#   'Text': 'As an IT staff member, I want to know how the data is used, so that I can determine what kind of basic services and functionalities are required.',
#   'Main Part': 'As an IT staff member, I want to know how the data is used',
#   'Benefit': 'I can determine what kind of basic services and functionalities are required',
#   'Triggers': {'Main Part': [['IT staff member', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'how']],
#    'Benefit': [['used', 'data'],
#     ['determine', 'kind of basic services'],
#     ['determine', 'functionalities']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1285',
#   'Text': 'As a data manager, I want to know whether the collected data depends on other data sets from my own or other institutions, so that I can ensure that these dependencies are maintained.',
#   'Main Part': 'As a data manager, I want to know whether the collected data depends on other data sets from my own or other institutions',
#   'Benefit': 'I can ensure that these dependencies are maintained',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [], 'Benefit': [['maintained', 'dependencies']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['own or other institutions', 'other data sets']]}},
#  {'PID': '#G22#',
#   'USID': '1286',
#   'Text': 'As an IT staff member, I want to know which formats are used, so that I can determine what kind of technical services and functionalities are required.',
#   'Main Part': 'As an IT staff member, I want to know which formats are used',
#   'Benefit': 'I can determine what kind of technical services and functionalities are required',
#   'Triggers': {'Main Part': [['IT staff member', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'formats'], ['used', 'formats']],
#    'Benefit': [['determine', 'kind of technical services'],
#     ['determine', 'functionalities']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1287',
#   'Text': 'As an IT staff member, I want to know with which software or technology the data is produced or used, so that I can determine what kind of technical services and functionalities are required.',
#   'Main Part': 'As an IT staff member, I want to know with which software or technology the data is produced or used',
#   'Benefit': 'I can determine what kind of technical services and functionalities are required',
#   'Triggers': {'Main Part': [['IT staff member', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'software'], ['know', 'technology']],
#    'Benefit': [['produced', 'data'],
#     ['used', 'data'],
#     ['determine', 'kind of technical services'],
#     ['determine', 'functionalities']]},
#   'Contains': {'Main Part': [['software', 'data'], ['technology', 'data']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1288',
#   'Text': 'As a data manager, I want to know which information is necessary to re-use the data, so that it can be checked whether all necessary information is available for researchers interested in re-using the data.',
#   'Main Part': 'As a data manager, I want to know which information is necessary to re-use the data',
#   'Benefit': 'it can be checked whether all necessary information is available for researchers interested in re-using the data',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'information']],
#    'Benefit': [['re-use', 'data'],
#     ['re-using', 'data'],
#     ['checked', 'information']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['researchers', 'all necessary information']]}},
#  {'PID': '#G22#',
#   'USID': '1289',
#   'Text': 'As a data manager, I want to know which formats are used, so that I know what technology or background information might be necessary to use the data.',
#   'Main Part': 'As a data manager, I want to know which formats are used',
#   'Benefit': 'I know what technology or background information might be necessary to use the data',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'formats'], ['used', 'formats']],
#    'Benefit': [['know', 'technology'],
#     ['know', 'background information'],
#     ['use', 'data']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1290',
#   'Text': 'As a data manager, I want to know whether the data can be reproduced efficiently, so that I can determine whether and how the data has to be stored.',
#   'Main Part': 'As a data manager, I want to know whether the data can be reproduced efficiently',
#   'Benefit': 'I can determine whether and how the data has to be stored',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [],
#    'Benefit': [['reproduced efficiently', 'data'],
#     ['determine', 'how'],
#     ['stored', 'data']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1291',
#   'Text': 'As a data manager, I want to know with which software or technology the data is produced or used, so that I know what technology or background information might be necessary to (re-)use the data.',
#   'Main Part': 'As a data manager, I want to know with which software or technology the data is produced or used',
#   'Benefit': 'I know what technology or background information might be necessary to (re-)use the data',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'software'],
#     ['know', 'technology'],
#     ['know', 'technology']],
#    'Benefit': [['produced', 'data'],
#     ['used', 'data'],
#     ['know', 'background information'],
#     ['(re-)use', 'data']]},
#   'Contains': {'Main Part': [['software', 'data']],
#    'Benefit': [['technology', 'data']]}},
#  {'PID': '#G22#',
#   'USID': '1292',
#   'Text': 'As a research evaluation manager, I want to ensure all data are quoted correctly with our affiliation, so that they are counted towards our citation counts.',
#   'Main Part': 'As a research evaluation manager, I want to ensure all data are quoted correctly with our affiliation',
#   'Benefit': 'they are counted towards our citation counts',
#   'Triggers': {'Main Part': [['research evaluation manager', 'ensure']],
#    'Benefit': []},
#   'Targets': {'Main Part': [], 'Benefit': [['quoted correctly', 'all data']]},
#   'Contains': {'Main Part': [], 'Benefit': [['all data', 'affiliation']]}},
#  {'PID': '#G22#',
#   'USID': '1293',
#   'Text': 'As an administrator, I want to check that all data has the appropriate security level, so that I can demonstrate compliance.',
#   'Main Part': 'As an administrator, I want to check that all data has the appropriate security level',
#   'Benefit': 'I can demonstrate compliance',
#   'Triggers': {'Main Part': [['administrator', 'check']], 'Benefit': []},
#   'Targets': {'Main Part': [['check', 'all data']],
#    'Benefit': [['demonstrate', 'compliance']]},
#   'Contains': {'Main Part': [['all data', 'appropriate security level']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1294',
#   'Text': 'As a data manager, I want to know the security requirements of the data, so that I can check whether the data can be kept secure.',
#   'Main Part': 'As a data manager, I want to know the security requirements of the data',
#   'Benefit': 'I can check whether the data can be kept secure',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'security requirements']],
#    'Benefit': [['kept secure', 'data']]},
#   'Contains': {'Main Part': [['data', 'security requirements']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1295',
#   'Text': 'As a institutional data steward, I want to be able to extract the data sets that are submitted to external repositories, so that I can add them to an institutional data catalogue.',
#   'Main Part': 'As a institutional data steward, I want to be able to extract the data sets that are submitted to external repositories',
#   'Benefit': 'I can add them to an institutional data catalogue',
#   'Triggers': {'Main Part': [['institutional data steward', 'extract']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['extract', 'data sets']], 'Benefit': []},
#   'Contains': {'Main Part': [['external repositories', 'data sets']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1296',
#   'Text': 'As an institutional data manager, I want to know about the privacy and security requirements of the data, so that I can plan the right storage system and sharing permissions.',
#   'Main Part': 'As an institutional data manager, I want to know about the privacy and security requirements of the data',
#   'Benefit': 'I can plan the right storage system and sharing permissions',
#   'Triggers': {'Main Part': [['institutional data manager', 'know']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['know', 'privacy'],
#     ['know', 'security requirements']],
#    'Benefit': [['plan', 'right storage system'],
#     ['plan', 'sharing permissions']]},
#   'Contains': {'Main Part': [['data', 'privacy'],
#     ['data', 'security requirements']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1297',
#   'Text': 'As a researcher, I want to see the sections on costing by other researchers in my department, so that I can see if we could share data manager posts.',
#   'Main Part': 'As a researcher, I want to see the sections on costing by other researchers in my department',
#   'Benefit': 'I can see if we could share data manager posts',
#   'Triggers': {'Main Part': [['researcher', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'sections']],
#    'Benefit': [['share', 'data manager posts']]},
#   'Contains': {'Main Part': [['sections', 'costing']],
#    'Benefit': [['department', 'other researchers'],
#     ['other researchers', 'costing']]}},
#  {'PID': '#G22#',
#   'USID': '1298',
#   'Text': 'As a researcher, I want to see the sections on roles submitted by other researchers in my department, so that I can see if we could share data manager posts.',
#   'Main Part': 'As a researcher, I want to see the sections on roles submitted by other researchers in my department',
#   'Benefit': 'I can see if we could share data manager posts',
#   'Triggers': {'Main Part': [['researcher', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'sections']],
#    'Benefit': [['share', 'data manager posts'], ['submitted', 'roles']]},
#   'Contains': {'Main Part': [['sections', 'roles']],
#    'Benefit': [['department', 'other researchers'],
#     ['other researchers', 'roles']]}},
#  {'PID': '#G22#',
#   'USID': '1299',
#   'Text': 'As a researcher, I want to see the sections on responsibilities submitted by other researchers in my department, so that I can see if we could share data manager posts.',
#   'Main Part': 'As a researcher, I want to see the sections on responsibilities submitted by other researchers in my department',
#   'Benefit': 'I can see if we could share data manager posts',
#   'Triggers': {'Main Part': [['researcher', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'sections']],
#    'Benefit': [['share', 'data manager posts'],
#     ['submitted', 'responsibilities']]},
#   'Contains': {'Main Part': [['sections', 'responsibilities']],
#    'Benefit': [['department', 'other researchers'],
#     ['other researchers', 'responsibilities']]}},
#  {'PID': '#G22#',
#   'USID': '1300',
#   'Text': 'As a faculty data steward, I want to see the sections on costing, so that I can ensure sufficient expertise on data management to support the project.',
#   'Main Part': 'As a faculty data steward, I want to see the sections on costing',
#   'Benefit': 'I can ensure sufficient expertise on data management to support the project',
#   'Triggers': {'Main Part': [['faculty data steward', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'sections']],
#    'Benefit': [['ensure', 'sufficient expertise'], ['support', 'project']]},
#   'Contains': {'Main Part': [['sections', 'costing']],
#    'Benefit': [['data management', 'sufficient expertise'],
#     ['project', 'data management']]}},
#  {'PID': '#G22#',
#   'USID': '1301',
#   'Text': 'As a faculty data steward, I want to see the sections on roles, so that I can ensure sufficient expertise on data management to support the project.',
#   'Main Part': 'As a faculty data steward, I want to see the sections on roles',
#   'Benefit': 'I can ensure sufficient expertise on data management to support the project',
#   'Triggers': {'Main Part': [['faculty data steward', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'sections']],
#    'Benefit': [['ensure', 'sufficient expertise'], ['support', 'project']]},
#   'Contains': {'Main Part': [['sections', 'roles']],
#    'Benefit': [['data management', 'sufficient expertise'],
#     ['project', 'data management']]}},
#  {'PID': '#G22#',
#   'USID': '1302',
#   'Text': 'As a faculty data steward, I want to see the sections on responsibilities, so that I can ensure sufficient expertise on data management to support the project.',
#   'Main Part': 'As a faculty data steward, I want to see the sections on responsibilities',
#   'Benefit': 'I can ensure sufficient expertise on data management to support the project',
#   'Triggers': {'Main Part': [['faculty data steward,', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'sections']],
#    'Benefit': [['support', 'project'], ['ensure', 'sufficient expertise']]},
#   'Contains': {'Main Part': [['sections', 'responsibilities']],
#    'Benefit': [['data management', 'sufficient expertise'],
#     ['project', 'data management']]}},
#  {'PID': '#G22#',
#   'USID': '1303',
#   'Text': 'As a data manager, I want to clarify the necessary rights for re-using the data, so that it is legal to reuse the data.',
#   'Main Part': 'As a data manager, I want to clarify the necessary rights for re-using the data',
#   'Benefit': 'it is legal to reuse the data',
#   'Triggers': {'Main Part': [['data manager', 'clarify']], 'Benefit': []},
#   'Targets': {'Main Part': [['clarify', 'necessary rights']],
#    'Benefit': [['re-using', 'data'], ['reuse', 'data']]},
#   'Contains': {'Main Part': [['data', 'necessary rights']], 'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1304',
#   'Text': 'As a researcher, I want to record my intention to share data I have collected under terms of a particular licence, so that other researchers who use the data understand the rights of use.',
#   'Main Part': 'As a researcher, I want to record my intention to share data I have collected under terms of a particular licence',
#   'Benefit': 'other researchers who use the data understand the rights of use',
#   'Triggers': {'Main Part': [['researcher', 'record']], 'Benefit': []},
#   'Targets': {'Main Part': [['record', 'intention']],
#    'Benefit': [['share', 'data I have collected'],
#     ['use', 'data'],
#     ['understand', 'rights of use']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['particular licence', 'terms'], ['data', 'rights of use']]}},
#  {'PID': '#G22#',
#   'USID': '1305',
#   'Text': 'As a data manager, I want to plan the anonymization of data, so that we protect the privacy of the people participating in the research as good as possible and still ensure reusability of data.',
#   'Main Part': 'As a data manager, I want to plan the anonymization of data',
#   'Benefit': 'we protect the privacy of the people participating in the research as good as possible and still ensure reusability of data',
#   'Triggers': {'Main Part': [['data manager', 'plan']], 'Benefit': []},
#   'Targets': {'Main Part': [['plan', 'anonymization of data']],
#    'Benefit': [['participating', 'research'],
#     ['still ensure', 'reusability of data'],
#     ['protect', 'privacy']]},
#   'Contains': {'Main Part': [], 'Benefit': [['people', 'privacy']]}},
#  {'PID': '#G22#',
#   'USID': '1306',
#   'Text': 'As a repository manager, I want to have metadata in additional languages, so that I can allow for multilingual data archive.',
#   'Main Part': 'As a repository manager, I want to have metadata in additional languages',
#   'Benefit': 'I can allow for multilingual data archive',
#   'Triggers': {'Main Part': [['repository manager', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'metadata']],
#    'Benefit': [['allow', 'multilingual data archive']]},
#   'Contains': {'Main Part': [['metadata', 'additional languages']],
#    'Benefit': []}},
#  {'PID': '#G22#',
#   'USID': '1307',
#   'Text': 'As a data manager, I want to know whether the DMP was approved, so that I can proceed with the required next steps.',
#   'Main Part': 'As a data manager, I want to know whether the DMP was approved',
#   'Benefit': 'I can proceed with the required next steps',
#   'Triggers': {'Main Part': [['data manager', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [],
#    'Benefit': [['approved', 'DMP'], ['proceed', 'required next steps']]},
#   'Contains': {'Main Part': [], 'Benefit': []}}]

# %%
ignored_items["#G02#"][0]
# Out:
# 'PID: #G02#; Text: As a UI designer, I want to redesign the Resources page, so that it matches the new Broker design styles.; Label Type: Contain'

# %%
df_ignored_items: pd.DataFrame = None
if True:            
    cols: list[str] =  ["PID", "Text", "Label Type"]
    df_ignored_items = pd.DataFrame(columns=cols)
    current_ignored_data: dict = {}
    curremt_pid: int = 0
    current_text: str = "" 
    for key, set in ignored_items.items():
        for item in set:
            parts = item.split('; ')
            for part in parts:
                key, value = part.split(': ', 1)
                current_ignored_data[key] = value
            df_ignored_items = pd.concat([df_ignored_items, pd.DataFrame([current_ignored_data])], ignore_index = True)               
            df_ignored_items.reset_index()
    save_to_excel(df_ignored_items, formatter_ignored_items, "Incomplete US labelling", os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))
print(f"Count of ignored Elements: {df_ignored_items.shape[0]}")
df_ignored_items.head()
# Out:
# Count of ignored Elements: 195
#      PID                                               Text Label Type
# 0  #G02#  As a UI designer, I want to redesign the Resou...    Contain
# 1  #G02#  As a UI designer, I want to track the issues t...     Target
# 2  #G02#  As a UI designer, I want to track the issues t...     Target
# 3  #G02#  As a UI designer, I want to track the issues t...     Target
# 4  #G02#  As an agency user, I want to submit my data el...    Contain

# %% [markdown]
# ### Datatransformation to panda dataframes and numpy arrarys.

# %%
def transform_2_dataframe(data: list):
    rows = []
    for entry in data:
        row = {
            "PID": entry["PID"],
            "USID": entry["USID"],
            "Text": entry["Text"],
            "Main Part": entry["Main Part"],
            "Benefit": entry["Benefit"],
            "Triggers": entry["Triggers"],
            "Targets": entry["Targets"],
            "Contains": entry["Contains"],
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
# n(n-1) / 2
def transform_pairwise(df: pd.DataFrame):
    rows = []
    for i, j in combinations(range(df.shape[0]), 2):
        row = {
            "First PID": df.iloc[i, 0],
            "First USID": df.iloc[i, 1],
            "First Text": df.iloc[i, 2],
            "First Main Part": df.iloc[i, 3],
            "First Benefit": df.iloc[i, 4],
            "First Triggers": df.iloc[i, 5],
            "First Targets": df.iloc[i, 6],
            "First Contains": df.iloc[i, 7],
            "Second PID": df.iloc[j, 0],
            "Second USID": df.iloc[j, 1],
            "Second Text": df.iloc[j, 2],
            "Second Main Part": df.iloc[j, 3],
            "Second Benefit": df.iloc[j, 4],
            "Second Triggers": df.iloc[j, 5],
            "Second Targets": df.iloc[j, 6],
            "Second Contains": df.iloc[j, 7]
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
def convert_dataframe_to_json(pair: pd.Series) -> tuple[dict, dict]:
    pair = pair.to_dict()
    us_one: dict = {
        "USID": pair["First USID"],
        "Text": pair["First Text"],
        "Main Part": pair["First Main Part"],
        "Benefit": pair["First Benefit"],
        "Triggers": pair["First Triggers"],
        "Targets": pair["First Targets"],
        "Contains": pair["First Contains"]
    }
    
    us_two: dict = {
        "USID": pair["Second USID"],
        "Text": pair["Second Text"],
        "Main Part": pair["Second Main Part"],
        "Benefit": pair["Second Benefit"],
        "Triggers": pair["Second Triggers"],
        "Targets": pair["Second Targets"],
        "Contains": pair["Second Contains"]
    }

    json_one: dict = json.loads(json.dumps(us_one))
    json_two: dict = json.loads(json.dumps(us_two))
    
    return json_one, json_two

# %%
def template_request_two_user_stories(
    current_message: list[dict],
    idx: int,
    pairs: pd.DataFrame,
) -> None:
    row = pairs.iloc[idx]
    json_us_one: dict = None
    json_us_two: dict = None
    json_us_one, json_us_two = convert_dataframe_to_json(row)
    request: dict = PromptHelperBuilder.get_instance().parsing_to_pair_requests(json_us_one, json_us_two)
    current_message.append(request)

# %%
def sort_threaded_results(to_sort: dict) -> None:
    new_list: list = None
    for _ in to_sort.values():
        new_list = sorted(_, key=lambda x: (int(x['relatedStories'][0]), int(x['relatedStories'][1])))
        _.clear()
        _ += new_list

# %%
def json_validator(json_data: dict) -> tuple[bool, str]:
    return validation(json_data, chat_gpt_schema_with_annotations)

# %% [markdown]
# ### Prepaire Prompting

# %%
# Init PromptBuilder
builder: PromptBuilder = PromptBuilder.get_instance()

# Collection of messages
message: list[dict] = []

# %%
# Actor Role
message.append(builder.get_actor_role())
message.append(builder.get_system_simulation_actor_role())

# %%
# User Story Definition
message.append(builder.get_user_story_definition())
message.append(builder.get_system_simulation_user_story_definition())

# %%
# Task and fucos definition
message.append(builder.get_task_focus_definition())
message.append(builder.get_system_simulation_task_focus_definition())

# %%
# Redundancy Definition for User Story pair
message.append(builder.get_redundancy_full_partial_definition())
message.append(builder.get_system_simulation_redundancy_full_partial_definition())

# %%
# Defining the JSON output
message.append(builder.get_json_format_defintion())
message.append(builder.get_system_simulation_json_format_defintion())

# %%
# Providing Examples
message.append(builder.get_input_output_examples(["USID", "Text", "Main Part", "Benefit", "Triggers", "Targets", "Contains"]))
message.append(builder.get_system_simulation_example_consideration())

# %%
if True:
    message_text: str = ""
    for key in message:
        message_text += key["content"]
        print(key["content"])
    enc = tiktoken.get_encoding('cl100k_base')
    token_size = enc.encode(message_text)
    print("-" * 3 + "Token" + "-" * 3)
    print(token_size)
    print("-" * 3 + "Sum of Tokens" + "-" * 3)
    # The output is not correct as the result from the online pages differs https://platform.openai.com/tokenizer
    print("The total token sum is: " + locale.format_string("%d", sum(token_size), grouping=True))
# Out:
# Act as a Requirements Engineer focused on identifying redundancies. Please review pairs of two User Stories and pinpoint any unnecessary duplications that obscure clarity or add no distinct value.
# As a requirements engineer in agile development, it is my responsibility to review user stories for redundancies. My goal is to identify and report any overlapping or duplicate requirements. By carefully analysing the user stories in depth, I ensure that each requirement is necessary and contributes uniquely, increasing the coherence of the product.
# A user story is a semi-structured sentence containing the following information:
# (1) the persona involved in the story,
# (2) the main part containing the actions that the persona will perform on the system and the entities involved in the actions, and optionally
# (3) a benefit that the persona will receive after having completed these actions. The benefit may also include actions and entities.
# Classically, a user story is expressed in the following form: 'As a <persona>, I can <Actions> over <entities>, so that <benefit>.'
# An example of a User Story is:As an API User, I want to be able to understand if a user is a Publisher, so that I can offer functionality based on Dataset Publisher privileges.An annotated user story is a user story together with a conceptual model that makes the following concepts explicit: The persona, a set of actions, a set of entities, a set of trigger references running fromthe persona to the actions, a set of target references running fromthe action to the entities, and a set of contains references betweenentities. The sets of actions and entities are divided between themain part and the optional benefit of a user story.
# An example of an annotated User Story in a JSON format is:
#
#     {"PID": "#G05#",
#     "USID": "399",
#     "Text": "As an API User, I want to be able to get bordering regions|cities when I query a region|city, So that I can provider wider visual context for mapping visualisations.",
#     "Main Part": "As an API User, I want to be able to get bordering regions|cities when I query a region|city, So that I can provider wider visual context for mapping visualisations.",
#     "Benefit": "I can provider wider visual context for mapping visualisations",
#     "Action": {"Main Part": ["get"], "Benefit": ["query", "provider"]},
#     "Entity": {"Main Part": ["cities", "bordering regions"], "Benefit": ["region", "city,", "wider visual context", "mapping visualisations"]},
#     "Triggers": {"Main Part": [["API User", "get"]], "Benefit": []},
#     "Targets": {"Main Part": [["get", "cities"], ["get", "bordering regions"]], "Benefit": [["provider", "wider visual context"], ["query", "city,"], ["query", "region"]]},
#     "Contains": {"Main Part": [], "Benefit": [["mapping visualisations", "wider visual context"]]}
#
# Understood. You provide me with a pair of two user stories and its annotations, represented in JSON format with conceptual modeling, similar to the provided example. This User Stories will be analysed. Anything to know more?
# Please, analyse redundancies in the 'Main Part' and 'Benefit' of a pair of two given User Stories which are entered as JSON objects. Note that a User Story pair may include multiple redundancies in the 'Main Part' as well as the 'Benefit'. The redundancies of the 'Main Part' and 'Benefit' are disjoint sets. Hence, a 'Main Part' can be redundant while a 'Benefit' is not and vice versa. However, in some cases the 'Main Part' and the 'Benefit' can be at the same time redundant, but they do not depend on each other and therefore they are independent redundant. Focus on this aspects in the 'Main Part': The 'Main Part' of the user Story describes the core action that a persona wishes to accomplish. It is the value of the key called 'Main Part'. The definition of a benefit is as follows: The benefit of the User Story is contained the value of the key 'Benefit'. References within the user Stories are contained as values of 'Triggers', 'Targets' and 'Contains'.
# I will analyse redundancies in the 'Main Part' and 'Benefit' of two User Stories. Each story might include multiple redundancies. The main part typically describes the desired functionality by the persona, while the 'Benefit' details the positive outcomes from the functionality. What is your definition of redundancies in a pair of User Stories?
# We distinguish between full and partial 'Main Part' redundancies and full and partial 'Benefits' redundancies. Thus, a 'Main Part' can be either full and partial redundant, which is also valid for the 'Benefits'1.) A partial main part redundancy occurs if one value of 'Targets'.'Main Part' of the first User Story also occur in the second User Story.
# 2.) A full main part redundancy occurs if the values of 'Targets'.'Main Part', 'Triggers'.'Main Part' and 'Contains'.'Main Part' of the first User Story also occur in the second User story and vice versa.
# 3.) A partial benefit redundancy occurs if one value of of 'Targets'.'Benefit' of the first User Story also occur in the second User Story.
# 4.) A full benefit redundancy occurs if the values of 'Triggers'.'Benefit' and 'Targets'.'Benefit' and 'Contains'.'Benefit' also occur in the second User Story and vice versa.
# I'll review the User Stories for redundancies given by your definition. What shall the JSON output format look like?
# The following  JSON output format which organizes information about redundancies of a pair of User Stories, focusing on both the 'Main Part's and the 'Benefit's regarding full and partial redundancies:
# 1.) The field 'relatedStories' is an array of exactly two integer values. These values are the user story IDs (usids) of the User Stories, and this field is mandatory.
# 2.) The 'mainPartRedundancies' field is a JSON object that provides detailed information about redundancies in the main parts of the User Stories pair. Conditions and Dependencies: If both 'partialRedundancy' and 'fullRedundancy' are false, then the arrays 'pairsOfTriggersRedundancies', 'pairsOfTargetsRedundancies', and 'pairsOfContainsRedundancies' must all have a maximum of 0 items. If 'partialRedundancy' is true, 'fullRedundancy' must be false, and vice versa. If 'fullRedundancy' is true, then all references between 'Targets'.'Main Part', 'Triggers'.'Main Part' and 'Contains'.'Main Part' of the first User Story also occur in the second User story and vice versa.If 'partialRedundancy' is true, then one value of 'Targets'.'Main Part' of the first User Story also occur in the second User Story
# It is mandatory and contains the following fields:
# 	2.1) The 'partialRedundancy' field is of the type boolean. A value of true indicates that a pair of User Stories has a partial redundancy in the main part, while a value of false indicates no partial redundancy. This field can only be true when the main part is not fully redundant. It is a mandatory field.
# 	2.2) The 'fullRedundancy' field is of the type boolean. A value of true indicates that a pair of User Stories has full redundancy in the main part, while a value of false indicates no full redundancy. It is a mandatory field.
# 	2.3) The 'pairsOfTriggersRedundancies' field is an array of objects, each containing:
# 		2.3.1) A 'descriptionOfTriggerPairRedundancies' field. This is a string that provides a description explaining the reason for the trigger redundancies. It must have a minimum length of 1 character.
# 		2.3.2) A 'firstUserStoryTriggerPair' field. This is an array of exactly two string values representing the redundant trigger reference of the first user story.
# 		2.3.3) A 'secondUserStoryTriggerPair' field. This is an array of exactly two string values representing the redundant trigger reference of the second user story.
# 		2.3.4) Each object in this array must contain the fields 'descriptionOfTriggerPairRedundancies', 'firstUserStoryTriggerPair', and 'secondUserStoryTriggerPair'. The array must contain unique items and can have zero or multiple elements.
# 	2.4) The 'pairsOfTargetsRedundancies' field is an array of objects, each containing:
# 		2.4.1) A 'descriptionOfTargetPairRedundancies' field. This is a string that provides a description explaining the reason for the target redundancies. It must have a minimum length of 1 character.
# 		2.4.2) A 'firstUserStoryTargetPair' field. This is an array of exactly two string values representing the redundant target reference of the first user story.
# 		2.4.3) A 'secondUserStoryTargetPair' field. This is an array of exactly two string values representing the redundant target reference of the second user story.
# 		2.4.4) Each object in this array must contain the fields 'descriptionOfTriggerPairRedundancies', 'firstUserStoryTriggerPair', and 'secondUserStoryTriggerPair'. The array must contain unique items and can have zero or multiple elements.
# 	2.5) The 'pairsOfTriggersRedundancies' field is an array of objects, each containing:
# 		2.5.1) A 'descriptionOfContainPairsRedundancies' field.
# 		2.5.2) A 'firstUserStoryContainPair' field. This is an array of exactly two string values representing the redundant contain reference of the first user story.
# 		2.5.3) A 'secondUserStoryContainPair' field. This is an array of exactly two string values representing the redundant contain reference of the second user story.
# 		2.5.4) Each object in this array must contain the fields 'descriptionOfTriggerPairRedundancies', 'firstUserStoryTriggerPair', and 'secondUserStoryTriggerPair'. The array must contain unique items and can have zero or multiple elements.
# 3.) The 'mainPartRedundancies' field is a JSON object that provides detailed information about redundancies in the main parts of the User Stories pair. Conditions and Dependencies: If both 'partialRedundancy' and 'fullRedundancy' are false, then the arrays 'pairsOfTriggersRedundancies', 'pairsOfTargetsRedundancies', and 'pairsOfContainsRedundancies' must all have a maximum of 0 items. If 'partialRedundancy' is true, 'fullRedundancy' must be false, and vice versa. If 'fullRedundancy' is true, then one value of of 'Targets'.'Benefit' of the first User Story also occur in the second User Story.
# If 'partialRedundancy' is true, then the values of 'Triggers'.'Benefit' and 'Targets'.'Benefit' and 'Contains'.'Benefit' also occur in the second User Story and vice versa.
# It is mandatory and contains the following fields:
# 	3.1) The 'partialRedundancy' field is of the type boolean. A value of true indicates that a pair of User Stories has a partial redundancy in the main part, while a value of false indicates no partial redundancy. This field can only be true when the main part is not fully redundant. It is a mandatory field.
# 	3.2) The 'fullRedundancy' field is of the type boolean. A value of true indicates that a pair of User Stories has full redundancy in the main part, while a value of false indicates no full redundancy. It is a mandatory field.
# 	3.3) The 'pairsOfTriggersRedundancies' field is an array of objects, each containing:
# 		3.3.1) A 'descriptionOfTriggerPairRedundancies' field. This is a string that provides a description explaining the reason for the trigger redundancies. It must have a minimum length of 1 character.
# 		3.3.2) A 'firstUserStoryTriggerPair' field. This is an array of exactly two string values representing the redundant trigger reference of the first user story.
# 		3.3.3) A 'secondUserStoryTriggerPair' field. This is an array of exactly two string values representing the redundant trigger reference of the second user story.
# 		3.3.4) Each object in this array must contain the fields 'descriptionOfTriggerPairRedundancies', 'firstUserStoryTriggerPair', and 'secondUserStoryTriggerPair'. The array must contain unique items and can have zero or multiple elements.
# 	2.4) The 'pairsOfTargetsRedundancies' field is an array of objects, each containing:
# 		3.4.1) A 'descriptionOfTargetPairRedundancies' field. This is a string that provides a description explaining the reason for the target redundancies. It must have a minimum length of 1 character.
# 		3.4.2) A 'firstUserStoryTargetPair' field. This is an array of exactly two string values representing the redundant target reference of the first user story.
# 		3.4.3) A 'secondUserStoryTargetPair' field. This is an array of exactly two string values representing the redundant target reference of the second user story.
# 		3.4.4) Each object in this array must contain the fields 'descriptionOfTriggerPairRedundancies', 'firstUserStoryTriggerPair', and 'secondUserStoryTriggerPair'. The array must contain unique items and can have zero or multiple elements.
# 	2.5) The 'pairsOfTriggersRedundancies' field is an array of objects, each containing:
# 		3.5.1) A 'descriptionOfContainPairsRedundancies' field.
# 		3.5.2) A 'firstUserStoryContainPair' field. This is an array of exactly two string values representing the redundant contain reference of the first user story.
# 		3.5.3) A 'secondUserStoryContainPair' field. This is an array of exactly two string values representing the redundant contain reference of the second user story.
# 		3.5.4) Each object in this array must contain the fields 'descriptionOfTriggerPairRedundancies', 'firstUserStoryTriggerPair', and 'secondUserStoryTriggerPair'. The array must contain unique items and can have zero or multiple elements.
#
# I've noted the JSON output format specified and will deliver a valid output. Can you provide some examples?
# Yes, here are some examples:
# Example 1.):
# The input json is {"PID": "#G12#", "USID": "615", "Text": "As a camp administrator, I want to be able to schedule activities for campers, so that camp workers can easily keep track of who is where at all times.", "Main Part": "As a camp administrator, I want to be able to schedule activities for campers", "Benefit": "camp workers can easily keep track of who is where at all times", "Triggers": {"Main Part": [["camp administrator", "schedule"]], "Benefit": []}, "Targets": {"Main Part": [["schedule", "activities"]], "Benefit": [["easily keep track", "campers"]]}, "Contains": {"Main Part": [], "Benefit": []}} and {"PID": "#G12#", "USID": "636", "Text": "As a camp administrator, I want to be able to schedule tasks/activities for a specific camp group, so that I can track each groups daily/weekly and monthly activities.", "Main Part": "As a camp administrator, I want to be able to schedule tasks/activities for a specific camp group", "Benefit": "I can track each groups daily/weekly and monthly activities", "Triggers": {"Main Part": [["camp administrator", "schedule"]], "Benefit": []}, "Targets": {"Main Part": [["schedule", "tasks"], ["schedule", "activities"]], "Benefit": [["track", "each groups daily/weekly and monthly activities"]]}, "Contains": {"Main Part": [["specific camp group", "activities"], ["specific camp group", "tasks"]], "Benefit": []}}
# The expected output is: {"relatedStories": [615, 636], "mainPartRedundancies": {"partialRedundancy": true, "fullRedundancy": false, "pairsOfTriggersRedundancies": [{"descriptionOfTriggersRedundancies": "In both stories, the camp administrator wants to schedule something.", "firstUserStoryTriggerPair": ["camp administrator", "schedule"], "secondUserStoryTriggerPair": ["camp administrator", "schedule"]}], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, the camp adiministrator wants to schedule activities.", "firstUserStoryTargetPair": ["schedule", "activities"], "secondUserStoryTargetPair": ["schedule", "activities"]}], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": false, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [], "pairsOfContainsRedundancies": []}}
# Example 2.):
# The input json is {"PID": "#G12#", "USID": "640", "Text": "As a camp administrator, I want to be able to delete campers from the database, so that I can keep my pages free of clutter.", "Main Part": "As a camp administrator, I want to be able to delete campers from the database", "Benefit": "I can keep my pages free of clutter", "Triggers": {"Main Part": [["camp administrator", "delete"]], "Benefit": []}, "Targets": {"Main Part": [["delete", "campers"]], "Benefit": [["keep", "pages"]]}, "Contains": {"Main Part": [["database", "campers"]], "Benefit": [["pages", "free of clutter"]]}} and {"PID": "#G12#", "USID": "642", "Text": "As a camp administrator, I want to be able to delete parents from the database, so that I can keep my pages free of unneeded clutter.", "Main Part": "As a camp administrator, I want to be able to delete parents from the database", "Benefit": "I can keep my pages free of unneeded clutter", "Triggers": {"Main Part": [["camp administrator", "delete"]], "Benefit": []}, "Targets": {"Main Part": [["delete", "parents"]], "Benefit": [["keep", "pages"]]}, "Contains": {"Main Part": [["database", "parents"]], "Benefit": [["pages", "free of unneeded clutter"]]}}
# The expected output is: {"relatedStories": [640, 642], "mainPartRedundancies": {"partialRedundancy": false, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": true, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, pages should kept in some way.", "firstUserStoryTargetPair": ["keep", "pages"], "secondUserStoryTargetPair": ["keep", "pages"]}], "pairsOfContainsRedundancies": []}}
# Example 3.):
# The input json is {"PID": "#G12#", "USID": "646", "Text": "As a parent, I want to be able to track my child's activity and schedule at camp, so that I can have peace of mind.", "Main Part": "As a parent, I want to be able to track my child's activity and schedule at camp", "Benefit": "I can have peace of mind", "Triggers": {"Main Part": [["parent", "track"]], "Benefit": []}, "Targets": {"Main Part": [["track", "child's activity"], ["track", "schedule"]], "Benefit": [["have", "peace of mind"]]}, "Contains": {"Main Part": [], "Benefit": []}} and {"PID": "#G12#", "USID": "649", "Text": "As a parent, I want to see which counselors are assigned to my kids, so that I can have peace of mind.", "Main Part": "As a parent, I want to see which counselors are assigned to my kids", "Benefit": "I can have peace of mind", "Triggers": {"Main Part": [["parent", "see"]], "Benefit": []}, "Targets": {"Main Part": [["see", "counselors"]], "Benefit": [["have", "peace of mind"]]}, "Contains": {"Main Part": [["counselors", "kids"]], "Benefit": []}}
# The expected output is: {"relatedStories": [646, 649], "mainPartRedundancies": {"partialRedundancy": false, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": false, "fullRedundancy": true, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, someone wants to have a peace of mind.", "firstUserStoryTargetPair": ["have", "peace of mind"], "secondUserStoryTargetPair": ["have", "peace of mind"]}], "pairsOfContainsRedundancies": []}}
# Example 4.):
# The input json is {"PID": "#G05#", "USID": "397", "Text": "As an API User, I want to be able to understand if a user is a Publisher, so that I can offer functionality based on Dataset Publisher privileges.", "Main Part": "As an API User, I want to be able to understand if a user is a Publisher", "Benefit": "I can offer functionality based on Dataset Publisher privileges", "Triggers": {"Main Part": [["API User", "understand"]], "Benefit": []}, "Targets": {"Main Part": [["understand", "user"]], "Benefit": [["offer", "functionality"]]}, "Contains": {"Main Part": [], "Benefit": []}} and {"PID": "#G05#", "USID": "398", "Text": "As an API User, I want to be able to understand if a user is an Administrator So that I can offer functionality based on Platform Administration privileges.", "Main Part": "As an API User, I want to be able to understand if a user is an Administrator", "Benefit": "I can offer functionality based on Platform Administration privileges", "Triggers": {"Main Part": [["API User", "understand"]], "Benefit": []}, "Targets": {"Main Part": [["understand", "user"]], "Benefit": [["offer", "functionality"]]}, "Contains": {"Main Part": [], "Benefit": []}}
# The expected output is: {"relatedStories": [397, 398], "mainPartRedundancies": {"partialRedundancy": false, "fullRedundancy": true, "pairsOfTriggersRedundancies": [{"descriptionOfTriggersRedundancies": "In both stories, the API User wants to understand something.", "firstUserStoryTriggerPair": ["API User", "understand"], "secondUserStoryTriggerPair": ["API User", "understand"]}], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, someone wants to understand the user.", "firstUserStoryTargetPair": ["understand", "user"], "secondUserStoryTargetPair": ["understand", "user"]}], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": false, "fullRedundancy": true, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, functionality wants to be offered.", "firstUserStoryTargetPair": ["offer", "functionality"], "secondUserStoryTargetPair": ["offer", "functionality"]}], "pairsOfContainsRedundancies": []}}
# Example 5.):
# The input json is {"PID": "#G05#", "USID": "377", "Text": "As a Platform Administrator, I want to have a view on all datasets published by all users, So that I can perform management actions on any dataset.", "Main Part": "As a Platform Administrator, I want to have a view on all datasets published by all users", "Benefit": "I can perform management actions on any dataset", "Triggers": {"Main Part": [["Platform Administrator", "have"]], "Benefit": []}, "Targets": {"Main Part": [["have", "view"]], "Benefit": [["perform", "management actions"]]}, "Contains": {"Main Part": [["view", "datasets published"]], "Benefit": [["any dataset", "management actions"]]}} and {"PID": "#G05#", "USID": "417", "Text": "As a Data Publishing User, I want to have a view on all the datasets I have published, So that I can perform management actions on my own datasets.", "Main Part": "As a Data Publishing User, I want to have a view on all the datasets I have published", "Benefit": "I can perform management actions on my own datasets", "Triggers": {"Main Part": [["Data Publishing User", "have"]], "Benefit": []}, "Targets": {"Main Part": [["have", "view"]], "Benefit": [["perform", "management actions"]]}, "Contains": {"Main Part": [["datasets I have published", "view"]], "Benefit": [["own datasets", "management actions"]]}}
# The expected output is: {"relatedStories": [377, 417], "mainPartRedundancies": {"partialRedundancy": true, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, someone wahts to have a view of something.", "firstUserStoryTargetPair": ["have", "view"], "secondUserStoryTargetPair": ["have", "view"]}], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": true, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, someone wants to perform management actions.", "firstUserStoryTargetPair": ["perform", "management actions"], "secondUserStoryTargetPair": ["perform", "management actions"]}], "pairsOfContainsRedundancies": []}}
# Example 6.):
# The input json is {"PID": "#G05#", "USID": "408", "Text": "As an API User, I want to be able to normalise measures by GDP, so I work with datasets in reference to their contextual constraints.", "Main Part": "As an API User, I want to be able to normalise measures by GDP, so ", "Benefit": "I work with datasets in reference to their contextual constraints", "Triggers": {"Main Part": [["API User", "normalise"]], "Benefit": []}, "Targets": {"Main Part": [["normalise", "measures"]], "Benefit": [["work", "datasets"]]}, "Contains": {"Main Part": [["measures", "GDP"]], "Benefit": [["datasets", "contextual constraints"]]}} and {"PID": "#G05#", "USID": "409", "Text": "As an API User, I want to be able to normalise measures by GINI and related socioeconomic indexes, So that I work with datasets in reference to their contextual constraints.", "Main Part": "As an API User, I want to be able to normalise measures by GINI and related socioeconomic indexes", "Benefit": "I work with datasets in reference to their contextual constraints", "Triggers": {"Main Part": [["API User", "normalise"]], "Benefit": []}, "Targets": {"Main Part": [["normalise", "measures"]], "Benefit": [["work", "datasets"]]}, "Contains": {"Main Part": [["GINI", "measures"], ["related socioeconomic indexes", "measures"]], "Benefit": [["datasets", "contextual constraints"]]}}
# The expected output is: {"relatedStories": [408, 409], "mainPartRedundancies": {"partialRedundancy": true, "fullRedundancy": false, "pairsOfTriggersRedundancies": [{"descriptionOfTriggersRedundancies": "In both stories, the API User is able to normalise something.", "firstUserStoryTriggerPair": ["API User", "normalise"], "secondUserStoryTriggerPair": ["API User", "normalise"]}], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, the API User wants to normalise measures.", "firstUserStoryTargetPair": ["normalise", "measures"], "secondUserStoryTargetPair": ["normalise", "measures"]}], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": false, "fullRedundancy": true, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [{"descriptionOfTargetPairRedundancies": "In both stories, the API User wants to work with datasets", "firstUserStoryTargetPair": ["work", "datasets"], "secondUserStoryTargetPair": ["work", "datasets"]}], "pairsOfContainsRedundancies": [{"descriptionOfContainsRedundancies": "In both stories, the user wants to work with datasets in reference with their contextual constraints.", "firstUserStoryContainPair": ["datasets", "contextual constraints"], "secondUserStoryContainPair": ["datasets", "contextual constraints"]}]}}
# Example 7.):
# The input json is {"PID": "#G05#", "USID": "373", "Text": "As a Data Publishing User, I want to be able to edit a dataset I have published, So that I can correct or enhance existing data.", "Main Part": "As a Data Publishing User, I want to be able to edit a dataset I have published", "Benefit": "I can correct or enhance existing data", "Triggers": {"Main Part": [["Data Publishing User", "edit"]], "Benefit": []}, "Targets": {"Main Part": [["edit", "dataset I have published"]], "Benefit": [["correct", "existing data"], ["enhance", "existing data"]]}, "Contains": {"Main Part": [], "Benefit": []}} and {"PID": "#G05#", "USID": "374", "Text": "As a Data Publishing User, I want to be able to edit the model of data I have already imported, So that I can fix bugs or make enhancements in the API built for my data.", "Main Part": "As a Data Publishing User, I want to be able to edit the model of data I have already imported", "Benefit": "I can fix bugs or make enhancements in the API built for my data", "Triggers": {"Main Part": [["Data Publishing User", "edit"]], "Benefit": []}, "Targets": {"Main Part": [["edit", "model"]], "Benefit": [["fix", "bugs"], ["make", "enhancements"]]}, "Contains": {"Main Part": [["data I have already imported", "model"]], "Benefit": [["API", "enhancements"], ["data", "API"]]}}
# The expected output is: {"relatedStories": [373, 374], "mainPartRedundancies": {"partialRedundancy": false, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [], "pairsOfContainsRedundancies": []}, "benefitRedundancies": {"partialRedundancy": false, "fullRedundancy": false, "pairsOfTriggersRedundancies": [], "pairsOfTargetsRedundancies": [], "pairsOfContainsRedundancies": []}}
#
# Got it. The examples provided align with the definitions and JSON format description for identifying redundancies in user stories. Ready to proceed?
# ---Token---
# [2471, 439, 264, 34884, 29483, 10968, 389, 25607, 37673, 32737, 13, 5321, 3477, 13840, 315, 1403, 2724, 30129, 323, 67638, 904, 26225, 27444, 811, 430, 40634, 32373, 477, 923, 912, 12742, 907, 20855, 264, 8670, 24490, 304, 62565, 4500, 11, 433, 374, 856, 12014, 311, 3477, 1217, 7493, 369, 37673, 32737, 13, 3092, 5915, 374, 311, 10765, 323, 1934, 904, 50917, 477, 23329, 8670, 13, 3296, 15884, 22209, 287, 279, 1217, 7493, 304, 8149, 11, 358, 6106, 430, 1855, 16686, 374, 5995, 323, 44072, 42329, 11, 7859, 279, 78925, 315, 279, 2027, 885, 1217, 3446, 374, 264, 18768, 12, 52243, 11914, 8649, 279, 2768, 2038, 512, 7, 16, 8, 279, 29055, 6532, 304, 279, 3446, 345, 7, 17, 8, 279, 1925, 961, 8649, 279, 6299, 430, 279, 29055, 690, 2804, 389, 279, 1887, 323, 279, 15086, 6532, 304, 279, 6299, 11, 323, 46624, 198, 7, 18, 8, 264, 8935, 430, 279, 29055, 690, 5371, 1306, 3515, 8308, 1521, 6299, 13, 578, 8935, 1253, 1101, 2997, 6299, 323, 15086, 627, 1999, 2740, 11, 264, 1217, 3446, 374, 13605, 304, 279, 2768, 1376, 25, 364, 2170, 264, 366, 71694, 8226, 358, 649, 366, 13245, 29, 927, 366, 10720, 8226, 779, 430, 366, 68244, 275, 14611, 1270, 2127, 3187, 315, 264, 2724, 15457, 374, 25, 2170, 459, 5446, 2724, 11, 358, 1390, 311, 387, 3025, 311, 3619, 422, 264, 1217, 374, 264, 40233, 11, 779, 430, 358, 649, 3085, 15293, 3196, 389, 40283, 40233, 36832, 8794, 63951, 1217, 3446, 374, 264, 1217, 3446, 3871, 449, 264, 44901, 1646, 430, 3727, 279, 2768, 19476, 11720, 25, 578, 29055, 11, 264, 743, 315, 6299, 11, 264, 743, 315, 15086, 11, 264, 743, 315, 8346, 15407, 4401, 505, 1820, 29055, 311, 279, 6299, 11, 264, 743, 315, 2218, 15407, 4401, 505, 1820, 1957, 311, 279, 15086, 11, 323, 264, 743, 315, 5727, 15407, 1990, 10720, 13, 578, 7437, 315, 6299, 323, 15086, 527, 18255, 1990, 1124, 467, 961, 323, 279, 10309, 8935, 315, 264, 1217, 3446, 627, 2127, 3187, 315, 459, 63951, 2724, 15457, 304, 264, 4823, 3645, 374, 1473, 262, 5324, 34851, 794, 5993, 38, 2304, 2, 761, 262, 330, 2078, 926, 794, 330, 18572, 761, 262, 330, 1199, 794, 330, 2170, 459, 5446, 2724, 11, 358, 1390, 311, 387, 3025, 311, 636, 3973, 287, 13918, 91, 54109, 994, 358, 3319, 264, 5654, 91, 9103, 11, 2100, 430, 358, 649, 9287, 22622, 9302, 2317, 369, 13021, 9302, 56276, 10560, 262, 330, 6334, 3744, 794, 330, 2170, 459, 5446, 2724, 11, 358, 1390, 311, 387, 3025, 311, 636, 3973, 287, 13918, 91, 54109, 994, 358, 3319, 264, 5654, 91, 9103, 11, 2100, 430, 358, 649, 9287, 22622, 9302, 2317, 369, 13021, 9302, 56276, 10560, 262, 330, 60076, 275, 794, 330, 40, 649, 9287, 22622, 9302, 2317, 369, 13021, 9302, 56276, 761, 262, 330, 2573, 794, 5324, 6334, 3744, 794, 4482, 456, 8073, 330, 60076, 275, 794, 4482, 1663, 498, 330, 20576, 1365, 1613, 262, 330, 3106, 794, 5324, 6334, 3744, 794, 4482, 54109, 498, 330, 9649, 287, 13918, 8073, 330, 60076, 275, 794, 4482, 4030, 498, 330, 9103, 59055, 330, 86, 1814, 9302, 2317, 498, 330, 41892, 9302, 56276, 1365, 1613, 262, 330, 1305, 22099, 794, 5324, 6334, 3744, 794, 79786, 7227, 2724, 498, 330, 456, 1365, 1145, 330, 60076, 275, 794, 3132, 1613, 262, 330, 50130, 794, 5324, 6334, 3744, 794, 79786, 456, 498, 330, 54109, 8073, 4482, 456, 498, 330, 9649, 287, 13918, 1365, 1145, 330, 60076, 275, 794, 79786, 20576, 498, 330, 86, 1814, 9302, 2317, 8073, 4482, 1663, 498, 330, 9103, 1359, 1145, 4482, 1663, 498, 330, 4030, 1365, 58452, 262, 330, 24741, 794, 5324, 6334, 3744, 794, 10277, 330, 60076, 275, 794, 79786, 41892, 9302, 56276, 498, 330, 86, 1814, 9302, 2317, 1365, 24333, 262, 9636, 52784, 13, 1472, 3493, 757, 449, 264, 6857, 315, 1403, 1217, 7493, 323, 1202, 33307, 11, 15609, 304, 4823, 3645, 449, 44901, 34579, 11, 4528, 311, 279, 3984, 3187, 13, 1115, 2724, 30129, 690, 387, 67458, 13, 42033, 311, 1440, 810, 30, 5618, 11, 49586, 37673, 32737, 304, 279, 364, 6334, 3744, 6, 323, 364, 60076, 275, 6, 315, 264, 6857, 315, 1403, 2728, 2724, 30129, 902, 527, 10862, 439, 4823, 6302, 13, 7181, 430, 264, 2724, 15457, 6857, 1253, 2997, 5361, 37673, 32737, 304, 279, 364, 6334, 37 ...
# ---Sum of Tokens---
# The total token sum is: 60.476.544

# %% [markdown]
# ## Example generation for the paper - the listed US are not contained in the trainings data (manuel removed before this analyse from the input_examples.josn and output_examples.json)

# %%
ID_G05: str = "g05"
data_g05: list = datasets[ID_G05]
df_g05: pd.DataFrame = transform_2_dataframe(data_g05)
df_g05_pairs = transform_pairwise(df_g05)

target_usids = [[408, 409]]

def is_in_target_usids(usid_one: int, usid_two: int):
    for element in target_usids:
        if (usid_one == element[0] and usid_two == element[1]):
            return True
    return False

# Apply the function to each row
df_g05_pairs_adjusted = df_g05_pairs[
    df_g05_pairs.apply(lambda row: is_in_target_usids(int(row['First USID']), int(row['Second USID'])), axis=1)
]

df_g05_pairs_adjusted

# %%
# process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g05_pairs_adjusted, key=ID_G05, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G03

# %%
ID_G03: str = "g03"
data_g03: list = datasets[ID_G03]
df_g03: pd.DataFrame = transform_2_dataframe(data_g03)
df_g03_pairs = transform_pairwise(df_g03)

# %%
datasets[ID_G03][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g03.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4      As an Applicant, I want to Submit Application
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g03_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3      As an Applicant, I want to Submit Application
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G03] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g03_pairs, key=ID_G03, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g03_pairs, key=ID_G03, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G04

# %%
ID_G04: str = "g04"
data_g04: list = datasets[ID_G04]
df_g04: pd.DataFrame = transform_2_dataframe(data_g04)
df_g04_pairs = transform_pairwise(df_g04)

# %%
datasets[ID_G04][0]
# Out:
# {'PID': '#G04#',
#  'USID': '164',
#  'Text': 'As a user, I want to click on the address, so that it takes me to a new tab with Google Maps.',
#  'Main Part': 'As a user, I want to click on the address',
#  'Benefit': 'it takes me to a new tab with Google Maps',
#  'Triggers': {'Main Part': [['user', 'click']], 'Benefit': []},
#  'Targets': {'Main Part': [['click', 'address']], 'Benefit': []},
#  'Contains': {'Main Part': [], 'Benefit': [['new tab', 'Google Maps']]}}

# %%
display(df_g04.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G04#  164  As a user, I want to click on the address, so ...
# 1  #G04#  165  As a user, I want to be able to anonymously vi...
# 2  #G04#  166  As a user, I want to be able to enter my zip c...
# 3  #G04#  167  As a user, I want to be able to get the hours ...
# 4  #G04#  168  As a user, I want to have a flexible pick up t...
#
#                                            Main Part  \
# 0          As a user, I want to click on the address
# 1  As a user, I want to be able to anonymously vi...
# 2  As a user, I want to be able to enter my zip c...
# 3  As a user, I want to be able to get the hours ...
# 4  As a user, I want to have a flexible pick up time
#
#                                              Benefit  \
# 0          it takes me to a new tab with Google Maps
# 1  I know about recycling centers near me before ...
# 2       I can determine which ones I should consider
# 3  I can arrange drop-offs on my off days or duri...
# 4            I can more conveniently use the website
#
#                                             Triggers  \
# 0  {'Main Part': [['user', 'click']], 'Benefit': []}
# 1  {'Main Part': [['user', 'anonymously view']], ...
# 2  {'Main Part': [['user', 'enter'], ['user', 'ge...
# 3    {'Main Part': [['user', 'get']], 'Benefit': []}
# 4   {'Main Part': [['user', 'have']], 'Benefit': []}
#
#                                              Targets  \
# 0  {'Main Part': [['click', 'address']], 'Benefit...
# 1  {'Main Part': [['anonymously view', 'public in...
# 2  {'Main Part': [['enter', 'zip code'], ['get', ...
# 3  {'Main Part': [['get', 'hours']], 'Benefit': [...
# 4  {'Main Part': [['have', 'flexible pick up time...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['new tab', 'Goo...
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [['list', 'nearby recycling faci...
# 3  {'Main Part': [['each recycling facility', 'ho...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g04_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G04#        164  As a user, I want to click on the address, so ...
# 1     #G04#        164  As a user, I want to click on the address, so ...
# 2     #G04#        164  As a user, I want to click on the address, so ...
# 3     #G04#        164  As a user, I want to click on the address, so ...
# 4     #G04#        164  As a user, I want to click on the address, so ...
#
#                              First Main Part  \
# 0  As a user, I want to click on the address
# 1  As a user, I want to click on the address
# 2  As a user, I want to click on the address
# 3  As a user, I want to click on the address
# 4  As a user, I want to click on the address
#
#                                First Benefit  \
# 0  it takes me to a new tab with Google Maps
# 1  it takes me to a new tab with Google Maps
# 2  it takes me to a new tab with Google Maps
# 3  it takes me to a new tab with Google Maps
# 4  it takes me to a new tab with Google Maps
#
#                                       First Triggers  \
# 0  {'Main Part': [['user', 'click']], 'Benefit': []}
# 1  {'Main Part': [['user', 'click']], 'Benefit': []}
# 2  {'Main Part': [['user', 'click']], 'Benefit': []}
# 3  {'Main Part': [['user', 'click']], 'Benefit': []}
# 4  {'Main Part': [['user', 'click']], 'Benefit': []}
#
#                                        First Targets  \
# 0  {'Main Part': [['click', 'address']], 'Benefit...
# 1  {'Main Part': [['click', 'address']], 'Benefit...
# 2  {'Main Part': [['click', 'address']], 'Benefit...
# 3  {'Main Part': [['click', 'address']], 'Benefit...
# 4  {'Main Part': [['click', 'address']], 'Benefit...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['new tab', 'Goo...      #G04#         165
# 1  {'Main Part': [], 'Benefit': [['new tab', 'Goo...      #G04#         166
# 2  {'Main Part': [], 'Benefit': [['new tab', 'Goo...      #G04#         167
# 3  {'Main Part': [], 'Benefit': [['new tab', 'Goo...      #G04#         168
# 4  {'Main Part': [], 'Benefit': [['new tab', 'Goo...      #G04#         169
#
#                                          Second Text  \
# 0  As a user, I want to be able to anonymously vi...
# 1  As a user, I want to be able to enter my zip c...
# 2  As a user, I want to be able to get the hours ...
# 3  As a user, I want to have a flexible pick up t...
# 4  As a user, I want to be able to select differe...
#
#                                     Second Main Part  \
# 0  As a user, I want to be able to anonymously vi...
# 1  As a user, I want to be able to enter my zip c...
# 2  As a user, I want to be able to get the hours ...
# 3  As a user, I want to have a flexible pick up time
# 4  As a user, I want to be able to select differe...
#
#                                       Second Benefit  \
# 0  I know about recycling centers near me before ...
# 1       I can determine which ones I should consider
# 2  I can arrange drop-offs on my off days or duri...
# 3            I can more conveniently use the website
# 4  I have and get a list of facilities that accep...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['user', 'anonymously view']], ...
# 1  {'Main Part': [['user', 'enter'], ['user', 'ge...
# 2    {'Main Part': [['user', 'get']], 'Benefit': []}
# 3   {'Main Part': [['user', 'have']], 'Benefit': []}
# 4  {'Main Part': [['user', 'select']], 'Benefit':...
#
#                                       Second Targets  \
# 0  {'Main Part': [['anonymously view', 'public in...
# 1  {'Main Part': [['enter', 'zip code'], ['get', ...
# 2  {'Main Part': [['get', 'hours']], 'Benefit': [...
# 3  {'Main Part': [['have', 'flexible pick up time...
# 4  {'Main Part': [['select', 'different types of ...
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [['list', 'nearby recycling faci...
# 2  {'Main Part': [['each recycling facility', 'ho...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['list', 'facili...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G04] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g04_pairs, key=ID_G04, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g04_pairs, key=ID_G04, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G08

# %%
ID_G08: str = "g08"
data_g08: list = datasets[ID_G08]
df_g08: pd.DataFrame = transform_2_dataframe(data_g08)
df_g08_pairs = transform_pairwise(df_g08)

# %%
datasets[ID_G08][0]
# Out:
# {'PID': '#G08#',
#  'USID': '426',
#  'Text': 'As a Developer, I want to get a Data Package into Node, so that I can start using the data for doing analysis and visualizations.',
#  'Main Part': 'As a Developer, I want to get a Data Package into Node',
#  'Benefit': 'I can start using the data for doing analysis and visualizations',
#  'Triggers': {'Main Part': [['Developer', 'get']], 'Benefit': []},
#  'Targets': {'Main Part': [['get', 'Data Package']],
#   'Benefit': [['doing', 'analysis'],
#    ['doing', 'visualizations'],
#    ['start using', 'data']]},
#  'Contains': {'Main Part': [['Node', 'Data Package']], 'Benefit': []}}

# %%
display(df_g08.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G08#  426  As a Developer, I want to get a Data Package i...
# 1  #G08#  427  As a Researcher, I want to get a Data Package ...
# 2  #G08#  428  As a Publisher, I want to add type information...
# 3  #G08#  429  As a Publisher, I want to be able to provide a...
# 4  #G08#  430  As a Researcher, I want to be able to save new...
#
#                                            Main Part  \
# 0  As a Developer, I want to get a Data Package i...
# 1  As a Researcher, I want to get a Data Package ...
# 2  As a Publisher, I want to add type information...
# 3  As a Publisher, I want to be able to provide a...
# 4  As a Researcher, I want to be able to save new...
#
#                                              Benefit  \
# 0  I can start using the data for doing analysis ...
# 1  I can start using the data for doing analysis ...
# 2  it is more useful to others and can be used be...
# 3  I can provide my analysis and show my work to ...
# 4  I can share them with others or include them i...
#
#                                             Triggers  \
# 0  {'Main Part': [['Developer', 'get']], 'Benefit...
# 1  {'Main Part': [['Researcher', 'get']], 'Benefi...
# 2  {'Main Part': [['Publisher', 'add']], 'Benefit...
# 3  {'Main Part': [['Publisher', 'provide']], 'Ben...
# 4  {'Main Part': [['Researcher', 'save']], 'Benef...
#
#                                              Targets  \
# 0  {'Main Part': [['get', 'Data Package']], 'Bene...
# 1  {'Main Part': [['get', 'Data Package']], 'Bene...
# 2  {'Main Part': [['add', 'type information']], '...
# 3  {'Main Part': [['provide', 'visualization']], ...
# 4  {'Main Part': [['save', 'new visualizations']]...
#
#                                             Contains
# 0  {'Main Part': [['Node', 'Data Package']], 'Ben...
# 1  {'Main Part': [['Julia', 'Data Package']], 'Be...
# 2  {'Main Part': [['data', 'type information']], ...
# 3  {'Main Part': [['visualization', 'data']], 'Be...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g08_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G08#        426  As a Developer, I want to get a Data Package i...
# 1     #G08#        426  As a Developer, I want to get a Data Package i...
# 2     #G08#        426  As a Developer, I want to get a Data Package i...
# 3     #G08#        426  As a Developer, I want to get a Data Package i...
# 4     #G08#        426  As a Developer, I want to get a Data Package i...
#
#                                      First Main Part  \
# 0  As a Developer, I want to get a Data Package i...
# 1  As a Developer, I want to get a Data Package i...
# 2  As a Developer, I want to get a Data Package i...
# 3  As a Developer, I want to get a Data Package i...
# 4  As a Developer, I want to get a Data Package i...
#
#                                        First Benefit  \
# 0  I can start using the data for doing analysis ...
# 1  I can start using the data for doing analysis ...
# 2  I can start using the data for doing analysis ...
# 3  I can start using the data for doing analysis ...
# 4  I can start using the data for doing analysis ...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Developer', 'get']], 'Benefit...
# 1  {'Main Part': [['Developer', 'get']], 'Benefit...
# 2  {'Main Part': [['Developer', 'get']], 'Benefit...
# 3  {'Main Part': [['Developer', 'get']], 'Benefit...
# 4  {'Main Part': [['Developer', 'get']], 'Benefit...
#
#                                        First Targets  \
# 0  {'Main Part': [['get', 'Data Package']], 'Bene...
# 1  {'Main Part': [['get', 'Data Package']], 'Bene...
# 2  {'Main Part': [['get', 'Data Package']], 'Bene...
# 3  {'Main Part': [['get', 'Data Package']], 'Bene...
# 4  {'Main Part': [['get', 'Data Package']], 'Bene...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['Node', 'Data Package']], 'Ben...      #G08#         427
# 1  {'Main Part': [['Node', 'Data Package']], 'Ben...      #G08#         428
# 2  {'Main Part': [['Node', 'Data Package']], 'Ben...      #G08#         429
# 3  {'Main Part': [['Node', 'Data Package']], 'Ben...      #G08#         430
# 4  {'Main Part': [['Node', 'Data Package']], 'Ben...      #G08#         431
#
#                                          Second Text  \
# 0  As a Researcher, I want to get a Data Package ...
# 1  As a Publisher, I want to add type information...
# 2  As a Publisher, I want to be able to provide a...
# 3  As a Researcher, I want to be able to save new...
# 4  As a ResearcherPublisher, I want to know that ...
#
#                                     Second Main Part  \
# 0  As a Researcher, I want to get a Data Package ...
# 1  As a Publisher, I want to add type information...
# 2  As a Publisher, I want to be able to provide a...
# 3  As a Researcher, I want to be able to save new...
# 4  As a ResearcherPublisher, I want to know that ...
#
#                                       Second Benefit  \
# 0  I can start using the data for doing analysis ...
# 1  it is more useful to others and can be used be...
# 2  I can provide my analysis and show my work to ...
# 3  I can share them with others or include them i...
# 4  I can feel trust in the validity and usefulnes...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['Researcher', 'get']], 'Benefi...
# 1  {'Main Part': [['Publisher', 'add']], 'Benefit...
# 2  {'Main Part': [['Publisher', 'provide']], 'Ben...
# 3  {'Main Part': [['Researcher', 'save']], 'Benef...
# 4  {'Main Part': [['ResearcherPublisher', 'know']...
#
#                                       Second Targets  \
# 0  {'Main Part': [['get', 'Data Package']], 'Bene...
# 1  {'Main Part': [['add', 'type information']], '...
# 2  {'Main Part': [['provide', 'visualization']], ...
# 3  {'Main Part': [['save', 'new visualizations']]...
# 4  {'Main Part': [['know', 'data']], 'Benefit': [...
#
#                                      Second Contains
# 0  {'Main Part': [['Julia', 'Data Package']], 'Be...
# 1  {'Main Part': [['data', 'type information']], ...
# 2  {'Main Part': [['visualization', 'data']], 'Be...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['data.', 'usefu...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G08] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g08_pairs, key=ID_G08, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g08_pairs, key=ID_G08, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G10

# %%
ID_G10: str = "g10"
data_g10: list = datasets[ID_G10]
df_g10: pd.DataFrame = transform_2_dataframe(data_g10)
df_g10_pairs = transform_pairwise(df_g10)

# %%
datasets[ID_G10][0]
# Out:
# {'PID': '#G10#',
#  'USID': '493',
#  'Text': 'As a site member, I want to describe myself on my own page in a semi-structured way, so that others can learn about me.',
#  'Main Part': 'As a site member, I want to describe myself on my own page in a semi-structured way',
#  'Benefit': 'others can learn about me',
#  'Triggers': {'Main Part': [['site member', 'describe']], 'Benefit': []},
#  'Targets': {'Main Part': [['describe', 'myself']], 'Benefit': []},
#  'Contains': {'Main Part': [],
#   'Benefit': [['own page', 'semi-structured way']]}}

# %%
display(df_g10.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G10#  493  As a site member, I want to describe myself on...
# 1  #G10#  494  As a site member, I want to fill out an applic...
# 2  #G10#  495  As a Practitioner, I want to include additiona...
# 3  #G10#  496  As a site member, I want to fill out an applic...
# 4  #G10#  497  As a Trainer, I want to include additional det...
#
#                                            Main Part  \
# 0  As a site member, I want to describe myself on...
# 1  As a site member, I want to fill out an applic...
# 2  As a Practitioner, I want to include additiona...
# 3  As a site member, I want to fill out an applic...
# 4  As a Trainer, I want to include additional det...
#
#                                              Benefit  \
# 0                          others can learn about me
# 1                        I can earn that designation
# 2                       I can showcase my experience
# 3  I can teach CSM and CSPO courses and certify o...
# 4  others can learn about me and decide if I am t...
#
#                                             Triggers  \
# 0  {'Main Part': [['site member', 'describe']], '...
# 1  {'Main Part': [['site member', 'fill out']], '...
# 2  {'Main Part': [['Practitioner', 'include']], '...
# 3  {'Main Part': [['site member', 'fill out']], '...
# 4  {'Main Part': [['Trainer', 'include']], 'Benef...
#
#                                              Targets  \
# 0  {'Main Part': [['describe', 'myself']], 'Benef...
# 1  {'Main Part': [['fill out', 'application']], '...
# 2  {'Main Part': [['include', 'additional details...
# 3  {'Main Part': [['fill out', 'application']], '...
# 4  {'Main Part': [['include', 'additional details...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['own page', 'se...
# 1  {'Main Part': [['Certified Scrum Practitioner'...
# 2  {'Main Part': [['profile page', 'additional de...
# 3  {'Main Part': [['Certified Scrum Trainer', 'ap...
# 4  {'Main Part': [['profile page about me', 'addi...

# %%
display(df_g10_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G10#        493  As a site member, I want to describe myself on...
# 1     #G10#        493  As a site member, I want to describe myself on...
# 2     #G10#        493  As a site member, I want to describe myself on...
# 3     #G10#        493  As a site member, I want to describe myself on...
# 4     #G10#        493  As a site member, I want to describe myself on...
#
#                                      First Main Part  \
# 0  As a site member, I want to describe myself on...
# 1  As a site member, I want to describe myself on...
# 2  As a site member, I want to describe myself on...
# 3  As a site member, I want to describe myself on...
# 4  As a site member, I want to describe myself on...
#
#                First Benefit  \
# 0  others can learn about me
# 1  others can learn about me
# 2  others can learn about me
# 3  others can learn about me
# 4  others can learn about me
#
#                                       First Triggers  \
# 0  {'Main Part': [['site member', 'describe']], '...
# 1  {'Main Part': [['site member', 'describe']], '...
# 2  {'Main Part': [['site member', 'describe']], '...
# 3  {'Main Part': [['site member', 'describe']], '...
# 4  {'Main Part': [['site member', 'describe']], '...
#
#                                        First Targets  \
# 0  {'Main Part': [['describe', 'myself']], 'Benef...
# 1  {'Main Part': [['describe', 'myself']], 'Benef...
# 2  {'Main Part': [['describe', 'myself']], 'Benef...
# 3  {'Main Part': [['describe', 'myself']], 'Benef...
# 4  {'Main Part': [['describe', 'myself']], 'Benef...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['own page', 'se...      #G10#         494
# 1  {'Main Part': [], 'Benefit': [['own page', 'se...      #G10#         495
# 2  {'Main Part': [], 'Benefit': [['own page', 'se...      #G10#         496
# 3  {'Main Part': [], 'Benefit': [['own page', 'se...      #G10#         497
# 4  {'Main Part': [], 'Benefit': [['own page', 'se...      #G10#         498
#
#                                          Second Text  \
# 0  As a site member, I want to fill out an applic...
# 1  As a Practitioner, I want to include additiona...
# 2  As a site member, I want to fill out an applic...
# 3  As a Trainer, I want to include additional det...
# 4  As a Practitioner, I want to write an article ...
#
#                                     Second Main Part  \
# 0  As a site member, I want to fill out an applic...
# 1  As a Practitioner, I want to include additiona...
# 2  As a site member, I want to fill out an applic...
# 3  As a Trainer, I want to include additional det...
# 4  As a Practitioner, I want to write an article ...
#
#                                       Second Benefit  \
# 0                        I can earn that designation
# 1                       I can showcase my experience
# 2  I can teach CSM and CSPO courses and certify o...
# 3  others can learn about me and decide if I am t...
# 4         others know my certifications when reading
#
#                                      Second Triggers  \
# 0  {'Main Part': [['site member', 'fill out']], '...
# 1  {'Main Part': [['Practitioner', 'include']], '...
# 2  {'Main Part': [['site member', 'fill out']], '...
# 3  {'Main Part': [['Trainer', 'include']], 'Benef...
# 4  {'Main Part': [['Practitioner', 'write']], 'Be...
#
#                                       Second Targets  \
# 0  {'Main Part': [['fill out', 'application']], '...
# 1  {'Main Part': [['include', 'additional details...
# 2  {'Main Part': [['fill out', 'application']], '...
# 3  {'Main Part': [['include', 'additional details...
# 4  {'Main Part': [['write', 'article']], 'Benefit...
#
#                                      Second Contains
# 0  {'Main Part': [['Certified Scrum Practitioner'...
# 1  {'Main Part': [['profile page', 'additional de...
# 2  {'Main Part': [['Certified Scrum Trainer', 'ap...
# 3  {'Main Part': [['profile page about me', 'addi...
# 4  {'Main Part': [], 'Benefit': [['site', 'articl...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G10] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g10_pairs, key=ID_G10, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g10_pairs, key=ID_G10, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G11

# %%
ID_G11: str = "g11"
data_g11: list = datasets[ID_G11]
df_g11: pd.DataFrame = transform_2_dataframe(data_g11)
df_g11_pairs = transform_pairwise(df_g11)

# %%
datasets[ID_G11][0]
# Out:
# {'PID': '#G11#',
#  'USID': '590',
#  'Text': 'As a team member, I want to see the first iteration of beta up on cloud.gov.',
#  'Main Part': '#G11# As a team member, I want to see the first iteration of beta up on cloud.gov.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['team member', 'see']], 'Benefit': []},
#  'Targets': {'Main Part': [['see', 'first iteration']], 'Benefit': []},
#  'Contains': {'Main Part': [['beta', 'first iteration']],
#   'Benefit': [['cloud.gov', 'beta']]}}

# %%
display(df_g11.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G11#  590  As a team member, I want to see the first iter...
# 1  #G11#  591  As a developer, I want to have the subdomain b...
# 2  #G11#  592  As a stakeholder, I want to have a decision on...
# 3  #G11#  593  As an NSF employee, I want to understand the p...
# 4  #G11#  594  As a stakeholder, I want to see the results of...
#
#                                            Main Part  \
# 0  #G11# As a team member, I want to see the firs...
# 1  As a developer, I want to have the subdomain b...
# 2  #G11# As a stakeholder, I want to have a decis...
# 3  #G11# As an NSF employee, I want to understand...
# 4  As a stakeholder, I want to see the results of...
#
#                                       Benefit  \
# 0
# 1              I can deploy a beta site to it
# 2
# 3
# 4  I can determine if the CMS is right for me
#
#                                             Triggers  \
# 0  {'Main Part': [['team member', 'see']], 'Benef...
# 1  {'Main Part': [['developer', 'have']], 'Benefi...
# 2  {'Main Part': [['stakeholder', 'have']], 'Bene...
# 3  {'Main Part': [['NSF employee', 'understand']]...
# 4  {'Main Part': [['stakeholder', 'see']], 'Benef...
#
#                                              Targets  \
# 0  {'Main Part': [['see', 'first iteration']], 'B...
# 1  {'Main Part': [['have', 'subdomain beta.nsf.go...
# 2  {'Main Part': [['have', 'decision']], 'Benefit...
# 3  {'Main Part': [['understand', 'process']], 'Be...
# 4  {'Main Part': [['see', 'results']], 'Benefit':...
#
#                                             Contains
# 0  {'Main Part': [['beta', 'first iteration']], '...
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [], 'Benefit': [['beta', 'blog a...
# 3  {'Main Part': [], 'Benefit': [['cloud.gov host...
# 4  {'Main Part': [['user research', 'results']], ...

# %%
display(df_g11_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G11#        590  As a team member, I want to see the first iter...
# 1     #G11#        590  As a team member, I want to see the first iter...
# 2     #G11#        590  As a team member, I want to see the first iter...
# 3     #G11#        590  As a team member, I want to see the first iter...
# 4     #G11#        590  As a team member, I want to see the first iter...
#
#                                      First Main Part First Benefit  \
# 0  #G11# As a team member, I want to see the firs...
# 1  #G11# As a team member, I want to see the firs...
# 2  #G11# As a team member, I want to see the firs...
# 3  #G11# As a team member, I want to see the firs...
# 4  #G11# As a team member, I want to see the firs...
#
#                                       First Triggers  \
# 0  {'Main Part': [['team member', 'see']], 'Benef...
# 1  {'Main Part': [['team member', 'see']], 'Benef...
# 2  {'Main Part': [['team member', 'see']], 'Benef...
# 3  {'Main Part': [['team member', 'see']], 'Benef...
# 4  {'Main Part': [['team member', 'see']], 'Benef...
#
#                                        First Targets  \
# 0  {'Main Part': [['see', 'first iteration']], 'B...
# 1  {'Main Part': [['see', 'first iteration']], 'B...
# 2  {'Main Part': [['see', 'first iteration']], 'B...
# 3  {'Main Part': [['see', 'first iteration']], 'B...
# 4  {'Main Part': [['see', 'first iteration']], 'B...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['beta', 'first iteration']], '...      #G11#         591
# 1  {'Main Part': [['beta', 'first iteration']], '...      #G11#         592
# 2  {'Main Part': [['beta', 'first iteration']], '...      #G11#         593
# 3  {'Main Part': [['beta', 'first iteration']], '...      #G11#         594
# 4  {'Main Part': [['beta', 'first iteration']], '...      #G11#         595
#
#                                          Second Text  \
# 0  As a developer, I want to have the subdomain b...
# 1  As a stakeholder, I want to have a decision on...
# 2  As an NSF employee, I want to understand the p...
# 3  As a stakeholder, I want to see the results of...
# 4  As a designer, I want to have a new social med...
#
#                                     Second Main Part  \
# 0  As a developer, I want to have the subdomain b...
# 1  #G11# As a stakeholder, I want to have a decis...
# 2  #G11# As an NSF employee, I want to understand...
# 3  As a stakeholder, I want to see the results of...
# 4  As a designer, I want to have a new social med...
#
#                                Second Benefit  \
# 0              I can deploy a beta site to it
# 1
# 2
# 3  I can determine if the CMS is right for me
# 4             I can begin implementing design
#
#                                      Second Triggers  \
# 0  {'Main Part': [['developer', 'have']], 'Benefi...
# 1  {'Main Part': [['stakeholder', 'have']], 'Bene...
# 2  {'Main Part': [['NSF employee', 'understand']]...
# 3  {'Main Part': [['stakeholder', 'see']], 'Benef...
# 4  {'Main Part': [['designer', 'have']], 'Benefit...
#
#                                       Second Targets  \
# 0  {'Main Part': [['have', 'subdomain beta.nsf.go...
# 1  {'Main Part': [['have', 'decision']], 'Benefit...
# 2  {'Main Part': [['understand', 'process']], 'Be...
# 3  {'Main Part': [['see', 'results']], 'Benefit':...
# 4  {'Main Part': [['have', 'new social media wire...
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [], 'Benefit': [['beta', 'blog a...
# 2  {'Main Part': [], 'Benefit': [['cloud.gov host...
# 3  {'Main Part': [['user research', 'results']], ...
# 4  {'Main Part': [['new social media wireframe', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G11] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g11_pairs, key=ID_G11, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g11_pairs, key=ID_G11, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G14

# %%
ID_G14: str = "g14"
data_g14: list = datasets[ID_G14]
df_g14: pd.DataFrame = transform_2_dataframe(data_g14)
df_g14_pairs = transform_pairwise(df_g14)

# %%
datasets[ID_G14][0]
# Out:
# {'PID': '#G14#',
#  'USID': '717',
#  'Text': 'As a Publisher, I want to publish a dataset, so that I can view just the dataset with a few people.',
#  'Main Part': 'As a Publisher, I want to publish a dataset',
#  'Benefit': 'I can view just the dataset with a few people',
#  'Triggers': {'Main Part': [['Publisher', 'publish']], 'Benefit': []},
#  'Targets': {'Main Part': [['publish', 'dataset']],
#   'Benefit': [['view', 'dataset']]},
#  'Contains': {'Main Part': [], 'Benefit': []}}

# %%
display(df_g14.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G14#  717  As a Publisher, I want to publish a dataset, s...
# 1  #G14#  718  As a Publisher, I want to publish a dataset, s...
# 2  #G14#  719  As a Publisher, I want to sign up for an accou...
# 3  #G14#  720  As a Visitor, I want to sign up via github or ...
# 4  #G14#  721  As a Publisher, I want to know what do next af...
#
#                                            Main Part  \
# 0        As a Publisher, I want to publish a dataset
# 1        As a Publisher, I want to publish a dataset
# 2   As a Publisher, I want to sign up for an account
# 3  As a Visitor, I want to sign up via github or ...
# 4  As a Publisher, I want to know what do next af...
#
#                                              Benefit  \
# 0      I can view just the dataset with a few people
# 1     I can share the dataset publicly with everyone
# 2  I can publish my data package to the registry ...
# 3  I don't have to enter lots of information and ...
# 4                            I can get going quickly
#
#                                             Triggers  \
# 0  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 1  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 2  {'Main Part': [['Publisher', 'sign up']], 'Ben...
# 3  {'Main Part': [['Visitor', 'sign up via']], 'B...
# 4  {'Main Part': [['Publisher', 'know']], 'Benefi...
#
#                                              Targets  \
# 0  {'Main Part': [['publish', 'dataset']], 'Benef...
# 1  {'Main Part': [['publish', 'dataset']], 'Benef...
# 2  {'Main Part': [['sign up', 'account']], 'Benef...
# 3  {'Main Part': [['sign up via', 'github'], ['si...
# 4  {'Main Part': [['know', 'what'], ['do next', '...
#
#                                             Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [], 'Benefit': [['everyone', 'da...
# 2  {'Main Part': [], 'Benefit': [['registry', 'da...
# 3  {'Main Part': [], 'Benefit': [['another websit...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g14_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G14#        717  As a Publisher, I want to publish a dataset, s...
# 1     #G14#        717  As a Publisher, I want to publish a dataset, s...
# 2     #G14#        717  As a Publisher, I want to publish a dataset, s...
# 3     #G14#        717  As a Publisher, I want to publish a dataset, s...
# 4     #G14#        717  As a Publisher, I want to publish a dataset, s...
#
#                                First Main Part  \
# 0  As a Publisher, I want to publish a dataset
# 1  As a Publisher, I want to publish a dataset
# 2  As a Publisher, I want to publish a dataset
# 3  As a Publisher, I want to publish a dataset
# 4  As a Publisher, I want to publish a dataset
#
#                                    First Benefit  \
# 0  I can view just the dataset with a few people
# 1  I can view just the dataset with a few people
# 2  I can view just the dataset with a few people
# 3  I can view just the dataset with a few people
# 4  I can view just the dataset with a few people
#
#                                       First Triggers  \
# 0  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 1  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 2  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 3  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 4  {'Main Part': [['Publisher', 'publish']], 'Ben...
#
#                                        First Targets  \
# 0  {'Main Part': [['publish', 'dataset']], 'Benef...
# 1  {'Main Part': [['publish', 'dataset']], 'Benef...
# 2  {'Main Part': [['publish', 'dataset']], 'Benef...
# 3  {'Main Part': [['publish', 'dataset']], 'Benef...
# 4  {'Main Part': [['publish', 'dataset']], 'Benef...
#
#                      First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': []}      #G14#         718
# 1  {'Main Part': [], 'Benefit': []}      #G14#         719
# 2  {'Main Part': [], 'Benefit': []}      #G14#         720
# 3  {'Main Part': [], 'Benefit': []}      #G14#         721
# 4  {'Main Part': [], 'Benefit': []}      #G14#         722
#
#                                          Second Text  \
# 0  As a Publisher, I want to publish a dataset, s...
# 1  As a Publisher, I want to sign up for an accou...
# 2  As a Visitor, I want to sign up via github or ...
# 3  As a Publisher, I want to know what do next af...
# 4  As an Admin, I want to invite someone to join ...
#
#                                     Second Main Part  \
# 0        As a Publisher, I want to publish a dataset
# 1   As a Publisher, I want to sign up for an account
# 2  As a Visitor, I want to sign up via github or ...
# 3  As a Publisher, I want to know what do next af...
# 4  As an Admin, I want to invite someone to join ...
#
#                                       Second Benefit  \
# 0     I can share the dataset publicly with everyone
# 1  I can publish my data package to the registry ...
# 2  I don't have to enter lots of information and ...
# 3                            I can get going quickly
# 4          they can start contributing or using data
#
#                                      Second Triggers  \
# 0  {'Main Part': [['Publisher', 'publish']], 'Ben...
# 1  {'Main Part': [['Publisher', 'sign up']], 'Ben...
# 2  {'Main Part': [['Visitor', 'sign up via']], 'B...
# 3  {'Main Part': [['Publisher', 'know']], 'Benefi...
# 4  {'Main Part': [['Admin', 'invite']], 'Benefit'...
#
#                                       Second Targets  \
# 0  {'Main Part': [['publish', 'dataset']], 'Benef...
# 1  {'Main Part': [['sign up', 'account']], 'Benef...
# 2  {'Main Part': [['sign up via', 'github'], ['si...
# 3  {'Main Part': [['know', 'what'], ['do next', '...
# 4  {'Main Part': [['invite', 'someone']], 'Benefi...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['everyone', 'da...
# 1  {'Main Part': [], 'Benefit': [['registry', 'da...
# 2  {'Main Part': [], 'Benefit': [['another websit...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['platform', 'da...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G14] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g14_pairs, key=ID_G14, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g14_pairs, key=ID_G14, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G16

# %%
ID_G16: str = "g16"
data_g16: list = datasets[ID_G16]
df_g16: pd.DataFrame = transform_2_dataframe(data_g16)
df_g16_pairs = transform_pairwise(df_g16)

# %%
datasets[ID_G16][0]
# Out:
# {'PID': '#G16#',
#  'USID': '784',
#  'Text': 'As a collection curator, I want to set a date after which data will expire and be deleted or hidden then deleted.',
#  'Main Part': '#G16# As a collection curator, I want to set a date after which data will expire and be deleted or hidden then deleted.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['collection curator', 'set']], 'Benefit': []},
#  'Targets': {'Main Part': [['set', 'date']],
#   'Benefit': [['deleted', 'data'], ['hidden', 'data'], ['deleted', 'data']]},
#  'Contains': {'Main Part': [], 'Benefit': []}}

# %%
display(df_g16.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G16#  784  As a collection curator, I want to set a date ...
# 1  #G16#  785  As a collection curator, I want to see the sch...
# 2  #G16#  786  As a repository manager, I want to track who i...
# 3  #G16#  787  As a repository manager, I want to be able t r...
# 4  #G16#  788  As a collection curator, I want to map an item...
#
#                                            Main Part  \
# 0  #G16# As a collection curator, I want to set a...
# 1  #G16# As a collection curator, I want to see t...
# 2  #G16# As a repository manager, I want to track...
# 3  #G16# As a repository manager, I want to be ab...
# 4  As a collection curator, I want to map an item...
#
#                                              Benefit  \
# 0
# 1
# 2
# 3
# 4  an item may administratively belong to one col...
#
#                                             Triggers  \
# 0  {'Main Part': [['collection curator', 'set']],...
# 1  {'Main Part': [['collection curator', 'see']],...
# 2  {'Main Part': [['repository manager', 'track']...
# 3  {'Main Part': [['repository manager', 'run']],...
# 4  {'Main Part': [['collection curator', 'map']],...
#
#                                              Targets  \
# 0  {'Main Part': [['set', 'date']], 'Benefit': [[...
# 1  {'Main Part': [['see', 'scheduled records dele...
# 2  {'Main Part': [['track', 'who'], ['track', 'wh...
# 3  {'Main Part': [['run', 'report']], 'Benefit': ...
# 4  {'Main Part': [['map', 'item'], ['map', 'items...
#
#                                             Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [['item', 'scheduled records del...
# 2  {'Main Part': [], 'Benefit': [['repository', '...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['collection', 'items']], 'Bene...

# %%
display(df_g16_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G16#        784  As a collection curator, I want to set a date ...
# 1     #G16#        784  As a collection curator, I want to set a date ...
# 2     #G16#        784  As a collection curator, I want to set a date ...
# 3     #G16#        784  As a collection curator, I want to set a date ...
# 4     #G16#        784  As a collection curator, I want to set a date ...
#
#                                      First Main Part First Benefit  \
# 0  #G16# As a collection curator, I want to set a...
# 1  #G16# As a collection curator, I want to set a...
# 2  #G16# As a collection curator, I want to set a...
# 3  #G16# As a collection curator, I want to set a...
# 4  #G16# As a collection curator, I want to set a...
#
#                                       First Triggers  \
# 0  {'Main Part': [['collection curator', 'set']],...
# 1  {'Main Part': [['collection curator', 'set']],...
# 2  {'Main Part': [['collection curator', 'set']],...
# 3  {'Main Part': [['collection curator', 'set']],...
# 4  {'Main Part': [['collection curator', 'set']],...
#
#                                        First Targets  \
# 0  {'Main Part': [['set', 'date']], 'Benefit': [[...
# 1  {'Main Part': [['set', 'date']], 'Benefit': [[...
# 2  {'Main Part': [['set', 'date']], 'Benefit': [[...
# 3  {'Main Part': [['set', 'date']], 'Benefit': [[...
# 4  {'Main Part': [['set', 'date']], 'Benefit': [[...
#
#                      First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': []}      #G16#         785
# 1  {'Main Part': [], 'Benefit': []}      #G16#         786
# 2  {'Main Part': [], 'Benefit': []}      #G16#         787
# 3  {'Main Part': [], 'Benefit': []}      #G16#         788
# 4  {'Main Part': [], 'Benefit': []}      #G16#         789
#
#                                          Second Text  \
# 0  As a collection curator, I want to see the sch...
# 1  As a repository manager, I want to track who i...
# 2  As a repository manager, I want to be able t r...
# 3  As a collection curator, I want to map an item...
# 4  As a faculty member, I want to add a date deli...
#
#                                     Second Main Part  \
# 0  #G16# As a collection curator, I want to see t...
# 1  #G16# As a repository manager, I want to track...
# 2  #G16# As a repository manager, I want to be ab...
# 3  As a collection curator, I want to map an item...
# 4  As a faculty member, I want to add a date deli...
#
#                                       Second Benefit  \
# 0
# 1
# 2
# 3  an item may administratively belong to one col...
# 4  I can limit a search to return only results fr...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['collection curator', 'see']],...
# 1  {'Main Part': [['repository manager', 'track']...
# 2  {'Main Part': [['repository manager', 'run']],...
# 3  {'Main Part': [['collection curator', 'map']],...
# 4  {'Main Part': [['faculty member', 'add']], 'Be...
#
#                                       Second Targets  \
# 0  {'Main Part': [['see', 'scheduled records dele...
# 1  {'Main Part': [['track', 'who'], ['track', 'wh...
# 2  {'Main Part': [['run', 'report']], 'Benefit': ...
# 3  {'Main Part': [['map', 'item'], ['map', 'items...
# 4  {'Main Part': [['add', 'date delimiter']], 'Be...
#
#                                      Second Contains
# 0  {'Main Part': [['item', 'scheduled records del...
# 1  {'Main Part': [], 'Benefit': [['repository', '...
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['collection', 'items']], 'Bene...
# 4  {'Main Part': [['search string', 'date delimit...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G16] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g16_pairs, key=ID_G16, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g16_pairs, key=ID_G16, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G18

# %%
ID_G18: str = "g18"
data_g18: list = datasets[ID_G18]
df_g18: pd.DataFrame = transform_2_dataframe(data_g18)
df_g18_pairs = transform_pairwise(df_g18)

# %%
datasets[ID_G18][0]
# Out:
# {'PID': '#G18#',
#  'USID': '916',
#  'Text': 'As a system administrator, I want to run a script that installs the Neurohub node onto a virgin Ubuntu operating system.',
#  'Main Part': '#G18# As a system administrator, I want to run a script that installs the Neurohub node onto a virgin Ubuntu operating system.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['system administrator,', 'run']], 'Benefit': []},
#  'Targets': {'Main Part': [['run', 'script']],
#   'Benefit': [['installs', 'Neurohub node']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['virgin Ubuntu operating system', 'Neurohub node']]}}

# %%
display(df_g18.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G18#  916  As a system administrator, I want to run a scr...
# 1  #G18#  917  As a system administrator, I want to run a scr...
# 2  #G18#  918  As a release engineer, I want to call a script...
# 3  #G18#  919  As an investigator, I want to view the accepta...
# 4  #G18#  920  As an MRI operator, I want to digitally record...
#
#                                            Main Part  \
# 0  #G18# As a system administrator, I want to run...
# 1  #G18# As a system administrator, I want to run...
# 2  #G18# As a release engineer, I want to call a ...
# 3  As an investigator, I want to view the accepta...
# 4  #G18# As an MRI operator, I want to digitally ...
#
#                                              Benefit  \
# 0
# 1
# 2
# 3  I can understand how feature-complete the Neur...
# 4
#
#                                             Triggers  \
# 0  {'Main Part': [['system administrator,', 'run'...
# 1  {'Main Part': [['system administrator', 'run']...
# 2  {'Main Part': [['release engineer', 'call'], [...
# 3  {'Main Part': [['investigator', 'view']], 'Ben...
# 4  {'Main Part': [['MRI operator', 'digitally rec...
#
#                                              Targets  \
# 0  {'Main Part': [['run', 'script']], 'Benefit': ...
# 1  {'Main Part': [['run', 'script']], 'Benefit': ...
# 2  {'Main Part': [['call', 'script'], ['report ba...
# 3  {'Main Part': [['view', 'acceptance test resul...
# 4  {'Main Part': [['digitally record', 'responses...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['virgin Ubuntu ...
# 1                   {'Main Part': [], 'Benefit': []}
# 2                   {'Main Part': [], 'Benefit': []}
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['subjects', 'responses']], 'Be...

# %%
display(df_g18_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G18#        916  As a system administrator, I want to run a scr...
# 1     #G18#        916  As a system administrator, I want to run a scr...
# 2     #G18#        916  As a system administrator, I want to run a scr...
# 3     #G18#        916  As a system administrator, I want to run a scr...
# 4     #G18#        916  As a system administrator, I want to run a scr...
#
#                                      First Main Part First Benefit  \
# 0  #G18# As a system administrator, I want to run...
# 1  #G18# As a system administrator, I want to run...
# 2  #G18# As a system administrator, I want to run...
# 3  #G18# As a system administrator, I want to run...
# 4  #G18# As a system administrator, I want to run...
#
#                                       First Triggers  \
# 0  {'Main Part': [['system administrator,', 'run'...
# 1  {'Main Part': [['system administrator,', 'run'...
# 2  {'Main Part': [['system administrator,', 'run'...
# 3  {'Main Part': [['system administrator,', 'run'...
# 4  {'Main Part': [['system administrator,', 'run'...
#
#                                        First Targets  \
# 0  {'Main Part': [['run', 'script']], 'Benefit': ...
# 1  {'Main Part': [['run', 'script']], 'Benefit': ...
# 2  {'Main Part': [['run', 'script']], 'Benefit': ...
# 3  {'Main Part': [['run', 'script']], 'Benefit': ...
# 4  {'Main Part': [['run', 'script']], 'Benefit': ...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['virgin Ubuntu ...      #G18#         917
# 1  {'Main Part': [], 'Benefit': [['virgin Ubuntu ...      #G18#         918
# 2  {'Main Part': [], 'Benefit': [['virgin Ubuntu ...      #G18#         919
# 3  {'Main Part': [], 'Benefit': [['virgin Ubuntu ...      #G18#         920
# 4  {'Main Part': [], 'Benefit': [['virgin Ubuntu ...      #G18#         921
#
#                                          Second Text  \
# 0  As a system administrator, I want to run a scr...
# 1  As a release engineer, I want to call a script...
# 2  As an investigator, I want to view the accepta...
# 3  As an MRI operator, I want to digitally record...
# 4  As a user, I want to navigate forwards and bac...
#
#                                     Second Main Part  \
# 0  #G18# As a system administrator, I want to run...
# 1  #G18# As a release engineer, I want to call a ...
# 2  As an investigator, I want to view the accepta...
# 3  #G18# As an MRI operator, I want to digitally ...
# 4  #G18# As a user, I want to navigate forwards a...
#
#                                       Second Benefit  \
# 0
# 1
# 2  I can understand how feature-complete the Neur...
# 3
# 4
#
#                                      Second Triggers  \
# 0  {'Main Part': [['system administrator', 'run']...
# 1  {'Main Part': [['release engineer', 'call'], [...
# 2  {'Main Part': [['investigator', 'view']], 'Ben...
# 3  {'Main Part': [['MRI operator', 'digitally rec...
# 4  {'Main Part': [['user', 'navigate forwards and...
#
#                                       Second Targets  \
# 0  {'Main Part': [['run', 'script']], 'Benefit': ...
# 1  {'Main Part': [['call', 'script'], ['report ba...
# 2  {'Main Part': [['view', 'acceptance test resul...
# 3  {'Main Part': [['digitally record', 'responses...
# 4  {'Main Part': [['navigate forwards and backwar...
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1                   {'Main Part': [], 'Benefit': []}
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['subjects', 'responses']], 'Be...
# 4                   {'Main Part': [], 'Benefit': []}

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G18] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g18_pairs, key=ID_G18, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g18_pairs, key=ID_G18, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G19

# %%
ID_G19: str = "g19"
data_g19: list = datasets[ID_G19]
df_g19: pd.DataFrame = transform_2_dataframe(data_g19)
df_g19_pairs = transform_pairwise(df_g19)

# %%
datasets[ID_G19][0]
# Out:
# {'PID': '#G19#',
#  'USID': '1018',
#  'Text': 'As an OlderPerson, I want to know exactly what ALFRED does with my personal data, and share it only on my specific permission.',
#  'Main Part': '#G19# As an OlderPerson, I want to know exactly what ALFRED does with my personal data, and share it only on my specific permission.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['OlderPerson', 'know exactly']], 'Benefit': []},
#  'Targets': {'Main Part': [['know exactly', 'what']],
#   'Benefit': [['share', 'personal data']]},
#  'Contains': {'Main Part': [], 'Benefit': [['ALFRED', 'personal data']]}}

# %%
display(df_g19.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G19#  1018  As an OlderPerson, I want to know exactly what...
# 1  #G19#  1019  As an OlderPerson, I want to receive informati...
# 2  #G19#  1020  As an OlderPerson, I want to use only well-vis...
# 3  #G19#  1021  As an OlderPerson, I want to use ALFRED as muc...
# 4  #G19#  1022  As an OlderPerson, I want to always keep contr...
#
#                                            Main Part Benefit  \
# 0  #G19# As an OlderPerson, I want to know exactl...
# 1  #G19# As an OlderPerson, I want to receive inf...
# 2  #G19# As an OlderPerson, I want to use only we...
# 3  #G19# As an OlderPerson, I want to use ALFRED ...
# 4  #G19# As an OlderPerson, I want to always keep...
#
#                                             Triggers  \
# 0  {'Main Part': [['OlderPerson', 'know exactly']...
# 1  {'Main Part': [['OlderPerson', 'receive']], 'B...
# 2  {'Main Part': [['OlderPerson', 'use only']], '...
# 3  {'Main Part': [['OlderPerson', 'use']], 'Benef...
# 4  {'Main Part': [['OlderPerson', 'always keep co...
#
#                                              Targets  \
# 0  {'Main Part': [['know exactly', 'what']], 'Ben...
# 1  {'Main Part': [['receive', 'information']], 'B...
# 2  {'Main Part': [['use only', 'well-visible butt...
# 3  {'Main Part': [['use', 'ALFRED']], 'Benefit': []}
# 4  {'Main Part': [['always keep control', 'activi...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...
# 1  {'Main Part': [['ALFRED', 'information']], 'Be...
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['ALFRED', 'speech interaction'...
# 4  {'Main Part': [['ALFRED', 'activities']], 'Ben...

# %%
display(df_g19_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 1     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 2     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 3     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 4     #G19#       1018  As an OlderPerson, I want to know exactly what...
#
#                                      First Main Part First Benefit  \
# 0  #G19# As an OlderPerson, I want to know exactl...
# 1  #G19# As an OlderPerson, I want to know exactl...
# 2  #G19# As an OlderPerson, I want to know exactl...
# 3  #G19# As an OlderPerson, I want to know exactl...
# 4  #G19# As an OlderPerson, I want to know exactl...
#
#                                       First Triggers  \
# 0  {'Main Part': [['OlderPerson', 'know exactly']...
# 1  {'Main Part': [['OlderPerson', 'know exactly']...
# 2  {'Main Part': [['OlderPerson', 'know exactly']...
# 3  {'Main Part': [['OlderPerson', 'know exactly']...
# 4  {'Main Part': [['OlderPerson', 'know exactly']...
#
#                                        First Targets  \
# 0  {'Main Part': [['know exactly', 'what']], 'Ben...
# 1  {'Main Part': [['know exactly', 'what']], 'Ben...
# 2  {'Main Part': [['know exactly', 'what']], 'Ben...
# 3  {'Main Part': [['know exactly', 'what']], 'Ben...
# 4  {'Main Part': [['know exactly', 'what']], 'Ben...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1019
# 1  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1020
# 2  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1021
# 3  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1022
# 4  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1023
#
#                                          Second Text  \
# 0  As an OlderPerson, I want to receive informati...
# 1  As an OlderPerson, I want to use only well-vis...
# 2  As an OlderPerson, I want to use ALFRED as muc...
# 3  As an OlderPerson, I want to always keep contr...
# 4  As an OlderPerson, I want to be able to manage...
#
#                                     Second Main Part Second Benefit  \
# 0  #G19# As an OlderPerson, I want to receive inf...
# 1  #G19# As an OlderPerson, I want to use only we...
# 2  #G19# As an OlderPerson, I want to use ALFRED ...
# 3  #G19# As an OlderPerson, I want to always keep...
# 4  #G19# As an OlderPerson, I want to be able to ...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['OlderPerson', 'receive']], 'B...
# 1  {'Main Part': [['OlderPerson', 'use only']], '...
# 2  {'Main Part': [['OlderPerson', 'use']], 'Benef...
# 3  {'Main Part': [['OlderPerson', 'always keep co...
# 4  {'Main Part': [['OlderPerson', 'manage']], 'Be...
#
#                                       Second Targets  \
# 0  {'Main Part': [['receive', 'information']], 'B...
# 1  {'Main Part': [['use only', 'well-visible butt...
# 2  {'Main Part': [['use', 'ALFRED']], 'Benefit': []}
# 3  {'Main Part': [['always keep control', 'activi...
# 4  {'Main Part': [['manage', 'privacy'], ['manage...
#
#                                      Second Contains
# 0  {'Main Part': [['ALFRED', 'information']], 'Be...
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [['ALFRED', 'speech interaction'...
# 3  {'Main Part': [['ALFRED', 'activities']], 'Ben...
# 4                   {'Main Part': [], 'Benefit': []}

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G19] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g19_pairs, key=ID_G19, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g19_pairs, key=ID_G19, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %%
target_usids = [[1152, 1155], [1018, 1022], [1018, 1021], [1018, 1028], [1018, 1019], [1018, 1026], [1018, 1032], [1018, 1042], [1018, 1041], [1018, 1037], [1018, 1036], [1018, 1034], [1018, 1043], [1018, 1045], [1018, 1044], [1018, 1048], [1018, 1057], [1018, 1053], [1018, 1066], [1018, 1070], [1018, 1074], [1018, 1079], [1018, 1078], [1018, 1080], [1018, 1083], [1018, 1085], [1018, 1103], [1018, 1094], [1018, 1104], [1018, 1106], [1018, 1125], [1018, 1129], [1018, 1132], [1018, 1142], [1018, 1145], [1018, 1144], [1018, 1141], [1018, 1138], [1018, 1134], [1018, 1143], [1018, 1137], [1018, 1140], [1018, 1135], [1018, 1136], [1018, 1139], [1018, 1151], [1018, 1147], [1018, 1152], [1019, 1022], [1019, 1026], [1019, 1021], [1019, 1028], [1019, 1033], [1019, 1034], [1019, 1035], [1019, 1038], [1019, 1037], [1019, 1041], [1019, 1040], [1019, 1039], [1019, 1048], [1019, 1050], [1019, 1053], [1019, 1059], [1019, 1069], [1019, 1080], [1019, 1083], [1019, 1085], [1019, 1102], [1019, 1101], [1019, 1114], [1019, 1125], [1019, 1108], [1019, 1118], [1019, 1134], [1019, 1132], [1019, 1139], [1019, 1143], [1019, 1148], [1019, 1149], [1020, 1033], [1020, 1036], [1020, 1039], [1020, 1041], [1020, 1054], [1020, 1085], [1020, 1131], [1020, 1130], [1021, 1029], [1021, 1022], [1021, 1025], [1021, 1031], [1021, 1028], [1021, 1033], [1021, 1036], [1021, 1037], [1021, 1035], [1021, 1042], [1021, 1040], [1021, 1039], [1021, 1041], [1021, 1038], [1021, 1043], [1021, 1044], [1021, 1045], [1021, 1056], [1021, 1023], [1021, 1048], [1021, 1034], [1021, 1054], [1021, 1052], [1021, 1053], [1021, 1058], [1021, 1060], [1021, 1062], [1021, 1064], [1021, 1068], [1021, 1069], [1021, 1070], [1021, 1071], [1021, 1074], [1021, 1076], [1021, 1075], [1021, 1080], [1021, 1084], [1021, 1079], [1021, 1082], [1021, 1083], [1021, 1087], [1021, 1078], [1021, 1090], [1021, 1088], [1021, 1086], [1021, 1091], [1021, 1094], [1021, 1096], [1021, 1092], [1021, 1093], [1021, 1101], [1021, 1097], [1021, 1103], [1021, 1105], [1021, 1098], [1021, 1100], [1021, 1111], [1021, 1107], [1021, 1108], [1021, 1112], [1021, 1115], [1021, 1116], [1021, 1117], [1021, 1118], [1021, 1113], [1021, 1120], [1021, 1119], [1021, 1121], [1021, 1123], [1021, 1125], [1021, 1124], [1021, 1131], [1021, 1130], [1021, 1138], [1021, 1132], [1021, 1137], [1021, 1128], [1021, 1126], [1021, 1134], [1021, 1140], [1021, 1135], [1021, 1136], [1021, 1139], [1021, 1151], [1021, 1144], [1021, 1145], [1021, 1143], [1021, 1149], [1022, 1033], [1022, 1041], [1022, 1044], [1022, 1048], [1021, 1147], [1022, 1050], [1022, 1053], [1022, 1083], [1022, 1085], [1022, 1101], [1022, 1110], [1022, 1130], [1022, 1145], [1022, 1149], [1023, 1040], [1023, 1057], [1023, 1102], [1023, 1111], [1023, 1130], [1024, 1090], [1025, 1027], [1025, 1034], [1025, 1070], [1025, 1103], [1025, 1114], [1025, 1118], [1025, 1132], [1025, 1080], [1026, 1028], [1026, 1029], [1026, 1033], [1026, 1048], [1026, 1041], [1026, 1045], [1026, 1037], [1026, 1044], [1026, 1060], [1026, 1059], [1026, 1061], [1026, 1081], [1026, 1076], [1026, 1078], [1026, 1088], [1026, 1108], [1026, 1105], [1026, 1110], [1026, 1098], [1026, 1109], [1026, 1116], [1026, 1115], [1026, 1139], [1027, 1030], [1027, 1042], [1026, 1143], [1027, 1040], [1026, 1155], [1027, 1039], [1027, 1041], [1027, 1031], [1027, 1056], [1027, 1076], [1027, 1080], [1027, 1103], [1027, 1122], [1027, 1106], [1027, 1128], [1027, 1129], [1028, 1033], [1028, 1103], [1028, 1130], [1028, 1149], [1029, 1039], [1029, 1033], [1029, 1042], [1029, 1040], [1029, 1070], [1029, 1078], [1029, 1102], [1029, 1114], [1029, 1138], [1029, 1131], [1030, 1039], [1030, 1049], [1030, 1068], [1030, 1057], [1030, 1103], [1030, 1144], [1030, 1143], [1031, 1103], [1031, 1132], [1031, 1115], [1032, 1089], [1032, 1113], [1033, 1040], [1033, 1041], [1033, 1038], [1033, 1035], [1033, 1043], [1033, 1042], [1033, 1037], [1033, 1039], [1033, 1044], [1033, 1047], [1033, 1046], [1033, 1050], [1033, 1051], [1033, 1049], [1033, 1057], [1033, 1058], [1033, 1060], [1033, 1054], [1033, 1059], [1033, 1055], [1033, 1061], [1033, 1056], [1033, 1053], [1033, 1067], [1033, 1063], [1033, 1065], [1033, 1074], [1033, 1068], [1033, 1073], [1033, 1070], [1033, 1069], [1033, 1076], [1033, 1077], [1033, 1075], [1033, 1078], [1033, 1079], [1033, 1082], [1033, 1081], [1033, 1083], [1033, 1084], [1033, 1085], [1033, 1091], [1033, 1088], [1033, 1090], [1033, 1089], [1033, 1093], [1033, 1094], [1033, 1095], [1033, 1092], [1033, 1096], [1033, 1097], [1033, 1099], [1033, 1100], [1033, 1101], [1033, 1103], [1033, 1104], [1033, 1106], [1033, 1105], [1033, 1107], [1033, 1109], [1033, 1111], [1033, 1119], [1033, 1110], [1033, 1116], [1033, 1113], [1033, 1118], [1033, 1117], [1033, 1115], [1033, 1123], [1033, 1120], [1033, 1125], [1033, 1122], [1033, 1127], [1033, 1124], [1033, 1129], [1033, 1136], [1033, 1130], [1033, 1128], [1033, 1132], [1033, 1141], [1033, 1137], [1033, 1139], [1033, 1140], [1033, 1138], [1033, 1143], [1033, 1145], [1033, 1146], [1033, 1147], [1033, 1149], [1033, 1153], [1033, 1155], [1033, 1151], [1034, 1037], [1034, 1044], [1034, 1039], [1034, 1046], [1034, 1051], [1034, 1049], [1034, 1048], [1034, 1050], [1034, 1054], [1034, 1056], [1034, 1059], [1034, 1061], [1034, 1068], [1034, 1066], [1034, 1076], [1034, 1073], [1034, 1074], [1034, 1084], [1034, 1080], [1034, 1083], [1034, 1082], [1034, 1088], [1034, 1085], [1034, 1089], [1034, 1087], [1034, 1090], [1034, 1094], [1034, 1092], [1034, 1096], [1034, 1079], [1034, 1095], [1034, 1098], [1034, 1103], [1034, 1116], [1034, 1111], [1034, 1118], [1034, 1127], [1034, 1123], [1034, 1130], [1034, 1120], [1034, 1124], [1034, 1129], [1034, 1136], [1034, 1139], [1034, 1138], [1034, 1140], [1034, 1151], [1034, 1145], [1034, 1149], [1034, 1147], [1034, 1155], [1035, 1039], [1035, 1048], [1035, 1055], [1035, 1057], [1035, 1078], [1035, 1085], [1035, 1101], [1035, 1129], [1035, 1145], [1036, 1060], [1036, 1092], [1036, 1101], [1036, 1126], [1037, 1039], [1037, 1041], [1037, 1044], [1037, 1054], [1037, 1059], [1037, 1062], [1037, 1080], [1037, 1085], [1037, 1104], [1037, 1091], [1037, 1106], [1037, 1118], [1037, 1115], [1037, 1120], [1037, 1128], [1037, 1139], [1037, 1144], [1037, 1145], [1038, 1040], [1038, 1042], [1038, 1043], [1038, 1050], [1038, 1054], [1038, 1057], [1038, 1078], [1038, 1083], [1038, 1085], [1038, 1103], [1038, 1101], [1038, 1119], [1038, 1118], [1038, 1129], [1039, 1040], [1039, 1041], [1038, 1145], [1039, 1046], [1038, 1155], [1039, 1054], [1039, 1056], [1039, 1053], [1039, 1070], [1039, 1063], [1039, 1067], [1039, 1057], [1039, 1069], [1039, 1075], [1039, 1079], [1039, 1082], [1039, 1085], [1039, 1078], [1039, 1095], [1039, 1089], [1039, 1090], [1039, 1064], [1039, 1092], [1039, 1096], [1039, 1101], [1039, 1111], [1039, 1099], [1039, 1106], [1039, 1119], [1039, 1118], [1039, 1124], [1039, 1136], [1039, 1132], [1039, 1137], [1039, 1130], [1039, 1127], [1039, 1139], [1039, 1129], [1039, 1142], [1040, 1041], [1040, 1054], [1040, 1045], [1040, 1044], [1040, 1056], [1040, 1065], [1040, 1068], [1040, 1072], [1040, 1074], [1040, 1079], [1040, 1082], [1040, 1080], [1040, 1092], [1040, 1101], [1040, 1100], [1040, 1096], [1040, 1106], [1040, 1111], [1040, 1103], [1040, 1112], [1040, 1095], [1040, 1115], [1040, 1120], [1040, 1132], [1040, 1123], [1040, 1127], [1040, 1135], [1040, 1128], [1040, 1130], [1040, 1137], [1040, 1144], [1040, 1129], [1040, 1142], [1040, 1145], [1040, 1143], [1041, 1049], [1041, 1051], [1041, 1056], [1041, 1053], [1041, 1054], [1041, 1064], [1041, 1065], [1041, 1061], [1041, 1062], [1041, 1076], [1041, 1073], [1041, 1069], [1041, 1072], [1041, 1070], [1041, 1068], [1041, 1078], [1041, 1084], [1041, 1082], [1041, 1089], [1041, 1074], [1041, 1099], [1041, 1101], [1041, 1103], [1041, 1106], [1041, 1105], [1041, 1079], [1041, 1094], [1041, 1118], [1041, 1127], [1041, 1117], [1041, 1120], [1041, 1119], [1041, 1130], [1041, 1124], [1041, 1132], [1041, 1137], [1041, 1135], [1041, 1145], [1041, 1139], [1041, 1142], [1041, 1138], [1041, 1147], [1042, 1096], [1042, 1103], [1042, 1130], [1042, 1145], [1042, 1151], [1043, 1085], [1043, 1102], [1043, 1118], [1043, 1145], [1044, 1049], [1044, 1050], [1044, 1051], [1044, 1045], [1044, 1048], [1044, 1054], [1044, 1053], [1044, 1057], [1044, 1060], [1044, 1064], [1044, 1066], [1044, 1070], [1044, 1074], [1044, 1079], [1044, 1080], [1044, 1083], [1044, 1101], [1044, 1106], [1044, 1111], [1044, 1105], [1044, 1109], [1044, 1117], [1044, 1110], [1044, 1125], [1044, 1121], [1044, 1129], [1044, 1132], [1044, 1139], [1044, 1138], [1044, 1149], [1044, 1152], [1045, 1054], [1045, 1053], [1045, 1057], [1045, 1070], [1045, 1080], [1045, 1088], [1045, 1103], [1045, 1102], [1045, 1111], [1045, 1132], [1045, 1135], [1045, 1151], [1046, 1057], [1046, 1104], [1046, 1130], [1046, 1145], [1047, 1054], [1047, 1102], [1047, 1111], [1047, 1118], [1048, 1049], [1048, 1051], [1048, 1060], [1048, 1057], [1048, 1054], [1048, 1061], [1048, 1066], [1048, 1068], [1048, 1070], [1048, 1074], [1048, 1073], [1048, 1079], [1048, 1075], [1048, 1076], [1048, 1080], [1048, 1081], [1048, 1083], [1048, 1084], [1048, 1085], [1048, 1087], [1048, 1090], [1048, 1103], [1048, 1095], [1048, 1096], [1048, 1099], [1048, 1098], [1048, 1120], [1048, 1111], [1048, 1116], [1048, 1119], [1048, 1121], [1048, 1127], [1048, 1134], [1048, 1136], [1048, 1137], [1048, 1139], [1048, 1144], [1048, 1147], [1048, 1152], [1048, 1151], [1049, 1057], [1049, 1053], [1049, 1054], [1049, 1061], [1049, 1064], [1049, 1059], [1049, 1060], [1049, 1087], [1049, 1078], [1049, 1080], [1049, 1083], [1049, 1089], [1049, 1090], [1049, 1092], [1049, 1095], [1049, 1097], [1049, 1117], [1049, 1107], [1049, 1119], [1049, 1111], [1049, 1120], [1049, 1114], [1049, 1115], [1049, 1118], [1049, 1125], [1049, 1121], [1049, 1123], [1049, 1135], [1049, 1127], [1049, 1128], [1049, 1131], [1049, 1134], [1049, 1139], [1049, 1144], [1049, 1147], [1049, 1151], [1050, 1051], [1050, 1054], [1050, 1065], [1050, 1076], [1050, 1070], [1050, 1083], [1050, 1099], [1050, 1120], [1050, 1111], [1050, 1128], [1050, 1138], [1050, 1146], [1050, 1149], [1050, 1148], [1051, 1067], [1051, 1059], [1051, 1093], [1051, 1078], [1051, 1085], [1051, 1092], [1051, 1103], [1051, 1102], [1051, 1108], [1051, 1111], [1051, 1118], [1051, 1115], [1051, 1130], [1051, 1122], [1051, 1134], [1051, 1135], [1051, 1145], [1051, 1147], [1052, 1054], [1052, 1082], [1052, 1078], [1052, 1104], [1052, 1138], [1052, 1151], [1053, 1060], [1053, 1070], [1053, 1068], [1053, 1080], [1053, 1078], [1053, 1081], [1053, 1085], [1053, 1090], [1053, 1093], [1053, 1095], [1053, 1097], [1053, 1101], [1053, 1104], [1053, 1111], [1053, 1114], [1053, 1118], [1053, 1130], [1053, 1138], [1053, 1144], [1053, 1139], [1053, 1143], [1053, 1145], [1053, 1149], [1053, 1151], [1054, 1063], [1054, 1059], [1054, 1060], [1054, 1064], [1054, 1067], [1054, 1057], [1054, 1068], [1054, 1070], [1054, 1074], [1054, 1072], [1054, 1075], [1054, 1077], [1054, 1078], [1054, 1080], [1054, 1083], [1054, 1081], [1054, 1088], [1054, 1087], [1054, 1090], [1054, 1097], [1054, 1093], [1054, 1095], [1054, 1096], [1054, 1103], [1054, 1107], [1054, 1108], [1054, 1115], [1054, 1117], [1054, 1116], [1054, 1125], [1054, 1118], [1054, 1123], [1054, 1128], [1054, 1129], [1054, 1132], [1054, 1135], [1054, 1137], [1054, 1139], [1054, 1140], [1054, 1143], [1054, 1145], [1054, 1149], [1054, 1147], [1054, 1151], [1054, 1155], [1056, 1057], [1056, 1082], [1056, 1068], [1056, 1093], [1056, 1102], [1056, 1114], [1057, 1060], [1057, 1064], [1057, 1065], [1057, 1063], [1057, 1061], [1057, 1066], [1057, 1077], [1057, 1070], [1057, 1082], [1057, 1069], [1057, 1080], [1057, 1068], [1057, 1079], [1057, 1074], [1057, 1078], [1057, 1089], [1057, 1083], [1057, 1088], [1057, 1084], [1057, 1087], [1057, 1085], [1057, 1101], [1057, 1107], [1057, 1096], [1057, 1108], [1057, 1105], [1057, 1103], [1057, 1100], [1057, 1098], [1057, 1109], [1057, 1115], [1057, 1119], [1057, 1118], [1057, 1124], [1057, 1113], [1057, 1116], [1057, 1117], [1057, 1112], [1057, 1123], [1057, 1121], [1057, 1137], [1057, 1130], [1057, 1128], [1057, 1127], [1057, 1134], [1057, 1136], [1057, 1129], [1057, 1141], [1057, 1140], [1057, 1145], [1057, 1139], [1057, 1146], [1057, 1143], [1057, 1144], [1057, 1147], [1057, 1151], [1057, 1155], [1057, 1149], [1057, 1153], [1058, 1085], [1058, 1130], [1059, 1067], [1059, 1099], [1059, 1103], [1059, 1125], [1059, 1130], [1059, 1144], [1059, 1148], [1059, 1145], [1059, 1151], [1059, 1152], [1059, 1149], [1060, 1064], [1060, 1074], [1060, 1075], [1060, 1078], [1060, 1084], [1060, 1111], [1060, 1118], [1060, 1138], [1060, 1130], [1060, 1145], [1060, 1141], [1060, 1147], [1061, 1090], [1061, 1139], [1062, 1130], [1063, 1145], [1064, 1077], [1064, 1098], [1064, 1101], [1065, 1113], [1065, 1153], [1066, 1093], [1066, 1114], [1067, 1070], [1067, 1102], [1067, 1118], [1067, 1130], [1068, 1103], [1068, 1120], [1068, 1113], [1068, 1132], [1069, 1070], [1069, 1085], [1069, 1088], [1069, 1102], [1069, 1111], [1069, 1118], [1070, 1078], [1070, 1083], [1070, 1085], [1070, 1095], [1070, 1101], [1070, 1111], [1070, 1118], [1070, 1138], [1070, 1139], [1070, 1149], [1071, 1123], [1071, 1124], [1072, 1073], [1072, 1075], [1072, 1077], [1072, 1078], [1072, 1074], [1072, 1079], [1072, 1080], [1072, 1081], [1072, 1084], [1072, 1082], [1072, 1083], [1072, 1087], [1072, 1090], [1072, 1094], [1072, 1092], [1072, 1085], [1072, 1093], [1072, 1095], [1072, 1096], [1072, 1099], [1072, 1100], [1072, 1102], [1072, 1103], [1072, 1105], [1072, 1109], [1072, 1108], [1072, 1107], [1072, 1112], [1072, 1110], [1072, 1111], [1072, 1115], [1072, 1114], [1072, 1116], [1072, 1117], [1072, 1118], [1072, 1119], [1072, 1125], [1072, 1124], [1072, 1122], [1072, 1126], [1072, 1129], [1072, 1128], [1072, 1130], [1072, 1132], [1072, 1134], [1072, 1135], [1072, 1139], [1072, 1138], [1072, 1145], [1072, 1144], [1072, 1142], [1072, 1140], [1072, 1146], [1072, 1141], [1072, 1148], [1072, 1151], [1072, 1152], [1072, 1155], [1072, 1153], [1073, 1075], [1073, 1101], [1073, 1103], [1073, 1102], [1073, 1114], [1073, 1118], [1073, 1151], [1074, 1090], [1074, 1093], [1075, 1123], [1075, 1135], [1076, 1078], [1076, 1090], [1076, 1093], [1076, 1102], [1076, 1118], [1076, 1129], [1076, 1139], [1076, 1145], [1076, 1148], [1076, 1151], [1077, 1111], [1077, 1143], [1078, 1079], [1078, 1082], [1078, 1080], [1078, 1089], [1078, 1084], [1078, 1088], [1078, 1083], [1078, 1087], [1078, 1085], [1078, 1093], [1078, 1096], [1078, 1090], [1078, 1094], [1078, 1095], [1078, 1098], [1078, 1092], [1078, 1099], [1078, 1101], [1078, 1100], [1078, 1106], [1078, 1103], [1078, 1119], [1078, 1105], [1078, 1113], [1078, 1118], [1078, 1115], [1078, 1116], [1078, 1123], [1078, 1124], [1078, 1127], [1078, 1130], [1078, 1128], [1078, 1137], [1078, 1141], [1078, 1144], [1078, 1139], [1079, 1083], [1079, 1102], [1079, 1116], [1079, 1118], [1080, 1101], [1080, 1138], [1081, 1086], [1081, 1100], [1081, 1111], [1081, 1119], [1081, 1144], [1082, 1090], [1083, 1088], [1083, 1093], [1083, 1101], [1083, 1106], [1083, 1118], [1083, 1124], [1083, 1127], [1083, 1138], [1084, 1095], [1084, 1111], [1084, 1132], [1084, 1145], [1085, 1087], [1085, 1093], [1085, 1092], [1085, 1118], [1085, 1121], [1085, 1135], [1085, 1144], [1085, 1147], [1085, 1145], [1085, 1151], [1086, 1130], [1086, 1141], [1087, 1095], [1087, 1094], [1087, 1093], [1087, 1098], [1087, 1104], [1087, 1100], [1087, 1106], [1087, 1101], [1087, 1103], [1087, 1111], [1087, 1115], [1087, 1118], [1087, 1136], [1087, 1137], [1087, 1128], [1087, 1130], [1087, 1134], [1087, 1138], [1087, 1145], [1088, 1095], [1088, 1101], [1088, 1106], [1088, 1119], [1088, 1110], [1088, 1130], [1088, 1123], [1088, 1135], [1088, 1144], [1088, 1145], [1088, 1147], [1088, 1146], [1088, 1151], [1089, 1090], [1089, 1101], [1089, 1092], [1089, 1114], [1090, 1097], [1090, 1130], [1090, 1125], [1090, 1132], [1090, 1138], [1090, 1144], [1090, 1143], [1092, 1093], [1092, 1103], [1092, 1134], [1092, 1145], [1093, 1104], [1093, 1102], [1093, 1119], [1093, 1118], [1093, 1121], [1093, 1120], [1093, 1117], [1093, 1106], [1093, 1111], [1093, 1131], [1093, 1123], [1093, 1138], [1093, 1149], [1094, 1103], [1094, 1118], [1094, 1130], [1094, 1144], [1095, 1096], [1095, 1100], [1095, 1101], [1095, 1104], [1095, 1106], [1095, 1105], [1095, 1121], [1095, 1115], [1095, 1127], [1095, 1138], [1095, 1128], [1095, 1135], [1095, 1134], [1095, 1143], [1095, 1145], [1096, 1102], [1096, 1111], [1096, 1120], [1096, 1118], [1096, 1130], [1096, 1133], [1096, 1135], [1096, 1138], [1096, 1143], [1096, 1145], [1097, 1099], [1097, 1101], [1097, 1103], [1097, 1106], [1097, 1111], [1097, 1114], [1097, 1115], [1097, 1120], [1097, 1119], [1097, 1124], [1097, 1123], [1097, 1125], [1097, 1127], [1097, 1130], [1097, 1128], [1097, 1137], [1097, 1139], [1097, 1138], [1097, 1143], [1097, 1145], [1097, 1144], [1097, 1148], [1098, 1106], [1098, 1125], [1098, 1128], [1099, 1118], [1100, 1103], [1100, 1119], [1100, 1130], [1101, 1103], [1101, 1104], [1101, 1105], [1101, 1106], [1101, 1111], [1101, 1113], [1101, 1114], [1101, 1115], [1101, 1116], [1101, 1118], [1101, 1120], [1101, 1121], [1101, 1125], [1101, 1127], [1101, 1130], [1101, 1117], [1101, 1132], [1101, 1136], [1101, 1135], [1101, 1123], [1101, 1139], [1101, 1144], [1101, 1146], [1101, 1143], [1101, 1147], [1101, 1145], [1101, 1152], [1101, 1151], [1101, 1155], [1102, 1104], [1102, 1111], [1102, 1110], [1102, 1108], [1102, 1109], [1102, 1112], [1102, 1107], [1102, 1115], [1102, 1120], [1102, 1114], [1102, 1121], [1102, 1122], [1102, 1113], [1102, 1124], [1102, 1123], [1102, 1126], [1102, 1128], [1102, 1129], [1102, 1130], [1102, 1132], [1102, 1131], [1102, 1136], [1102, 1134], [1102, 1135], [1102, 1140], [1102, 1143], [1102, 1138], [1102, 1145], [1102, 1142], [1102, 1144], [1102, 1147], [1102, 1146], [1102, 1148], [1102, 1151], [1102, 1149], [1102, 1152], [1102, 1155], [1103, 1111], [1103, 1113], [1103, 1119], [1103, 1130], [1103, 1132], [1103, 1124], [1103, 1143], [1103, 1149], [1104, 1107], [1104, 1118], [1103, 1155], [1104, 1130], [1104, 1135], [1104, 1138], [1104, 1149], [1105, 1114], [1106, 1118], [1106, 1138], [1106, 1130], [1107, 1113], [1108, 1113], [1108, 1151], [1109, 1113], [1109, 1139], [1109, 1145], [1109, 1151], [1111, 1114], [1111, 1116], [1111, 1120], [1111, 1118], [1111, 1124], [1111, 1123], [1111, 1126], [1111, 1132], [1111, 1136], [1111, 1134], [1111, 1135], [1111, 1137], [1111, 1141], [1111, 1140], [1111, 1139], [1111, 1138], [1111, 1144], [1111, 1145], [1111, 1152], [1111, 1155], [1113, 1130], [1114, 1118], [1114, 1120], [1114, 1130], [1114, 1138], [1114, 1143], [1115, 1145], [1116, 1118], [1116, 1121], [1116, 1127], [1116, 1128], [1116, 1140], [1116, 1144], [1116, 1155], [1116, 1151], [1117, 1151], [1119, 1120], [1119, 1123], [1119, 1121], [1119, 1128], [1119, 1133], [1119, 1130], [1119, 1137], [1119, 1138], [1119, 1143], [1119, 1148], [1119, 1147], [1119, 1149], [1119, 1155], [1120, 1128], [1120, 1130], [1120, 1135], [1120, 1132], [1120, 1138], [1120, 1136], [1120, 1141], [1120, 1145], [1120, 1143], [1120, 1149], [1121, 1140], [1121, 1145], [1124, 1139], [1124, 1143], [1125, 1126], [1125, 1128], [1125, 1132], [1125, 1151], [1125, 1149], [1126, 1130], [1126, 1132], [1126, 1134], [1126, 1139], [1126, 1149], [1127, 1130], [1128, 1130], [1128, 1139], [1128, 1141], [1128, 1144], [1129, 1130], [1129, 1137], [1129, 1144], [1129, 1147], [1129, 1149], [1130, 1135], [1129, 1155], [1130, 1146], [1130, 1145], [1130, 1147], [1130, 1149], [1131, 1132], [1131, 1134], [1130, 1155], [1131, 1145], [1131, 1140], [1131, 1144], [1131, 1151], [1132, 1134], [1132, 1143], [1132, 1138], [1132, 1145], [1132, 1151], [1136, 1143], [1137, 1147], [1138, 1141], [1138, 1143], [1138, 1146], [1138, 1147], [1138, 1148], [1138, 1149], [1138, 1144], [1138, 1153], [1138, 1151], [1138, 1152], [1138, 1150], [1138, 1155], [1139, 1141], [1139, 1144], [1139, 1143], [1139, 1142], [1139, 1140], [1139, 1145], [1139, 1146], [1139, 1148], [1139, 1147], [1139, 1149], [1139, 1150], [1139, 1151], [1139, 1155], [1139, 1152], [1139, 1153], [1140, 1141], [1140, 1142], [1140, 1145], [1140, 1144], [1140, 1143], [1140, 1146], [1140, 1147], [1140, 1148], [1140, 1150], [1140, 1149], [1140, 1151], [1140, 1152], [1140, 1153], [1140, 1155], [1141, 1142], [1141, 1143], [1141, 1144], [1141, 1145], [1141, 1146], [1141, 1147], [1141, 1148], [1141, 1150], [1141, 1149], [1141, 1151], [1141, 1152], [1141, 1153], [1141, 1155], [1142, 1143], [1142, 1145], [1142, 1144], [1142, 1146], [1142, 1147], [1142, 1148], [1142, 1149], [1142, 1150], [1142, 1151], [1142, 1152], [1142, 1153], [1143, 1144], [1142, 1155], [1143, 1145], [1143, 1146], [1143, 1147], [1143, 1149], [1143, 1148], [1143, 1150], [1143, 1152], [1143, 1151], [1143, 1153], [1143, 1155], [1144, 1145], [1144, 1147], [1144, 1146], [1144, 1149], [1144, 1148], [1144, 1150], [1144, 1151], [1144, 1153], [1144, 1152], [1144, 1155], [1145, 1146], [1145, 1147], [1145, 1148], [1145, 1150], [1145, 1149], [1145, 1151], [1145, 1152], [1145, 1153], [1145, 1155], [1146, 1147], [1146, 1148], [1146, 1149], [1146, 1151], [1146, 1150], [1146, 1152], [1146, 1153], [1147, 1148], [1146, 1155], [1147, 1149], [1147, 1150], [1147, 1151], [1147, 1153], [1147, 1152], [1147, 1155], [1148, 1149], [1148, 1150], [1148, 1151], [1148, 1152], [1148, 1153], [1148, 1155], [1149, 1150], [1149, 1151], [1149, 1152], [1149, 1153], [1150, 1151], [1149, 1155], [1150, 1152], [1150, 1153], [1150, 1155], [1151, 1152], [1151, 1153], [1151, 1155], [1152, 1153], [1153, 1155]]

def is_in_target_usids(usid_one: int, usid_two: int):
    for element in target_usids:
        if (usid_one == element[0] and usid_two == element[1]):
            return True
    return False

# Apply the function to each row
df_g19_pairs_adjusted = df_g19_pairs[
    df_g19_pairs.apply(lambda row: is_in_target_usids(int(row['First USID']), int(row['Second USID'])), axis=1)
]

print(len(df_g19_pairs_adjusted))
df_g19_pairs_adjusted.head(5)
# Out:
# 1541
#   First PID First USID                                         First Text  \
# 0     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 2     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 3     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 7     #G19#       1018  As an OlderPerson, I want to know exactly what...
# 9     #G19#       1018  As an OlderPerson, I want to know exactly what...
#
#                                      First Main Part First Benefit  \
# 0  #G19# As an OlderPerson, I want to know exactl...
# 2  #G19# As an OlderPerson, I want to know exactl...
# 3  #G19# As an OlderPerson, I want to know exactl...
# 7  #G19# As an OlderPerson, I want to know exactl...
# 9  #G19# As an OlderPerson, I want to know exactl...
#
#                                       First Triggers  \
# 0  {'Main Part': [['OlderPerson', 'know exactly']...
# 2  {'Main Part': [['OlderPerson', 'know exactly']...
# 3  {'Main Part': [['OlderPerson', 'know exactly']...
# 7  {'Main Part': [['OlderPerson', 'know exactly']...
# 9  {'Main Part': [['OlderPerson', 'know exactly']...
#
#                                        First Targets  \
# 0  {'Main Part': [['know exactly', 'what']], 'Ben...
# 2  {'Main Part': [['know exactly', 'what']], 'Ben...
# 3  {'Main Part': [['know exactly', 'what']], 'Ben...
# 7  {'Main Part': [['know exactly', 'what']], 'Ben...
# 9  {'Main Part': [['know exactly', 'what']], 'Ben...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1019
# 2  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1021
# 3  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1022
# 7  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1026
# 9  {'Main Part': [], 'Benefit': [['ALFRED', 'pers...      #G19#        1028
#
#                                          Second Text  \
# 0  As an OlderPerson, I want to receive informati...
# 2  As an OlderPerson, I want to use ALFRED as muc...
# 3  As an OlderPerson, I want to always keep contr...
# 7  As an OlderPerson, I want to have ALFRED on al...
# 9  As an OlderPerson, I want to have clear instru...
#
#                                     Second Main Part Second Benefit  \
# 0  #G19# As an OlderPerson, I want to receive inf...
# 2  #G19# As an OlderPerson, I want to use ALFRED ...
# 3  #G19# As an OlderPerson, I want to always keep...
# 7  #G19# As an OlderPerson, I want to have ALFRED...
# 9  #G19# As an OlderPerson, I want to have clear ...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['OlderPerson', 'receive']], 'B...
# 2  {'Main Part': [['OlderPerson', 'use']], 'Benef...
# 3  {'Main Part': [['OlderPerson', 'always keep co...
# 7  {'Main Part': [['OlderPerson', 'have']], 'Bene...
# 9  {'Main Part': [['OlderPerson', 'have']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['receive', 'information']], 'B...
# 2  {'Main Part': [['use', 'ALFRED']], 'Benefit': []}
# 3  {'Main Part': [['always keep control', 'activi...
# 7  {'Main Part': [['have', 'ALFRED']], 'Benefit':...
# 9  {'Main Part': [['have', 'clear instructions'],...
#
#                                      Second Contains
# 0  {'Main Part': [['ALFRED', 'information']], 'Be...
# 2  {'Main Part': [['ALFRED', 'speech interaction'...
# 3  {'Main Part': [['ALFRED', 'activities']], 'Ben...
# 7  {'Main Part': [['computers', 'ALFRED'], ['tabl...
# 9                   {'Main Part': [], 'Benefit': []}

# %%
# process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g19_pairs, key=ID_G19, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G21

# %%
ID_G21: str = "g21"
data_g21: list = datasets[ID_G21]
df_g21: pd.DataFrame = transform_2_dataframe(data_g21)
df_g21_pairs = transform_pairwise(df_g21)

# %%
datasets[ID_G21][0]
# Out:
# {'PID': '#G21#',
#  'USID': '1156',
#  'Text': 'As a anonymoususer, I want to view a list of sponsors, so that I can thank all the awesome sponsors.',
#  'Main Part': 'As a anonymoususer, I want to view a list of sponsors',
#  'Benefit': 'I can thank all the awesome sponsors',
#  'Triggers': {'Main Part': [['anonymoususer', 'view']], 'Benefit': []},
#  'Targets': {'Main Part': [['view', 'list']],
#   'Benefit': [['thank', 'awesome sponsors.']]},
#  'Contains': {'Main Part': [['list', 'sponsors']], 'Benefit': []}}

# %%
display(df_g21.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G21#  1156  As a anonymoususer, I want to view a list of s...
# 1  #G21#  1157  As a anonymoususer, I want to view a list of u...
# 2  #G21#  1158  As a trainingcoordinator, I want to email all ...
# 3  #G21#  1159  As a attendee, I want to have a very clear map...
# 4  #G21#  1160  As a trainer, I want to edit my training node ...
#
#                                            Main Part  \
# 0  As a anonymoususer, I want to view a list of s...
# 1  As a anonymoususer, I want to view a list of u...
# 2  As a trainingcoordinator, I want to email all ...
# 3  As a attendee, I want to have a very clear map...
# 4  As a trainer, I want to edit my training node ...
#
#                                              Benefit  \
# 0               I can thank all the awesome sponsors
# 1             I know who is attending the conference
# 2                                It is easier to use
# 3                     I can make it to class on time
# 4  the training coordinators don't have to and li...
#
#                                             Triggers  \
# 0  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 1  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 2  {'Main Part': [['trainingcoordinator', 'email'...
# 3  {'Main Part': [['attendee', 'have']], 'Benefit...
# 4  {'Main Part': [['trainer', 'edit']], 'Benefit'...
#
#                                              Targets  \
# 0  {'Main Part': [['view', 'list']], 'Benefit': [...
# 1  {'Main Part': [['view', 'list']], 'Benefit': [...
# 2  {'Main Part': [['email', 'trainers']], 'Benefi...
# 3  {'Main Part': [['have', 'very clear map']], 'B...
# 4  {'Main Part': [['edit', 'training node']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [['list', 'sponsors']], 'Benefit...
# 1  {'Main Part': [['list', 'user profiles']], 'Be...
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['very clear map', 'buildings']...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g21_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G21#       1156  As a anonymoususer, I want to view a list of s...
# 1     #G21#       1156  As a anonymoususer, I want to view a list of s...
# 2     #G21#       1156  As a anonymoususer, I want to view a list of s...
# 3     #G21#       1156  As a anonymoususer, I want to view a list of s...
# 4     #G21#       1156  As a anonymoususer, I want to view a list of s...
#
#                                      First Main Part  \
# 0  As a anonymoususer, I want to view a list of s...
# 1  As a anonymoususer, I want to view a list of s...
# 2  As a anonymoususer, I want to view a list of s...
# 3  As a anonymoususer, I want to view a list of s...
# 4  As a anonymoususer, I want to view a list of s...
#
#                           First Benefit  \
# 0  I can thank all the awesome sponsors
# 1  I can thank all the awesome sponsors
# 2  I can thank all the awesome sponsors
# 3  I can thank all the awesome sponsors
# 4  I can thank all the awesome sponsors
#
#                                       First Triggers  \
# 0  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 1  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 2  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 3  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 4  {'Main Part': [['anonymoususer', 'view']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['view', 'list']], 'Benefit': [...
# 1  {'Main Part': [['view', 'list']], 'Benefit': [...
# 2  {'Main Part': [['view', 'list']], 'Benefit': [...
# 3  {'Main Part': [['view', 'list']], 'Benefit': [...
# 4  {'Main Part': [['view', 'list']], 'Benefit': [...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['list', 'sponsors']], 'Benefit...      #G21#        1157
# 1  {'Main Part': [['list', 'sponsors']], 'Benefit...      #G21#        1158
# 2  {'Main Part': [['list', 'sponsors']], 'Benefit...      #G21#        1159
# 3  {'Main Part': [['list', 'sponsors']], 'Benefit...      #G21#        1160
# 4  {'Main Part': [['list', 'sponsors']], 'Benefit...      #G21#        1161
#
#                                          Second Text  \
# 0  As a anonymoususer, I want to view a list of u...
# 1  As a trainingcoordinator, I want to email all ...
# 2  As a attendee, I want to have a very clear map...
# 3  As a trainer, I want to edit my training node ...
# 4  As a trainee, I want to limit to one registrat...
#
#                                     Second Main Part  \
# 0  As a anonymoususer, I want to view a list of u...
# 1  As a trainingcoordinator, I want to email all ...
# 2  As a attendee, I want to have a very clear map...
# 3  As a trainer, I want to edit my training node ...
# 4  As a trainee, I want to limit to one registrat...
#
#                                       Second Benefit  \
# 0             I know who is attending the conference
# 1                                It is easier to use
# 2                     I can make it to class on time
# 3  the training coordinators don't have to and li...
# 4                     we don't have duplicate spaces
#
#                                      Second Triggers  \
# 0  {'Main Part': [['anonymoususer', 'view']], 'Be...
# 1  {'Main Part': [['trainingcoordinator', 'email'...
# 2  {'Main Part': [['attendee', 'have']], 'Benefit...
# 3  {'Main Part': [['trainer', 'edit']], 'Benefit'...
# 4  {'Main Part': [['trainee', 'limit']], 'Benefit...
#
#                                       Second Targets  \
# 0  {'Main Part': [['view', 'list']], 'Benefit': [...
# 1  {'Main Part': [['email', 'trainers']], 'Benefi...
# 2  {'Main Part': [['have', 'very clear map']], 'B...
# 3  {'Main Part': [['edit', 'training node']], 'Be...
# 4  {'Main Part': [['limit', 'one registration']],...
#
#                                      Second Contains
# 0  {'Main Part': [['list', 'user profiles']], 'Be...
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [['very clear map', 'buildings']...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['day', 'one registration'], ['...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G21] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g21_pairs, key=ID_G21, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g21_pairs, key=ID_G21, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G22

# %%
ID_G22: str = "g22"
data_g22: list = datasets[ID_G22]
df_g22: pd.DataFrame = transform_2_dataframe(data_g22)
df_g22_pairs = transform_pairwise(df_g22)

# %%
datasets[ID_G22][0]
# Out:
# {'PID': '#G22#',
#  'USID': '1225',
#  'Text': 'As a PI, I want to properly record all metadata, so that I can ensure proper running of the project in case of staff changes.',
#  'Main Part': 'As a PI, I want to properly record all metadata',
#  'Benefit': 'I can ensure proper running of the project in case of staff changes',
#  'Triggers': {'Main Part': [['PI', 'properly record']], 'Benefit': []},
#  'Targets': {'Main Part': [['properly record', 'all metadata']],
#   'Benefit': [['ensure', 'proper running'], ['changes', 'staff']]},
#  'Contains': {'Main Part': [], 'Benefit': []}}

# %%
display(df_g22.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G22#  1225  As a PI, I want to properly record all metadat...
# 1  #G22#  1226  As a researcher, I want to indicate where my d...
# 2  #G22#  1227  As a researcher, I want to import metadata tha...
# 3  #G22#  1228  As a data manager, I want to know how the data...
# 4  #G22#  1229  As a repository owner, I want to be able to ch...
#
#                                            Main Part  \
# 0    As a PI, I want to properly record all metadata
# 1  As a researcher, I want to indicate where my d...
# 2  As a researcher, I want to import metadata tha...
# 3  As a data manager, I want to know how the data...
# 4  As a repository owner, I want to be able to ch...
#
#                                              Benefit  \
# 0  I can ensure proper running of the project in ...
# 1  it remains accessible during all stages of the...
# 2         I do not have to capture it again in a DMP
# 3  I can develop more detailed usage and support ...
# 4  I can calculate necessary submission fees and ...
#
#                                             Triggers  \
# 0  {'Main Part': [['PI', 'properly record']], 'Be...
# 1  {'Main Part': [['researcher', 'indicate']], 'B...
# 2  {'Main Part': [['researcher', 'import']], 'Ben...
# 3  {'Main Part': [['data manager', 'know']], 'Ben...
# 4  {'Main Part': [['repository owner', 'check']],...
#
#                                              Targets  \
# 0  {'Main Part': [['properly record', 'all metada...
# 1  {'Main Part': [['indicate', 'where'], ['indica...
# 2  {'Main Part': [['import', 'metadata']], 'Benef...
# 3  {'Main Part': [['know', 'how']], 'Benefit': [[...
# 4  {'Main Part': [['check', 'planned provenance']...
#
#                                             Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [], 'Benefit': [['where', 'data'...
# 2                   {'Main Part': [], 'Benefit': []}
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['data', 'planned provenance']]...

# %%
display(df_g22_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G22#       1225  As a PI, I want to properly record all metadat...
# 1     #G22#       1225  As a PI, I want to properly record all metadat...
# 2     #G22#       1225  As a PI, I want to properly record all metadat...
# 3     #G22#       1225  As a PI, I want to properly record all metadat...
# 4     #G22#       1225  As a PI, I want to properly record all metadat...
#
#                                    First Main Part  \
# 0  As a PI, I want to properly record all metadata
# 1  As a PI, I want to properly record all metadata
# 2  As a PI, I want to properly record all metadata
# 3  As a PI, I want to properly record all metadata
# 4  As a PI, I want to properly record all metadata
#
#                                        First Benefit  \
# 0  I can ensure proper running of the project in ...
# 1  I can ensure proper running of the project in ...
# 2  I can ensure proper running of the project in ...
# 3  I can ensure proper running of the project in ...
# 4  I can ensure proper running of the project in ...
#
#                                       First Triggers  \
# 0  {'Main Part': [['PI', 'properly record']], 'Be...
# 1  {'Main Part': [['PI', 'properly record']], 'Be...
# 2  {'Main Part': [['PI', 'properly record']], 'Be...
# 3  {'Main Part': [['PI', 'properly record']], 'Be...
# 4  {'Main Part': [['PI', 'properly record']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['properly record', 'all metada...
# 1  {'Main Part': [['properly record', 'all metada...
# 2  {'Main Part': [['properly record', 'all metada...
# 3  {'Main Part': [['properly record', 'all metada...
# 4  {'Main Part': [['properly record', 'all metada...
#
#                      First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': []}      #G22#        1226
# 1  {'Main Part': [], 'Benefit': []}      #G22#        1227
# 2  {'Main Part': [], 'Benefit': []}      #G22#        1228
# 3  {'Main Part': [], 'Benefit': []}      #G22#        1229
# 4  {'Main Part': [], 'Benefit': []}      #G22#        1230
#
#                                          Second Text  \
# 0  As a researcher, I want to indicate where my d...
# 1  As a researcher, I want to import metadata tha...
# 2  As a data manager, I want to know how the data...
# 3  As a repository owner, I want to be able to ch...
# 4  As an IT manager, I want to know about IT reso...
#
#                                     Second Main Part  \
# 0  As a researcher, I want to indicate where my d...
# 1  As a researcher, I want to import metadata tha...
# 2  As a data manager, I want to know how the data...
# 3  As a repository owner, I want to be able to ch...
# 4  As an IT manager, I want to know about IT reso...
#
#                                       Second Benefit  \
# 0  it remains accessible during all stages of the...
# 1         I do not have to capture it again in a DMP
# 2  I can develop more detailed usage and support ...
# 3  I can calculate necessary submission fees and ...
# 4         I can enable resource acquisition planning
#
#                                      Second Triggers  \
# 0  {'Main Part': [['researcher', 'indicate']], 'B...
# 1  {'Main Part': [['researcher', 'import']], 'Ben...
# 2  {'Main Part': [['data manager', 'know']], 'Ben...
# 3  {'Main Part': [['repository owner', 'check']],...
# 4  {'Main Part': [['IT manager', 'know']], 'Benef...
#
#                                       Second Targets  \
# 0  {'Main Part': [['indicate', 'where'], ['indica...
# 1  {'Main Part': [['import', 'metadata']], 'Benef...
# 2  {'Main Part': [['know', 'how']], 'Benefit': [[...
# 3  {'Main Part': [['check', 'planned provenance']...
# 4  {'Main Part': [['know', 'IT resource requireme...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['where', 'data'...
# 1                   {'Main Part': [], 'Benefit': []}
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['data', 'planned provenance']]...
# 4  {'Main Part': [['project lifecycle', 'IT resou...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G22] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g22_pairs, key=ID_G22, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g22_pairs, key=ID_G22, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %%
target_usids = [[1018, 1019], [1018, 1022]]

def is_in_target_usids(usid_one: int, usid_two: int):
    for element in target_usids:
        if (usid_one == element[0] and usid_two == element[1]):
            return True
    return False

# Apply the function to each row
df_g22_pairs_adjusted = df_g22_pairs[
    df_g22_pairs.apply(lambda row: is_in_target_usids(int(row['First USID']), int(row['Second USID'])), axis=1)
]

print(len(df_g22_pairs_adjusted))
df_g22_pairs_adjusted.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 10
#       7     return False
#       9 # Apply the function to each row
# ---> 10 df_g22_pairs_adjusted = df_g22_pairs[
#      11     df_g22_pairs.apply(lambda row: is_in_target_usids(int(row['First USID']), int(row['Second USID'])), axis=1)
#      12 ]
#      14 print(len(df_g22_pairs_adjusted))
#      15 df_g22_pairs_adjusted.head(5)
#
# NameError: name 'df_g22_pairs' is not defined

# %%
# process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g22_pairs_adjusted, key=ID_G22, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G23

# %%
ID_G23: str = "g23"
data_g23: list = datasets[ID_G23]
df_g23: pd.DataFrame = transform_2_dataframe(data_g23)
df_g23_pairs = transform_pairwise(df_g23)

# %%
datasets[ID_G23][0]
# Out:
# {'PID': '#G23#',
#  'USID': '1308',
#  'Text': 'As a researcher, I want to be able to view a finding aid for a particular collection/Resource.',
#  'Main Part': '#G23# As a researcher, I want to be able to view a finding aid for a particular collection/Resource.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['researcher', 'view']], 'Benefit': []},
#  'Targets': {'Main Part': [['view', 'finding aid']], 'Benefit': []},
#  'Contains': {'Main Part': [['particular collection', 'finding aid'],
#    ['Resource', 'finding aid']],
#   'Benefit': []}}

# %%
display(df_g23.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G23#  1308  As a researcher, I want to be able to view a f...
# 1  #G23#  1309  As an Application Administrator, I want to be ...
# 2  #G23#  1310  As a user, I want backend changes for managing...
# 3  #G23#  1311  As an Archivist, I want to import EAD files th...
# 4  #G23#  1312  As an Archivist, I want to assign a component ...
#
#                                            Main Part Benefit  \
# 0  #G23# As a researcher, I want to be able to vi...
# 1  #G23# As an Application Administrator, I want ...
# 2  #G23# As a user, I want backend changes for ma...
# 3  #G23# As an Archivist, I want to import EAD fi...
# 4  #G23# As an Archivist, I want to assign a comp...
#
#                                             Triggers  \
# 0  {'Main Part': [['researcher', 'view']], 'Benef...
# 1  {'Main Part': [['Application Administrator', '...
# 2   {'Main Part': [['user', 'want']], 'Benefit': []}
# 3  {'Main Part': [['Archivist', 'import']], 'Bene...
# 4  {'Main Part': [['Archivist', 'assign']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['view', 'finding aid']], 'Bene...
# 1  {'Main Part': [['reset', 'User's password']], ...
# 2  {'Main Part': [['want', 'backend changes']], '...
# 3  {'Main Part': [['import', 'EAD files']], 'Bene...
# 4  {'Main Part': [['assign', 'component unique id...
#
#                                             Contains
# 0  {'Main Part': [['particular collection', 'find...
# 1                   {'Main Part': [], 'Benefit': []}
# 2                   {'Main Part': [], 'Benefit': []}
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['Resource Component', 'compone...

# %%
display(df_g23_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G23#       1308  As a researcher, I want to be able to view a f...
# 1     #G23#       1308  As a researcher, I want to be able to view a f...
# 2     #G23#       1308  As a researcher, I want to be able to view a f...
# 3     #G23#       1308  As a researcher, I want to be able to view a f...
# 4     #G23#       1308  As a researcher, I want to be able to view a f...
#
#                                      First Main Part First Benefit  \
# 0  #G23# As a researcher, I want to be able to vi...
# 1  #G23# As a researcher, I want to be able to vi...
# 2  #G23# As a researcher, I want to be able to vi...
# 3  #G23# As a researcher, I want to be able to vi...
# 4  #G23# As a researcher, I want to be able to vi...
#
#                                       First Triggers  \
# 0  {'Main Part': [['researcher', 'view']], 'Benef...
# 1  {'Main Part': [['researcher', 'view']], 'Benef...
# 2  {'Main Part': [['researcher', 'view']], 'Benef...
# 3  {'Main Part': [['researcher', 'view']], 'Benef...
# 4  {'Main Part': [['researcher', 'view']], 'Benef...
#
#                                        First Targets  \
# 0  {'Main Part': [['view', 'finding aid']], 'Bene...
# 1  {'Main Part': [['view', 'finding aid']], 'Bene...
# 2  {'Main Part': [['view', 'finding aid']], 'Bene...
# 3  {'Main Part': [['view', 'finding aid']], 'Bene...
# 4  {'Main Part': [['view', 'finding aid']], 'Bene...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['particular collection', 'find...      #G23#        1309
# 1  {'Main Part': [['particular collection', 'find...      #G23#        1310
# 2  {'Main Part': [['particular collection', 'find...      #G23#        1311
# 3  {'Main Part': [['particular collection', 'find...      #G23#        1312
# 4  {'Main Part': [['particular collection', 'find...      #G23#        1313
#
#                                          Second Text  \
# 0  As an Application Administrator, I want to be ...
# 1  As a user, I want backend changes for managing...
# 2  As an Archivist, I want to import EAD files th...
# 3  As an Archivist, I want to assign a component ...
# 4     As a User , I want to authenticate using LDAP.
#
#                                     Second Main Part Second Benefit  \
# 0  #G23# As an Application Administrator, I want ...
# 1  #G23# As a user, I want backend changes for ma...
# 2  #G23# As an Archivist, I want to import EAD fi...
# 3  #G23# As an Archivist, I want to assign a comp...
# 4  #G23# As a User , I want to authenticate using...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['Application Administrator', '...
# 1   {'Main Part': [['user', 'want']], 'Benefit': []}
# 2  {'Main Part': [['Archivist', 'import']], 'Bene...
# 3  {'Main Part': [['Archivist', 'assign']], 'Bene...
# 4  {'Main Part': [['User', 'authenticate']], 'Ben...
#
#                                       Second Targets  \
# 0  {'Main Part': [['reset', 'User's password']], ...
# 1  {'Main Part': [['want', 'backend changes']], '...
# 2  {'Main Part': [['import', 'EAD files']], 'Bene...
# 3  {'Main Part': [['assign', 'component unique id...
# 4  {'Main Part': [], 'Benefit': [['using', 'LDAP']]}
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1                   {'Main Part': [], 'Benefit': []}
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['Resource Component', 'compone...
# 4                   {'Main Part': [], 'Benefit': []}

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G23] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g23_pairs, key=ID_G23, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g23_pairs, key=ID_G23, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G24

# %%
ID_G24: str = "g24"
data_g24: list = datasets[ID_G24]
df_g24: pd.DataFrame = transform_2_dataframe(data_g24)
df_g24_pairs = transform_pairwise(df_g24)

# %%
datasets[ID_G24][0]
# Out:
# {'PID': '#G24#',
#  'USID': '1365',
#  'Text': "As a depositor, I want to deposit and maintain datasets through a simple web interface, so that I don't need to install and learn new software to deposit.",
#  'Main Part': 'As a depositor, I want to deposit and maintain datasets through a simple web interface',
#  'Benefit': "I don't need to install and learn new software to deposit",
#  'Triggers': {'Main Part': [['depositor', 'deposit'],
#    ['depositor', 'maintain']],
#   'Benefit': []},
#  'Targets': {'Main Part': [['deposit', 'datasets'], ['maintain', 'datasets']],
#   'Benefit': []},
#  'Contains': {'Main Part': [['simple web interface', 'datasets']],
#   'Benefit': []}}

# %%
display(df_g24.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G24#  1365  As a depositor, I want to deposit and maintain...
# 1  #G24#  1366  As a depositor, I want to have a user interfac...
# 2  #G24#  1367  As a depositor, I want to deposit and maintain...
# 3  #G24#  1368  As a depositor, I want to deposit and maintain...
# 4  #G24#  1369  As a depositor, I want to deposit the files th...
#
#                                            Main Part  \
# 0  As a depositor, I want to deposit and maintain...
# 1  As a depositor, I want to have a user interfac...
# 2  As a depositor, I want to deposit and maintain...
# 3  As a depositor, I want to deposit and maintain...
# 4  As a depositor, I want to deposit the files th...
#
#                                              Benefit  \
# 0  I don't need to install and learn new software...
# 1  I feel like all the University systems are joi...
# 2  I have a single onestop shop for managing my r...
# 3  I can continue to work with tools with which I...
# 4  I don't have to spend a lot of time finding th...
#
#                                             Triggers  \
# 0  {'Main Part': [['depositor', 'deposit'], ['dep...
# 1  {'Main Part': [['depositor', 'have']], 'Benefi...
# 2  {'Main Part': [['depositor', 'deposit'], ['dep...
# 3  {'Main Part': [['depositor', 'deposit'], ['dep...
# 4  {'Main Part': [['depositor', 'deposit']], 'Ben...
#
#                                              Targets  \
# 0  {'Main Part': [['deposit', 'datasets'], ['main...
# 1  {'Main Part': [['have', 'user interface']], 'B...
# 2  {'Main Part': [['deposit', 'datasets'], ['main...
# 3  {'Main Part': [['maintain', 'datasets'], ['dep...
# 4  {'Main Part': [['deposit', 'files']], 'Benefit...
#
#                                             Contains
# 0  {'Main Part': [['simple web interface', 'datas...
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [['Pure', 'datasets']], 'Benefit...
# 3  {'Main Part': [['Virtual Research Environments...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g24_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G24#       1365  As a depositor, I want to deposit and maintain...
# 1     #G24#       1365  As a depositor, I want to deposit and maintain...
# 2     #G24#       1365  As a depositor, I want to deposit and maintain...
# 3     #G24#       1365  As a depositor, I want to deposit and maintain...
# 4     #G24#       1365  As a depositor, I want to deposit and maintain...
#
#                                      First Main Part  \
# 0  As a depositor, I want to deposit and maintain...
# 1  As a depositor, I want to deposit and maintain...
# 2  As a depositor, I want to deposit and maintain...
# 3  As a depositor, I want to deposit and maintain...
# 4  As a depositor, I want to deposit and maintain...
#
#                                        First Benefit  \
# 0  I don't need to install and learn new software...
# 1  I don't need to install and learn new software...
# 2  I don't need to install and learn new software...
# 3  I don't need to install and learn new software...
# 4  I don't need to install and learn new software...
#
#                                       First Triggers  \
# 0  {'Main Part': [['depositor', 'deposit'], ['dep...
# 1  {'Main Part': [['depositor', 'deposit'], ['dep...
# 2  {'Main Part': [['depositor', 'deposit'], ['dep...
# 3  {'Main Part': [['depositor', 'deposit'], ['dep...
# 4  {'Main Part': [['depositor', 'deposit'], ['dep...
#
#                                        First Targets  \
# 0  {'Main Part': [['deposit', 'datasets'], ['main...
# 1  {'Main Part': [['deposit', 'datasets'], ['main...
# 2  {'Main Part': [['deposit', 'datasets'], ['main...
# 3  {'Main Part': [['deposit', 'datasets'], ['main...
# 4  {'Main Part': [['deposit', 'datasets'], ['main...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['simple web interface', 'datas...      #G24#        1366
# 1  {'Main Part': [['simple web interface', 'datas...      #G24#        1367
# 2  {'Main Part': [['simple web interface', 'datas...      #G24#        1368
# 3  {'Main Part': [['simple web interface', 'datas...      #G24#        1369
# 4  {'Main Part': [['simple web interface', 'datas...      #G24#        1370
#
#                                          Second Text  \
# 0  As a depositor, I want to have a user interfac...
# 1  As a depositor, I want to deposit and maintain...
# 2  As a depositor, I want to deposit and maintain...
# 3  As a depositor, I want to deposit the files th...
# 4  As a depositor, I want to place data under an ...
#
#                                     Second Main Part  \
# 0  As a depositor, I want to have a user interfac...
# 1  As a depositor, I want to deposit and maintain...
# 2  As a depositor, I want to deposit and maintain...
# 3  As a depositor, I want to deposit the files th...
# 4  As a depositor, I want to place data under an ...
#
#                                       Second Benefit  \
# 0  I feel like all the University systems are joi...
# 1  I have a single onestop shop for managing my r...
# 2  I can continue to work with tools with which I...
# 3  I don't have to spend a lot of time finding th...
# 4  my right of first use is protected, and I can ...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['depositor', 'have']], 'Benefi...
# 1  {'Main Part': [['depositor', 'deposit'], ['dep...
# 2  {'Main Part': [['depositor', 'deposit'], ['dep...
# 3  {'Main Part': [['depositor', 'deposit']], 'Ben...
# 4  {'Main Part': [['depositor', 'place']], 'Benef...
#
#                                       Second Targets  \
# 0  {'Main Part': [['have', 'user interface']], 'B...
# 1  {'Main Part': [['deposit', 'datasets'], ['main...
# 2  {'Main Part': [['maintain', 'datasets'], ['dep...
# 3  {'Main Part': [['deposit', 'files']], 'Benefit...
# 4  {'Main Part': [['place', 'data']], 'Benefit': ...
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [['Pure', 'datasets']], 'Benefit...
# 2  {'Main Part': [['Virtual Research Environments...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['data', 'embargo']], 'Benefit'...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G24] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g24_pairs, key=ID_G24, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g24_pairs, key=ID_G24, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G25

# %%
ID_G25: str = "g25"
data_g25: list = datasets[ID_G25]
df_g25: pd.DataFrame = transform_2_dataframe(data_g25)
df_g25_pairs = transform_pairwise(df_g25)

# %%
datasets[ID_G25][0]
# Out:
# {'PID': '#G25#',
#  'USID': '1418',
#  'Text': 'As a repository manager, I want to know all the collections and objects in the DAMS for which I have custodial responsibility.',
#  'Main Part': '#G25# As a repository manager, I want to know all the collections and objects in the DAMS for which I have custodial responsibility.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['repository manager', 'know']], 'Benefit': []},
#  'Targets': {'Main Part': [['know', 'collections'], ['know', 'objects']],
#   'Benefit': []},
#  'Contains': {'Main Part': [['DAMS', 'objects'], ['DAMS', 'collections']],
#   'Benefit': []}}

# %%
display(df_g25.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G25#  1418  As a repository manager, I want to know all th...
# 1  #G25#  1419  As a repository manager, I want to be able to ...
# 2  #G25#  1420  As a repository manager, I want to constrain c...
# 3  #G25#  1421  As a user, I want to list all the collections ...
# 4  #G25#  1422  As a user, I want to be able to contact reposi...
#
#                                            Main Part Benefit  \
# 0  #G25# As a repository manager, I want to know ...
# 1  #G25# As a repository manager, I want to be ab...
# 2  #G25# As a repository manager, I want to const...
# 3  #G25# As a user, I want to list all the collec...
# 4  #G25# As a user, I want to be able to contact ...
#
#                                             Triggers  \
# 0  {'Main Part': [['repository manager', 'know']]...
# 1  {'Main Part': [['repository manager', 'update'...
# 2  {'Main Part': [['repository manager', 'constra...
# 3   {'Main Part': [['user', 'list']], 'Benefit': []}
# 4  {'Main Part': [['user', 'contact']], 'Benefit'...
#
#                                              Targets  \
# 0  {'Main Part': [['know', 'collections'], ['know...
# 1  {'Main Part': [['update', 'repository informat...
# 2  {'Main Part': [['constrain', 'curatorial acces...
# 3  {'Main Part': [['list', 'collections'], ['list...
# 4  {'Main Part': [['contact', 'repositories']], '...
#
#                                             Contains
# 0  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...
# 1  {'Main Part': [['one place', 'repository infor...
# 2  {'Main Part': [['units assets', 'curatorial ac...
# 3  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g25_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G25#       1418  As a repository manager, I want to know all th...
# 1     #G25#       1418  As a repository manager, I want to know all th...
# 2     #G25#       1418  As a repository manager, I want to know all th...
# 3     #G25#       1418  As a repository manager, I want to know all th...
# 4     #G25#       1418  As a repository manager, I want to know all th...
#
#                                      First Main Part First Benefit  \
# 0  #G25# As a repository manager, I want to know ...
# 1  #G25# As a repository manager, I want to know ...
# 2  #G25# As a repository manager, I want to know ...
# 3  #G25# As a repository manager, I want to know ...
# 4  #G25# As a repository manager, I want to know ...
#
#                                       First Triggers  \
# 0  {'Main Part': [['repository manager', 'know']]...
# 1  {'Main Part': [['repository manager', 'know']]...
# 2  {'Main Part': [['repository manager', 'know']]...
# 3  {'Main Part': [['repository manager', 'know']]...
# 4  {'Main Part': [['repository manager', 'know']]...
#
#                                        First Targets  \
# 0  {'Main Part': [['know', 'collections'], ['know...
# 1  {'Main Part': [['know', 'collections'], ['know...
# 2  {'Main Part': [['know', 'collections'], ['know...
# 3  {'Main Part': [['know', 'collections'], ['know...
# 4  {'Main Part': [['know', 'collections'], ['know...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...      #G25#        1419
# 1  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...      #G25#        1420
# 2  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...      #G25#        1421
# 3  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...      #G25#        1422
# 4  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...      #G25#        1423
#
#                                          Second Text  \
# 0  As a repository manager, I want to be able to ...
# 1  As a repository manager, I want to constrain c...
# 2  As a user, I want to list all the collections ...
# 3  As a user, I want to be able to contact reposi...
# 4  As the DAMS manager, I want to be able to list...
#
#                                     Second Main Part Second Benefit  \
# 0  #G25# As a repository manager, I want to be ab...
# 1  #G25# As a repository manager, I want to const...
# 2  #G25# As a user, I want to list all the collec...
# 3  #G25# As a user, I want to be able to contact ...
# 4  #G25# As the DAMS manager, I want to be able t...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['repository manager', 'update'...
# 1  {'Main Part': [['repository manager', 'constra...
# 2   {'Main Part': [['user', 'list']], 'Benefit': []}
# 3  {'Main Part': [['user', 'contact']], 'Benefit'...
# 4  {'Main Part': [['DAMS manager', 'list']], 'Ben...
#
#                                       Second Targets  \
# 0  {'Main Part': [['update', 'repository informat...
# 1  {'Main Part': [['constrain', 'curatorial acces...
# 2  {'Main Part': [['list', 'collections'], ['list...
# 3  {'Main Part': [['contact', 'repositories']], '...
# 4  {'Main Part': [['browsing', 'all formal collec...
#
#                                      Second Contains
# 0  {'Main Part': [['one place', 'repository infor...
# 1  {'Main Part': [['units assets', 'curatorial ac...
# 2  {'Main Part': [['DAMS', 'objects'], ['DAMS', '...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['DAMS', 'all formal collection...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G25] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g25_pairs, key=ID_G25, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g25_pairs, key=ID_G25, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G26

# %%
ID_G26: str = "g26"
data_g26: list = datasets[ID_G26]
df_g26: pd.DataFrame = transform_2_dataframe(data_g26)
df_g26_pairs = transform_pairwise(df_g26)

# %%
datasets[ID_G26][0]
# Out:
# {'PID': '#G26#',
#  'USID': '1518',
#  'Text': 'As an archivist, I want to apply a license or rights statement, so that I know what I can do with a file.',
#  'Main Part': 'As an archivist, I want to apply a license or rights statement',
#  'Benefit': 'I know what I can do with a file',
#  'Triggers': {'Main Part': [['archivist', 'apply']], 'Benefit': []},
#  'Targets': {'Main Part': [['apply', 'license'],
#    ['apply', 'rights statement']],
#   'Benefit': [['know', 'what'], ['do', 'file']]},
#  'Contains': {'Main Part': [], 'Benefit': []}}

# %%
display(df_g26.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G26#  1518  As an archivist, I want to apply a license or ...
# 1  #G26#  1519  As an archivist, I want to mark individual fil...
# 2  #G26#  1520  As an archivist, I want to mark groups of file...
# 3  #G26#  1521  As an archivist, I want to restrict a file fro...
# 4  #G26#  1522  As an archivist, I want to restrict a group of...
#
#                                            Main Part  \
# 0  As an archivist, I want to apply a license or ...
# 1  As an archivist, I want to mark individual fil...
# 2  As an archivist, I want to mark groups of file...
# 3  #G26# As an archivist, I want to restrict a fi...
# 4  #G26# As an archivist, I want to restrict a gr...
#
#                             Benefit  \
# 0  I know what I can do with a file
# 1  they don't get shared by mistake
# 2  they don't get shared by mistake
# 3
# 4
#
#                                             Triggers  \
# 0  {'Main Part': [['archivist', 'apply']], 'Benef...
# 1  {'Main Part': [['archivist', 'mark']], 'Benefi...
# 2  {'Main Part': [['archivist', 'mark']], 'Benefi...
# 3  {'Main Part': [['archivist', 'restrict']], 'Be...
# 4  {'Main Part': [['archivist', 'restrict']], 'Be...
#
#                                              Targets  \
# 0  {'Main Part': [['apply', 'license'], ['apply',...
# 1  {'Main Part': [['mark', 'individual files']], ...
# 2  {'Main Part': [['mark', 'groups']], 'Benefit':...
# 3  {'Main Part': [['restrict', 'file']], 'Benefit...
# 4  {'Main Part': [['restrict', 'group']], 'Benefi...
#
#                                             Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [['groups', 'files']], 'Benefit'...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['group', 'files']], 'Benefit':...

# %%
display(df_g26_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G26#       1518  As an archivist, I want to apply a license or ...
# 1     #G26#       1518  As an archivist, I want to apply a license or ...
# 2     #G26#       1518  As an archivist, I want to apply a license or ...
# 3     #G26#       1518  As an archivist, I want to apply a license or ...
# 4     #G26#       1518  As an archivist, I want to apply a license or ...
#
#                                      First Main Part  \
# 0  As an archivist, I want to apply a license or ...
# 1  As an archivist, I want to apply a license or ...
# 2  As an archivist, I want to apply a license or ...
# 3  As an archivist, I want to apply a license or ...
# 4  As an archivist, I want to apply a license or ...
#
#                       First Benefit  \
# 0  I know what I can do with a file
# 1  I know what I can do with a file
# 2  I know what I can do with a file
# 3  I know what I can do with a file
# 4  I know what I can do with a file
#
#                                       First Triggers  \
# 0  {'Main Part': [['archivist', 'apply']], 'Benef...
# 1  {'Main Part': [['archivist', 'apply']], 'Benef...
# 2  {'Main Part': [['archivist', 'apply']], 'Benef...
# 3  {'Main Part': [['archivist', 'apply']], 'Benef...
# 4  {'Main Part': [['archivist', 'apply']], 'Benef...
#
#                                        First Targets  \
# 0  {'Main Part': [['apply', 'license'], ['apply',...
# 1  {'Main Part': [['apply', 'license'], ['apply',...
# 2  {'Main Part': [['apply', 'license'], ['apply',...
# 3  {'Main Part': [['apply', 'license'], ['apply',...
# 4  {'Main Part': [['apply', 'license'], ['apply',...
#
#                      First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': []}      #G26#        1519
# 1  {'Main Part': [], 'Benefit': []}      #G26#        1520
# 2  {'Main Part': [], 'Benefit': []}      #G26#        1521
# 3  {'Main Part': [], 'Benefit': []}      #G26#        1522
# 4  {'Main Part': [], 'Benefit': []}      #G26#        1523
#
#                                          Second Text  \
# 0  As an archivist, I want to mark individual fil...
# 1  As an archivist, I want to mark groups of file...
# 2  As an archivist, I want to restrict a file fro...
# 3  As an archivist, I want to restrict a group of...
# 4  As an archivist, I want to set a date on which...
#
#                                     Second Main Part  \
# 0  As an archivist, I want to mark individual fil...
# 1  As an archivist, I want to mark groups of file...
# 2  #G26# As an archivist, I want to restrict a fi...
# 3  #G26# As an archivist, I want to restrict a gr...
# 4  As an archivist, I want to set a date on which...
#
#                         Second Benefit  \
# 0     they don't get shared by mistake
# 1     they don't get shared by mistake
# 2
# 3
# 4  I don't have to update this by hand
#
#                                      Second Triggers  \
# 0  {'Main Part': [['archivist', 'mark']], 'Benefi...
# 1  {'Main Part': [['archivist', 'mark']], 'Benefi...
# 2  {'Main Part': [['archivist', 'restrict']], 'Be...
# 3  {'Main Part': [['archivist', 'restrict']], 'Be...
# 4  {'Main Part': [['archivist', 'set']], 'Benefit...
#
#                                       Second Targets  \
# 0  {'Main Part': [['mark', 'individual files']], ...
# 1  {'Main Part': [['mark', 'groups']], 'Benefit':...
# 2  {'Main Part': [['restrict', 'file']], 'Benefit...
# 3  {'Main Part': [['restrict', 'group']], 'Benefi...
# 4  {'Main Part': [['set', 'date']], 'Benefit': [[...
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [['groups', 'files']], 'Benefit'...
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['group', 'files']], 'Benefit':...
# 4  {'Main Part': [], 'Benefit': [['file', 'restri...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G26] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g26_pairs, key=ID_G26, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g26_pairs, key=ID_G26, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G27

# %%
ID_G27: str = "g27"
data_g27: list = datasets[ID_G27]
df_g27: pd.DataFrame = transform_2_dataframe(data_g27)
df_g27_pairs = transform_pairwise(df_g27)

# %%
datasets[ID_G27][0]
# Out:
# {'PID': '#G27#',
#  'USID': '1618',
#  'Text': 'As a faculty member, I want to access a collection within the repository, so that I can obtain research materials.',
#  'Main Part': 'As a faculty member, I want to access a collection within the repository',
#  'Benefit': 'I can obtain research materials',
#  'Triggers': {'Main Part': [['faculty member', 'access']], 'Benefit': []},
#  'Targets': {'Main Part': [['access', 'collection']],
#   'Benefit': [['obtain', 'research materials']]},
#  'Contains': {'Main Part': [['repository', 'collection']], 'Benefit': []}}

# %%
display(df_g27.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G27#  1618  As a faculty member, I want to access a collec...
# 1  #G27#  1619  As a faculty member, I want to direct students...
# 2  #G27#  1620  As a Cornell faculty member, I want to upload ...
# 3  #G27#  1621  As a patron, I want to know which reports/data...
# 4  #G27#  1622  As a patron, I want to select/deselect reports...
#
#                                            Main Part  \
# 0  As a faculty member, I want to access a collec...
# 1  As a faculty member, I want to direct students...
# 2  As a Cornell faculty member, I want to upload ...
# 3  As a patron, I want to know which reports/data...
# 4  #G27# As a patron, I want to select/deselect r...
#
#                                              Benefit  \
# 0                    I can obtain research materials
# 1  I can facilitate my teaching (i.e. desires abi...
# 2  I receive attribution for my data as well as m...
# 3                 I can access latest report/dataset
# 4
#
#                                             Triggers  \
# 0  {'Main Part': [['faculty member', 'access']], ...
# 1  {'Main Part': [['faculty member', 'direct']], ...
# 2  {'Main Part': [['Cornell faculty member', 'upl...
# 3  {'Main Part': [['patron', 'know']], 'Benefit':...
# 4  {'Main Part': [['patron', 'select'], ['patron'...
#
#                                              Targets  \
# 0  {'Main Part': [['access', 'collection']], 'Ben...
# 1  {'Main Part': [['direct', 'students']], 'Benef...
# 2  {'Main Part': [['upload', 'data'], ['associate...
# 3  {'Main Part': [['know', 'reports'], ['know', '...
# 4  {'Main Part': [['select', 'reports'], ['select...
#
#                                             Contains
# 0  {'Main Part': [['repository', 'collection']], ...
# 1  {'Main Part': [['students', 'item']], 'Benefit...
# 2  {'Main Part': [], 'Benefit': [['repository', '...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['reports', 'new versions'], ['...

# %%
display(df_g27_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G27#       1618  As a faculty member, I want to access a collec...
# 1     #G27#       1618  As a faculty member, I want to access a collec...
# 2     #G27#       1618  As a faculty member, I want to access a collec...
# 3     #G27#       1618  As a faculty member, I want to access a collec...
# 4     #G27#       1618  As a faculty member, I want to access a collec...
#
#                                      First Main Part  \
# 0  As a faculty member, I want to access a collec...
# 1  As a faculty member, I want to access a collec...
# 2  As a faculty member, I want to access a collec...
# 3  As a faculty member, I want to access a collec...
# 4  As a faculty member, I want to access a collec...
#
#                      First Benefit  \
# 0  I can obtain research materials
# 1  I can obtain research materials
# 2  I can obtain research materials
# 3  I can obtain research materials
# 4  I can obtain research materials
#
#                                       First Triggers  \
# 0  {'Main Part': [['faculty member', 'access']], ...
# 1  {'Main Part': [['faculty member', 'access']], ...
# 2  {'Main Part': [['faculty member', 'access']], ...
# 3  {'Main Part': [['faculty member', 'access']], ...
# 4  {'Main Part': [['faculty member', 'access']], ...
#
#                                        First Targets  \
# 0  {'Main Part': [['access', 'collection']], 'Ben...
# 1  {'Main Part': [['access', 'collection']], 'Ben...
# 2  {'Main Part': [['access', 'collection']], 'Ben...
# 3  {'Main Part': [['access', 'collection']], 'Ben...
# 4  {'Main Part': [['access', 'collection']], 'Ben...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [['repository', 'collection']], ...      #G27#        1619
# 1  {'Main Part': [['repository', 'collection']], ...      #G27#        1620
# 2  {'Main Part': [['repository', 'collection']], ...      #G27#        1621
# 3  {'Main Part': [['repository', 'collection']], ...      #G27#        1622
# 4  {'Main Part': [['repository', 'collection']], ...      #G27#        1623
#
#                                          Second Text  \
# 0  As a faculty member, I want to direct students...
# 1  As a Cornell faculty member, I want to upload ...
# 2  As a patron, I want to know which reports/data...
# 3  As a patron, I want to select/deselect reports...
# 4  As a DB/IR administrator, I want to mark repor...
#
#                                     Second Main Part  \
# 0  As a faculty member, I want to direct students...
# 1  As a Cornell faculty member, I want to upload ...
# 2  As a patron, I want to know which reports/data...
# 3  #G27# As a patron, I want to select/deselect r...
# 4  #G27# As a DB/IR administrator, I want to mark...
#
#                                       Second Benefit  \
# 0  I can facilitate my teaching (i.e. desires abi...
# 1  I receive attribution for my data as well as m...
# 2                 I can access latest report/dataset
# 3
# 4
#
#                                      Second Triggers  \
# 0  {'Main Part': [['faculty member', 'direct']], ...
# 1  {'Main Part': [['Cornell faculty member', 'upl...
# 2  {'Main Part': [['patron', 'know']], 'Benefit':...
# 3  {'Main Part': [['patron', 'select'], ['patron'...
# 4  {'Main Part': [['DB/IR administrator', 'mark']...
#
#                                       Second Targets  \
# 0  {'Main Part': [['direct', 'students']], 'Benef...
# 1  {'Main Part': [['upload', 'data'], ['associate...
# 2  {'Main Part': [['know', 'reports'], ['know', '...
# 3  {'Main Part': [['select', 'reports'], ['select...
# 4  {'Main Part': [['mark', 'report'], ['mark', 'd...
#
#                                      Second Contains
# 0  {'Main Part': [['students', 'item']], 'Benefit...
# 1  {'Main Part': [], 'Benefit': [['repository', '...
# 2                   {'Main Part': [], 'Benefit': []}
# 3  {'Main Part': [['reports', 'new versions'], ['...
# 4  {'Main Part': [['report', 'error'], ['dataset'...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G27] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g27_pairs, key=ID_G27, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g27_pairs, key=ID_G27, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G28

# %%
ID_G28: str = "g28"
data_g28: list = datasets[ID_G28]
df_g28: pd.DataFrame = transform_2_dataframe(data_g28)
df_g28_pairs = transform_pairwise(df_g28)

# %%
datasets[ID_G28][0]
# Out:
# {'PID': '#G28#',
#  'USID': '1733',
#  'Text': 'As a user, I want to search and discover music using content identification or fingerprinting.',
#  'Main Part': '#G28# As a user, I want to search and discover music using content identification or fingerprinting.',
#  'Benefit': '',
#  'Triggers': {'Main Part': [['user', 'search'], ['user', 'discover']],
#   'Benefit': []},
#  'Targets': {'Main Part': [['search', 'music'], ['discover', 'music']],
#   'Benefit': [['using', 'content identification'],
#    ['using', 'fingerprinting']]},
#  'Contains': {'Main Part': [], 'Benefit': []}}

# %%
display(df_g28.head(5))
# Out:
#      PID  USID                                               Text  \
# 0  #G28#  1733  As a user, I want to search and discover music...
# 1  #G28#  1734  As a user, I want to search and discover music...
# 2  #G28#  1735  As a user, I want to search and discover music...
# 3  #G28#  1736  As a user, I want to search and discover music...
# 4  #G28#  1737  As a user, I want to search and discover music...
#
#                                            Main Part  \
# 0  #G28# As a user, I want to search and discover...
# 1  #G28# As a user, I want to search and discover...
# 2  #G28# As a user, I want to search and discover...
# 3  #G28# As a user, I want to search and discover...
# 4  As a user, I want to search and discover music...
#
#                                              Benefit  \
# 0
# 1
# 2
# 3
# 4  I find related artists, new genre, or other re...
#
#                                             Triggers  \
# 0  {'Main Part': [['user', 'search'], ['user', 'd...
# 1  {'Main Part': [['user', 'search'], ['user', 'd...
# 2  {'Main Part': [['user', 'search'], ['user', 'd...
# 3  {'Main Part': [['user', 'search'], ['user', 'd...
# 4  {'Main Part': [['user', 'search'], ['user', 'd...
#
#                                              Targets  \
# 0  {'Main Part': [['search', 'music'], ['discover...
# 1  {'Main Part': [['search', 'music'], ['discover...
# 2  {'Main Part': [['discover', 'music'], ['search...
# 3  {'Main Part': [['discover', 'music'], ['discov...
# 4  {'Main Part': [['search', 'music'], ['discover...
#
#                                             Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1                   {'Main Part': [], 'Benefit': []}
# 2  {'Main Part': [['other users similar to myself...
# 3  {'Main Part': [], 'Benefit': [['given music vi...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g28_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G28#       1733  As a user, I want to search and discover music...
# 1     #G28#       1733  As a user, I want to search and discover music...
# 2     #G28#       1733  As a user, I want to search and discover music...
# 3     #G28#       1733  As a user, I want to search and discover music...
# 4     #G28#       1733  As a user, I want to search and discover music...
#
#                                      First Main Part First Benefit  \
# 0  #G28# As a user, I want to search and discover...
# 1  #G28# As a user, I want to search and discover...
# 2  #G28# As a user, I want to search and discover...
# 3  #G28# As a user, I want to search and discover...
# 4  #G28# As a user, I want to search and discover...
#
#                                       First Triggers  \
# 0  {'Main Part': [['user', 'search'], ['user', 'd...
# 1  {'Main Part': [['user', 'search'], ['user', 'd...
# 2  {'Main Part': [['user', 'search'], ['user', 'd...
# 3  {'Main Part': [['user', 'search'], ['user', 'd...
# 4  {'Main Part': [['user', 'search'], ['user', 'd...
#
#                                        First Targets  \
# 0  {'Main Part': [['search', 'music'], ['discover...
# 1  {'Main Part': [['search', 'music'], ['discover...
# 2  {'Main Part': [['search', 'music'], ['discover...
# 3  {'Main Part': [['search', 'music'], ['discover...
# 4  {'Main Part': [['search', 'music'], ['discover...
#
#                      First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': []}      #G28#        1734
# 1  {'Main Part': [], 'Benefit': []}      #G28#        1735
# 2  {'Main Part': [], 'Benefit': []}      #G28#        1736
# 3  {'Main Part': [], 'Benefit': []}      #G28#        1737
# 4  {'Main Part': [], 'Benefit': []}      #G28#        1738
#
#                                          Second Text  \
# 0  As a user, I want to search and discover music...
# 1  As a user, I want to search and discover music...
# 2  As a user, I want to search and discover music...
# 3  As a user, I want to search and discover music...
# 4  As a user, I want to upload tagged videos and ...
#
#                                     Second Main Part  \
# 0  #G28# As a user, I want to search and discover...
# 1  #G28# As a user, I want to search and discover...
# 2  #G28# As a user, I want to search and discover...
# 3  As a user, I want to search and discover music...
# 4  #G28# As a user, I want to upload tagged video...
#
#                                       Second Benefit  \
# 0
# 1
# 2
# 3  I find related artists, new genre, or other re...
# 4
#
#                                      Second Triggers  \
# 0  {'Main Part': [['user', 'search'], ['user', 'd...
# 1  {'Main Part': [['user', 'search'], ['user', 'd...
# 2  {'Main Part': [['user', 'search'], ['user', 'd...
# 3  {'Main Part': [['user', 'search'], ['user', 'd...
# 4  {'Main Part': [['user', 'upload'], ['user', 'h...
#
#                                       Second Targets  \
# 0  {'Main Part': [['search', 'music'], ['discover...
# 1  {'Main Part': [['discover', 'music'], ['search...
# 2  {'Main Part': [['discover', 'music'], ['discov...
# 3  {'Main Part': [['search', 'music'], ['discover...
# 4  {'Main Part': [['upload', 'tagged videos'], ['...
#
#                                      Second Contains
# 0                   {'Main Part': [], 'Benefit': []}
# 1  {'Main Part': [['other users similar to myself...
# 2  {'Main Part': [], 'Benefit': [['given music vi...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [['all further processing steps'...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
# time_recorder = TimeRecorder()
# time_recorders[ID_G28] = time_recorder

# if THREADING:
#     process_user_stories_parallel(index_usid1=1, index_usid2=9, message=message, pairs=df_g28_pairs, key=ID_G28, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
#                                   sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
# else:
#     process_user_stories(index_usid1=1, index_usid2=9, message=message, pairs=df_g28_pairs, key=ID_G28, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
#                          json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Save total Speeds

# %%
SHEET_NAME = 'Time Consup. Anlys.S.'

# %%
base_path: str = os.getcwd()
path_to_file = os.path.join(base_path, "results")
path_to_file = os.path.join(path_to_file, "redundancy-model-" + MODEL_VERSION_NAME)

count_runs_per_data_set: dict[str, int] = {}
for key in time_recorders.keys():
        idx = 0
        _ =  f"{idx:02d}_{key}.json"
        while os.path.exists(os.path.join(path_to_file, f"{idx:02d}_{key}.json")):
                idx += 1
        count_runs_per_data_set[key] = idx

entries: list[tuple[int,str,str, int, float, float, float]] = []

entry: tuple[int,str,str, int, float, float, float] = None
for key, value in time_recorders.items():
        entry = (key, count_runs_per_data_set[key], MODEL_VERSION_NAME, str(THREADING).lower(), 
                 value.nanoseconds, value.milliseconds, value.seconds, value.minutes)
        entries.append(entry)

columns = ['Dataset', 'Run Count', 'Model Version', 'Threading Enabled', 
           'Nanoseconds', 'Milliseconds', 'Seconds', 'Minutes']

_file_path: str = os.path.join(base_path, os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))
check = os.path.exists(_file_path)

old_time_consuption_data: pd.DataFrame = None
if check:
        try:
                old_time_consuption_data = pd.read_excel(_file_path, SHEET_NAME)
        except ValueError:
                check = False
           
time_consumption_data: pd.DataFrame = pd.DataFrame(entries, columns=columns)

if check and not old_time_consuption_data.empty:
        # Checking if in the excel is already the data. Case: this code is executed twice for the same data
        old_time_consuption_data = old_time_consuption_data.dropna()
        for idx in range(len(old_time_consuption_data)):
                condition = time_consumption_data[
                        (time_consumption_data['Dataset'] == old_time_consuption_data.iat[idx, 0]) & 
                        (time_consumption_data['Run Count'] == old_time_consuption_data.iat[idx, 1])
                ].index
                time_consumption_data = time_consumption_data.drop(condition).reset_index(drop=True)
        time_consumption_data = pd.concat([old_time_consuption_data, time_consumption_data]).reset_index(drop=True)

# %%
def formatter_time(wb: Workbook, sheet_name: str): 
    ws = wb[sheet_name]
    header_font = Font(size=14, bold=True)
    for cell in ws["1:1"]:
        cell.font = header_font
    
    ADDITIONAL_LENGTH: int = 0
    ADJUSTED_WIDTH: int = 0
    MAX_LEN: int = 0
    for col in ws.iter_cols(min_row=1, max_row=1):
        for cell in col:
            MAX_LEN = len(str(cell.value))
            ADDITIONAL_LENGTH = (MAX_LEN + 2)
            ADJUSTED_WIDTH = 0
            ADJUSTED_WIDTH =  ADDITIONAL_LENGTH * 1.5
            ws.column_dimensions[utils_get_column_letter(cell.column)].width = ADJUSTED_WIDTH
            
    alignment = Alignment(vertical='center', horizontal='left')
    for row in ws.iter_rows():
        for cell in row:
            cell.alignment = alignment

    num_columns = ws.max_column
    header_range = f"A1:{utils_get_column_letter(num_columns)}1"
    ws.auto_filter.ref = header_range
    ws.freeze_panes = ws['A2']

    wrap_alignment = Alignment(wrap_text=True, vertical='top', horizontal='left')
    for row in ws.iter_rows(min_row=2):
        for cell in row:
            cell.alignment = wrap_alignment

# %%
save_to_excel(time_consumption_data, formatter_time, SHEET_NAME, os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))

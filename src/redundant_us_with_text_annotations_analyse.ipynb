# %% [markdown]
# # Analysing the redundancies of User Stories - Annotations and US Text

# %%
import locale
import os, json
from itertools import combinations

import pandas as pd
import tiktoken
from openpyxl import Workbook
from openpyxl.styles import Alignment, Font
from openpyxl.utils import get_column_letter as utils_get_column_letter

from prompt_structure.helper_prompt_composition import PromptHelperBuilder
from prompt_structure.prompt_builder import PromptBuilder
from support_functions.excel_helper import save_to_excel, formatter_ignored_items
from support_functions.load_data import load_datasets_with_annotations as loading
from support_functions.request_handler import process_user_stories, process_user_stories_parallel
from support_functions.data_transformations import convert_annotation_dataset
from support_functions.time_recorder import TimeRecorder
from support_functions.json_validator import validation, chat_gpt_schema_with_annotations

# %%
locale.setlocale(locale.LC_ALL, 'de_DE') 
MODEL_VERSION_NAME = os.getenv('MODEL_VERSION')
THREADING = bool(int(os.getenv('THREADING')))
print(f"Threading is used: {THREADING}")
print(MODEL_VERSION_NAME)
# Out:
# Threading is used: True
# gpt-3.5-turbo

# %%
time_recorders: dict = {}
time_recorder: TimeRecorder = None

# %% [markdown]
# ### Load all User Stories from the different packages
#
# We use here Text and it split and the annotations (formatted):
# - Text
# - Main Part
# - Benefit
# - Triggers
# - Targets
# - Contains
#
# We do not need:
# - POS
#
# Irgnored Files as they differer from the common structure [Ref](https://github.com/ace-design/nlp-stories/tree/main?tab=readme-ov-file#note):
# - g02-federal-funding
# - g13-planningpoker
# - g17-cask
# - g27-culrepo
#
# Ignored Files as they were used as trainings data
# - g05
# - g12
#
# Data sets to analyse:
# - 'g03', 'g04', 'g08', 'g10', 'g11', 'g14', 'g16', 'g18', 'g19', 'g21', 'g22', 'g23', 'g24', 'g25', 'g26', 'g28'
#
# Used Data:
# - "nlp" --> "nlp_outputs" --> "individual_backlog" --> "nlp_outputs_original" --> "pos_baseline"
#
# Highlighting words with #

# %%
not_processed_datasets: dict[str, list] = loading()
print(not_processed_datasets["g02"][0])
# Out:
# {'PID': '#G02#', 'Text': '#G02# As a Data user, I want to have the 12-19-2017 deletions processed.', 'Persona': ['Data user'], 'Action': {'Primary Action': ['have'], 'Secondary Action': ['processed']}, 'Entity': {'Primary Entity': ['12-19-2017 deletions'], 'Secondary Entity': ['']}, 'Benefit': '', 'Triggers': [['Data user', 'have']], 'Targets': [['processed', '12-19-2017 deletions'], ['have', '12-19-2017 deletions']], 'Contains': [], 'Persona POS': {'Persona POS tag': [['NOUN', 'NOUN']], 'Persona POS text': [['Data', 'user']]}, 'Action POS': {'Primary Action POS': {'Primary Action POS tag': [['VERB']], 'Primary Action POS text': [['have']]}, 'Secondary Action POS': {'Secondary Action POS tag': [['VERB']], 'Secondary Action POS text': [['processed']]}}, 'Entity POS': {'Primary Entity POS': {'Primary Entity POS tag': [['NUM', 'NOUN']], 'Primary Entity POS text': [['12-19-2017', 'deletions']]}, 'Secondary Entity POS': {'Secondary Entity POS tag': [[]], 'Secondary Entity POS text': [[]]}}}

# %% [markdown]
# ### Converting Data to used suited format

# %%
datasets, ignored_items = convert_annotation_dataset(not_processed_datasets)

# %%
datasets.keys()
# Out:
# dict_keys(['g02', 'g03', 'g04', 'g05', 'g08', 'g10', 'g11', 'g12', 'g13', 'g14', 'g16', 'g17', 'g18', 'g19', 'g21', 'g22', 'g23', 'g24', 'g25', 'g26', 'g27', 'g28'])

# %%
datasets["g12"]
# Out:
# [{'PID': '#G12#',
#   'USID': '610',
#   'Text': 'As a camp administrator, I want to be able to add campers, so that I can keep track of each individual camper.',
#   'Main Part': 'As a camp administrator, I want to be able to add campers, ',
#   'Benefit': 'I can keep track of each individual camper',
#   'Triggers': {'Main Part': [['camp administrator', 'add']], 'Benefit': []},
#   'Targets': {'Main Part': [['add', 'campers']],
#    'Benefit': [['keep track', 'individual camper']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '611',
#   'Text': "As a camp administrator, I want to be able to remove campers if they don't attend the camp anymore, so that I can keep the records organized.",
#   'Main Part': "As a camp administrator, I want to be able to remove campers if they don't attend the camp anymore, ",
#   'Benefit': 'I can keep the records organized',
#   'Triggers': {'Main Part': [['camp administrator', 'remove']], 'Benefit': []},
#   'Targets': {'Main Part': [['remove', 'campers']],
#    'Benefit': [['keep', 'records organized']]},
#   'Contains': {'Main Part': [['camp', 'campers']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '612',
#   'Text': 'As a camp administrator, I want to be able to keep camper records from previous years, so that the amount of work I need to do is lowered.',
#   'Main Part': 'As a camp administrator, I want to be able to keep camper records from previous years, ',
#   'Benefit': 'the amount of work I need to do is lowered',
#   'Triggers': {'Main Part': [['camp administrator', 'keep']], 'Benefit': []},
#   'Targets': {'Main Part': [['keep', 'camper records']],
#    'Benefit': [['lowered', 'amount of work']]},
#   'Contains': {'Main Part': [['previous years', 'camper records']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '613',
#   'Text': 'As a camp administrator, I want to be able to upload consent forms, so that campers or their parents can easily access the forms.',
#   'Main Part': 'As a camp administrator, I want to be able to upload consent forms, ',
#   'Benefit': 'campers or their parents can easily access the forms',
#   'Triggers': {'Main Part': [['camp administrator', 'upload']], 'Benefit': []},
#   'Targets': {'Main Part': [['upload', 'consent forms']],
#    'Benefit': [['easily access', 'forms']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '614',
#   'Text': 'As a camp administrator, I want to be able to keep track of which camper submitted which forms, so that legal issues are avoided.',
#   'Main Part': 'As a camp administrator, I want to be able to keep track of which camper submitted which forms, ',
#   'Benefit': 'legal issues are avoided',
#   'Triggers': {'Main Part': [['camp administrator', 'keep track']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['keep track', 'forms']],
#    'Benefit': [['avoided', 'egal issues']]},
#   'Contains': {'Main Part': [['camper', 'forms']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '615',
#   'Text': 'As a camp administrator, I want to be able to schedule activities for campers, so that camp workers can easily keep track of who is where at all times.',
#   'Main Part': 'As a camp administrator, I want to be able to schedule activities for campers, ',
#   'Benefit': 'camp workers can easily keep track of who is where at all times',
#   'Triggers': {'Main Part': [['camp administrator', 'schedule']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['schedule', 'activities']],
#    'Benefit': [['easily keep track', 'campers']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '616',
#   'Text': 'As a camp administrator, I want to be able to automatically create nametags for campers, so that I can lower the amount of work I need to do.',
#   'Main Part': 'As a camp administrator, I want to be able to automatically create nametags for campers, ',
#   'Benefit': 'I can lower the amount of work I need to do',
#   'Triggers': {'Main Part': [['camp administrator', 'automatically create']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['automatically create', 'nametags']],
#    'Benefit': [['lower', 'amount of work']]},
#   'Contains': {'Main Part': [['campers', 'nametags']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '617',
#   'Text': 'As a camp administrator, I want to be able to suspend a camper who had behavioral problems.',
#   'Main Part': 'As a camp administrator, I want to be able to suspend a camper who had behavioral problems.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp administrator', 'suspend']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['suspend', 'camper']], 'Benefit': []},
#   'Contains': {'Main Part': [['camper', 'behavioral problems']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '618',
#   'Text': 'As a camp administrator, I want to be able to set a reminders related to specific tasks that has to be done.',
#   'Main Part': 'As a camp administrator, I want to be able to set a reminders related to specific tasks that has to be done.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp administrator', 'set']], 'Benefit': []},
#   'Targets': {'Main Part': [['set', 'reminders']], 'Benefit': []},
#   'Contains': {'Main Part': [['specific tasks', 'reminders']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '619',
#   'Text': 'As a camp administrator, I want to be able to assign different positions to the staff members, so that it is possible to organize activities in terms of responsibilities.',
#   'Main Part': 'As a camp administrator, I want to be able to assign different positions to the staff members, ',
#   'Benefit': 'it is possible to organize activities in terms of responsibilities',
#   'Triggers': {'Main Part': [['camp administrator', 'assign']], 'Benefit': []},
#   'Targets': {'Main Part': [['assign', 'different positions']],
#    'Benefit': [['organize', 'activities']]},
#   'Contains': {'Main Part': [['staff members', 'different positions']],
#    'Benefit': [['activities', 'responsibilities']]}},
#  {'PID': '#G12#',
#   'USID': '620',
#   'Text': 'As a camp administrator, I want to be able to warn a camp worker who I think did his/her job inappropriate.',
#   'Main Part': 'As a camp administrator, I want to be able to warn a camp worker who I think did his/her job inappropriate.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp administrator', 'warn']], 'Benefit': []},
#   'Targets': {'Main Part': [['warn', 'camp worker']], 'Benefit': []},
#   'Contains': {'Main Part': [['camp worker', 'job inappropriate']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '621',
#   'Text': 'As a camp administrator, I want to be able to create, modify rules that campers and camp workers has to follow.',
#   'Main Part': 'As a camp administrator, I want to be able to create, modify rules that campers and camp workers has to follow.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp administrator', 'create'],
#     ['camp administrator', 'modify']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['create', 'rules'],
#     ['modify', 'rules'],
#     ['follow', 'rules']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '622',
#   'Text': "As a camp administrator, I want to keep track of the usage of internal camp facilities, so that I don't create conflicting schedules for the different camp groups.",
#   'Main Part': 'As a camp administrator, I want to keep track of the usage of internal camp facilities, ',
#   'Benefit': "don't create conflicting schedules for the different camp groups",
#   'Triggers': {'Main Part': [['camp administrator', 'keep track']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['keep track',
#      'usage of internal camp facilities']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '623',
#   'Text': 'As a camp administrator, I want to create an avenue so parents can submit feedback and general concerns, so that I can keep improving the services I provide.',
#   'Main Part': 'As a camp administrator, I want to create an avenue so parents can submit feedback and general concerns, ',
#   'Benefit': 'I can keep improving the services I provide',
#   'Triggers': {'Main Part': [['camp administrator', 'create']], 'Benefit': []},
#   'Targets': {'Main Part': [['create', 'avenue']],
#    'Benefit': [['submit', 'feedback'],
#     ['submit', 'general concerns'],
#     ['keep improving', 'services'],
#     ['provide', 'services']]},
#   'Contains': {'Main Part': [['avenue', 'feedback'],
#     ['avenue', 'general concerns']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '624',
#   'Text': "As a camp administrator, I want to store campers' emergency information in a database, so that I can easily notify the necessary parties in case of an emergency.",
#   'Main Part': "As a camp administrator, I want to store campers' emergency information in a database, ",
#   'Benefit': 'I can easily notify the necessary parties in case of an emergency',
#   'Triggers': {'Main Part': [['camp administrator', 'store']], 'Benefit': []},
#   'Targets': {'Main Part': [['store', "campers' emergency information"]],
#    'Benefit': [['easily notify', 'necessary parties']]},
#   'Contains': {'Main Part': [['database', "campers' emergency information"]],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '625',
#   'Text': "As a camp administrator, I want to store camper's immediate parent/guardian's information, so that I can easily call to notify them in case a grossly unacceptable behavior.",
#   'Main Part': "As a camp administrator, I want to store camper's immediate parent/guardian's information, ",
#   'Benefit': 'I can easily call to notify them in case a grossly unacceptable behavior',
#   'Triggers': {'Main Part': [['camp administrator', 'store']], 'Benefit': []},
#   'Targets': {'Main Part': [['store',
#      "camper's immediate parent/guardian's information"]],
#    'Benefit': [['notify', 'grossly unacceptable behavior']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '626',
#   'Text': "As a camp administrator, I want to provide bi-weekly feedback to camper's parents, so that they can be aware of their child's behavior and performance at camp.",
#   'Main Part': "As a camp administrator, I want to provide bi-weekly feedback to camper's parents, ",
#   'Benefit': "they can be aware of their child's behavior and performance at camp",
#   'Triggers': {'Main Part': [['camp administrator', 'provide']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['provide', 'bi-weekly feedback']],
#    'Benefit': [['aware', "child's behavior"], ['aware', 'performance']]},
#   'Contains': {'Main Part': [["camper's parents", 'bi-weekly feedback']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '627',
#   'Text': "As a camp administrator, I want to be able to make nametags faster, so that I don't have to spend two hours making 200+ nametags",
#   'Main Part': 'As a camp administrator, I want to be able to make nametags faster, ',
#   'Benefit': "I don't have to spend two hours making 200+ nametags",
#   'Triggers': {'Main Part': [['camp administrator', 'make']], 'Benefit': []},
#   'Targets': {'Main Part': [['make', 'nametags']],
#    'Benefit': [['making', '200+ nametags']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '628',
#   'Text': 'As a camp administrator, I want to be able to create a registration form for both staff and kids, so that I can keep organized.',
#   'Main Part': 'As a camp administrator, I want to be able to create a registration form for both staff and kids, ',
#   'Benefit': 'I can keep organized',
#   'Triggers': {'Main Part': [['camp administrator', 'create']], 'Benefit': []},
#   'Targets': {'Main Part': [['create', 'registration form']], 'Benefit': []},
#   'Contains': {'Main Part': [['staff', 'registration form'],
#     ['kids', 'registration form']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '629',
#   'Text': 'As a camp administrator, I want to be able to keep my information in one place, so that the admins next year can improve on the previous years.',
#   'Main Part': 'As a camp administrator, I want to be able to keep my information in one place, ',
#   'Benefit': 'the admins next year can improve on the previous years',
#   'Triggers': {'Main Part': [['camp administrator', 'keep']], 'Benefit': []},
#   'Targets': {'Main Part': [['keep', 'information']],
#    'Benefit': [['improve', 'previous years']]},
#   'Contains': {'Main Part': [['one place', 'information']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '630',
#   'Text': 'As a camp administrator, I want to be able to see medical forms, so that we can be prepared for an allergy attack',
#   'Main Part': 'As a camp administrator, I want to be able to see medical forms, ',
#   'Benefit': 'we can be prepared for an allergy attack',
#   'Triggers': {'Main Part': [['camp administrator', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'medical forms']],
#    'Benefit': [['be prepared', 'allergy attack']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '631',
#   'Text': 'As a camp administrator, I want to be able to notify parents all at once, so that they can be notified of any upcoming events.',
#   'Main Part': 'As a camp administrator, I want to be able to notify parents all at once, ',
#   'Benefit': 'they can be notified of any upcoming events',
#   'Triggers': {'Main Part': [['camp administrator', 'notify']], 'Benefit': []},
#   'Targets': {'Main Part': [['notify', 'parents'],
#     ['notify', 'any upcoming events']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '632',
#   'Text': 'As a camp administrator, I want to be quickly log attendance everyday, so that I can track which kids are coming in.',
#   'Main Part': 'As a camp administrator, I want to be quickly log attendance everyday, ',
#   'Benefit': 'I can track which kids are coming in',
#   'Triggers': {'Main Part': [['camp administrator', 'quickly log']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['quickly log', 'attendance']],
#    'Benefit': [['track', 'kids']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '633',
#   'Text': 'As a camp administrator, I want to be able to add parents, so that they can enroll their kids at camp.',
#   'Main Part': 'As a camp administrator, I want to be able to add parents, ',
#   'Benefit': 'they can enroll their kids at camp',
#   'Triggers': {'Main Part': [['camp administrator', 'add']], 'Benefit': []},
#   'Targets': {'Main Part': [['add', 'parents']],
#    'Benefit': [['enroll', 'kids']]},
#   'Contains': {'Main Part': [], 'Benefit': [['camp', 'kids']]}},
#  {'PID': '#G12#',
#   'USID': '634',
#   'Text': 'As a camp administrator, I want to be able to create groups and add campers to the groups, so that I can easily organize the campers.',
#   'Main Part': 'As a camp administrator, I want to be able to create groups and add campers to the groups, ',
#   'Benefit': 'I can easily organize the campers',
#   'Triggers': {'Main Part': [['camp administrator', 'create'],
#     ['camp administrator', 'add']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['create', 'groups'], ['add', 'campers']],
#    'Benefit': [['easily organize', 'campers']]},
#   'Contains': {'Main Part': [['groups', 'campers']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '635',
#   'Text': 'As a camp administrator, I want to be able to see all my camp groups and the events scheduled for each camp group, so that I can notify counselor of what their group will be doing for the day.',
#   'Main Part': 'As a camp administrator, I want to be able to see all my camp groups and the events scheduled for each camp group, ',
#   'Benefit': 'I can notify counselor of what their group will be doing for the day',
#   'Triggers': {'Main Part': [['camp administrator', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'camp groups'],
#     ['see', 'events scheduled']],
#    'Benefit': [['notify', 'counselor']]},
#   'Contains': {'Main Part': [['each camp group', 'events scheduled']],
#    'Benefit': [['counselor', 'group']]}},
#  {'PID': '#G12#',
#   'USID': '636',
#   'Text': 'As a camp administrator, I want to be able to schedule tasks/activities for a specific camp group, so that I can track each groups daily/weekly and monthly activities.',
#   'Main Part': 'As a camp administrator, I want to be able to schedule tasks/activities for a specific camp group, ',
#   'Benefit': 'I can track each groups daily/weekly and monthly activities',
#   'Triggers': {'Main Part': [['camp administrator', 'schedule']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['schedule', 'tasks'], ['schedule', 'activities']],
#    'Benefit': [['track', 'each groups daily/weekly and monthly activities']]},
#   'Contains': {'Main Part': [['specific camp group', 'activities'],
#     ['specific camp group', 'tasks']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '637',
#   'Text': 'As a camp administrator, I want to be able to delete tasks/activities I scheduled, so that I can keep the schedule clean of unneeded activities.',
#   'Main Part': 'As a camp administrator, I want to be able to delete tasks/activities I scheduled, ',
#   'Benefit': 'I can keep the schedule clean of unneeded activities',
#   'Triggers': {'Main Part': [['camp administrator', 'delete']], 'Benefit': []},
#   'Targets': {'Main Part': [['delete', 'tasks'], ['delete', 'activities']],
#    'Benefit': [['keep', 'schedule']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['schedule', 'clean of unneeded activities']]}},
#  {'PID': '#G12#',
#   'USID': '638',
#   'Text': 'As a camp administrator, I want to be able to modify tasks/events I scheduled in case there is a change, so that I can always keep the schedule up to date.',
#   'Main Part': 'As a camp administrator, I want to be able to modify tasks/events I scheduled in case there is a change, ',
#   'Benefit': 'I can always keep the schedule up to date',
#   'Triggers': {'Main Part': [['camp administrator', 'modify']], 'Benefit': []},
#   'Targets': {'Main Part': [['modify', 'tasks'], ['modify', 'events']],
#    'Benefit': [['always keep', 'schedule up to date']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '639',
#   'Text': 'As a camp administrator, I want to be able to modify the information of enrolled campers, so that I can keep the campers information up to date.',
#   'Main Part': 'As a camp administrator, I want to be able to modify the information of enrolled campers, ',
#   'Benefit': 'I can keep the campers information up to date',
#   'Triggers': {'Main Part': [['camp administrator', 'modify']], 'Benefit': []},
#   'Targets': {'Main Part': [['modify', 'information']],
#    'Benefit': [['keep', 'campers information up to date']]},
#   'Contains': {'Main Part': [['enrolled campers', 'information']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '640',
#   'Text': 'As a camp administrator, I want to be able to delete campers from the database, so that I can keep my pages free of clutter.',
#   'Main Part': 'As a camp administrator, I want to be able to delete campers from the database, ',
#   'Benefit': 'I can keep my pages free of clutter',
#   'Triggers': {'Main Part': [['camp administrator', 'delete']], 'Benefit': []},
#   'Targets': {'Main Part': [['delete', 'campers']],
#    'Benefit': [['keep', 'pages']]},
#   'Contains': {'Main Part': [['database', 'campers']],
#    'Benefit': [['pages', 'free of clutter']]}},
#  {'PID': '#G12#',
#   'USID': '641',
#   'Text': "As a camp administrator, I want to be able to modify the information of added parents, so that I can keep parent's information up to date.",
#   'Main Part': 'As a camp administrator, I want to be able to modify the information of added parents, ',
#   'Benefit': "I can keep parent's information up to date",
#   'Triggers': {'Main Part': [['camp administrator', 'modify']], 'Benefit': []},
#   'Targets': {'Main Part': [['modify', 'information']],
#    'Benefit': [['keep', "parent's information up to date"]]},
#   'Contains': {'Main Part': [['added parents', 'information']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '642',
#   'Text': 'As a camp administrator, I want to be able to delete parents from the database, so that I can keep my pages free of unneeded clutter.',
#   'Main Part': 'As a camp administrator, I want to be able to delete parents from the database, ',
#   'Benefit': 'I can keep my pages free of unneeded clutter',
#   'Triggers': {'Main Part': [['camp administrator', 'delete']], 'Benefit': []},
#   'Targets': {'Main Part': [['delete', 'parents']],
#    'Benefit': [['keep', 'pages']]},
#   'Contains': {'Main Part': [['database', 'parents']],
#    'Benefit': [['pages', 'free of unneeded clutter']]}},
#  {'PID': '#G12#',
#   'USID': '643',
#   'Text': "As a camp administrator, I want to be able to modify a group's information, so that I can keep the groups up to date.",
#   'Main Part': "As a camp administrator, I want to be able to modify a group's information, ",
#   'Benefit': 'I can keep the groups up to date',
#   'Triggers': {'Main Part': [['camp administrator', 'modify']], 'Benefit': []},
#   'Targets': {'Main Part': [['modify', "group's information"]],
#    'Benefit': [['keep', 'groups up to date']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '644',
#   'Text': 'As a camp administrator, I want to be able to see only events for a specific group/groups on the event calendar, so that I can easily read the data on the calendar without too much clutter.',
#   'Main Part': 'As a camp administrator, I want to be able to see only events for a specific group/groups on the event calendar, ',
#   'Benefit': 'I can easily read the data on the calendar without too much clutter',
#   'Triggers': {'Main Part': [['camp administrator', 'see only']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['see only', 'events']],
#    'Benefit': [['easily read', 'data']]},
#   'Contains': {'Main Part': [['events', 'specific group'],
#     ['events', 'groups'],
#     ['event calendar', 'events']],
#    'Benefit': [['calendar', 'data']]}},
#  {'PID': '#G12#',
#   'USID': '645',
#   'Text': 'As a parent, I want to be able to see which consent forms I have submitted, so that I can know what I still need to do.',
#   'Main Part': 'As a parent, I want to be able to see which consent forms I have submitted, ',
#   'Benefit': 'I can know what I still need to do',
#   'Triggers': {'Main Part': [['parent', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'consent forms I have submitted']],
#    'Benefit': [['know', 'what'], ['do', 'what']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '646',
#   'Text': "As a parent, I want to be able to track my child's activity and schedule at camp, so that I can have peace of mind.",
#   'Main Part': "As a parent, I want to be able to track my child's activity and schedule at camp, ",
#   'Benefit': 'I can have peace of mind',
#   'Triggers': {'Main Part': [['parent', 'track']], 'Benefit': []},
#   'Targets': {'Main Part': [['track', "child's activity"],
#     ['track', 'schedule']],
#    'Benefit': [['have', 'peace of mind']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '647',
#   'Text': 'As a parent, I want to be able to submit various type of forms to the camp management.',
#   'Main Part': 'As a parent, I want to be able to submit various type of forms to the camp management.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['parent', 'submit']], 'Benefit': []},
#   'Targets': {'Main Part': [['submit', 'various type of forms']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '648',
#   'Text': 'As a parent, I want to be able to create an account, so that I can sign up my kids for camp online.',
#   'Main Part': 'As a parent, I want to be able to create an account, ',
#   'Benefit': 'I can sign up my kids for camp online',
#   'Triggers': {'Main Part': [['parent', 'create']], 'Benefit': []},
#   'Targets': {'Main Part': [['create', 'account']],
#    'Benefit': [['sign up', 'kids']]},
#   'Contains': {'Main Part': [], 'Benefit': [['camp', 'kids']]}},
#  {'PID': '#G12#',
#   'USID': '649',
#   'Text': 'As a parent, I want to see which counselors are assigned to my kids, so that I can have peace of mind.',
#   'Main Part': 'As a parent, I want to see which counselors are assigned to my kids, ',
#   'Benefit': 'I can have peace of mind',
#   'Triggers': {'Main Part': [['parent', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'counselors']],
#    'Benefit': [['have', 'peace of mind']]},
#   'Contains': {'Main Part': [['counselors', 'kids']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '650',
#   'Text': "As a parent, I want to be able to message my child's counselors, so that I can voice my concerns or check on my child's progress.",
#   'Main Part': "As a parent, I want to be able to message my child's counselors, ",
#   'Benefit': "I can voice my concerns or check on my child's progress",
#   'Triggers': {'Main Part': [['parent', 'message']], 'Benefit': []},
#   'Targets': {'Main Part': [['message', "child's counselors"]],
#    'Benefit': [['voice', 'concerns'], ['check', "child's progress"]]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '651',
#   'Text': "As a parent, I want to be able to sign and submit consent forms online, so that I don't have to deal with my child losing a consent form.",
#   'Main Part': 'As a parent, I want to be able to sign and submit consent forms online, ',
#   'Benefit': "I don't have to deal with my child losing a consent form",
#   'Triggers': {'Main Part': [['parent', 'sign'], ['parent', 'submit']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['submit', 'consent forms online'],
#     ['sign', 'consent forms online']],
#    'Benefit': [['losing', 'consent form']]},
#   'Contains': {'Main Part': [], 'Benefit': [['child', 'consent form']]}},
#  {'PID': '#G12#',
#   'USID': '652',
#   'Text': 'As a parent, I want to be able to see if I made all the necessary payments.',
#   'Main Part': 'As a parent, I want to be able to see if I made all the necessary payments.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['parent', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'necessary payments'],
#     ['made', 'necessary payments']],
#    'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '653',
#   'Text': 'As a parent, I want to be able to share any photos the camp has taken of my child.',
#   'Main Part': 'As a parent, I want to be able to share any photos the camp has taken of my child.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['parent', 'share']], 'Benefit': []},
#   'Targets': {'Main Part': [['share', 'any photos']], 'Benefit': []},
#   'Contains': {'Main Part': [['camp', 'any photos'], ['any photos', 'child']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '654',
#   'Text': 'As a parent, I want to be able to connect with the staff in case of an emergency.',
#   'Main Part': 'As a parent, I want to be able to connect with the staff in case of an emergency.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['parent', 'connect']], 'Benefit': []},
#   'Targets': {'Main Part': [['connect', 'staff']], 'Benefit': []},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '655',
#   'Text': 'As a parent, I want to be able to enroll my children, so that they can be admitted to camp.',
#   'Main Part': 'As a parent, I want to be able to enroll my children, ',
#   'Benefit': 'they can be admitted to camp',
#   'Triggers': {'Main Part': [['parent', 'enroll']], 'Benefit': []},
#   'Targets': {'Main Part': [['enroll', 'children']],
#    'Benefit': [['admitted', 'camp']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '656',
#   'Text': 'As a parent, I want to be able to see and edit my enrolled children to the camp year, so that I can know who I already enrolled to camp, who is still pending admission etc.',
#   'Main Part': 'As a parent, I want to be able to see and edit my enrolled children to the camp year, ',
#   'Benefit': 'I can know who I already enrolled to camp, who is still pending admission etc',
#   'Triggers': {'Main Part': [['parent', 'see'], ['parent', 'edit']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['see', 'enrolled children'],
#     ['edit', 'enrolled children']],
#    'Benefit': [['already enrolled', 'camp'],
#     ['still pending', 'admission'],
#     ['know', 'who'],
#     ['know', 'who']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '657',
#   'Text': 'As a parent, I want to be able to see a schedule of the activities my children are involved in at camp, so that I can be more informed as to what they are doing at camp.',
#   'Main Part': 'As a parent, I want to be able to see a schedule of the activities my children are involved in at camp, ',
#   'Benefit': 'I can be more informed as to what they are doing at camp',
#   'Triggers': {'Main Part': [['parent', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'schedule']],
#    'Benefit': [['be more informed', 'children'],
#     ['be more informed', 'activities']]},
#   'Contains': {'Main Part': [['schedule', 'activities']],
#    'Benefit': [['camp', 'activities'], ['camp', 'children']]}},
#  {'PID': '#G12#',
#   'USID': '658',
#   'Text': 'As a camp worker, I want to be able to see which campers I am in charge of and where, so that I can make sure I am doing my job properly.',
#   'Main Part': 'As a camp worker, I want to be able to see which campers I am in charge of and where, ',
#   'Benefit': 'I can make sure I am doing my job properly',
#   'Triggers': {'Main Part': [['camp worker', 'see']], 'Benefit': []},
#   'Targets': {'Main Part': [['see', 'campers I am in charge of']],
#    'Benefit': [['doing', 'job']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '659',
#   'Text': 'As a camp worker, I would be able to submit a completion report for the tasks which was assigned to me.',
#   'Main Part': 'As a camp worker, I would be able to submit a completion report for the tasks which was assigned to me.',
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp worker', 'submit']], 'Benefit': []},
#   'Targets': {'Main Part': [['submit', 'completion report']], 'Benefit': []},
#   'Contains': {'Main Part': [['tasks', 'completion report']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '660',
#   'Text': "As a camp worker, I'm able to report a camper to the manager with an inappropriate behavior.",
#   'Main Part': "As a camp worker, I'm able to report a camper to the manager with an inappropriate behavior.",
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp worker', 'report']], 'Benefit': []},
#   'Targets': {'Main Part': [['report', 'camper']], 'Benefit': []},
#   'Contains': {'Main Part': [['camper', 'inappropriate behavior']],
#    'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '661',
#   'Text': "As a camp worker, I'm able to report a list of supplies to the manager that the camp is short of.",
#   'Main Part': "As a camp worker, I'm able to report a list of supplies to the manager that the camp is short of.",
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp worker', 'report']], 'Benefit': []},
#   'Targets': {'Main Part': [['report', 'list']], 'Benefit': []},
#   'Contains': {'Main Part': [['list', 'supplies'], ['manager', 'list']],
#    'Benefit': [['camp', 'supplies']]}},
#  {'PID': '#G12#',
#   'USID': '662',
#   'Text': "As a camp worker, I'm able to report necessary repairs to the manager that the camp is needed of.",
#   'Main Part': "As a camp worker, I'm able to report necessary repairs to the manager that the camp is needed of.",
#   'Benefit': '',
#   'Triggers': {'Main Part': [['camp worker', 'report']], 'Benefit': []},
#   'Targets': {'Main Part': [['report', 'necessary repairs']], 'Benefit': []},
#   'Contains': {'Main Part': [['camp', 'necessary repairs']], 'Benefit': []}},
#  {'PID': '#G12#',
#   'USID': '663',
#   'Text': 'As a camp counselor, I want to be able to take attendance of my assigned kids, so that I can make ensure everybody is accounted for.',
#   'Main Part': 'As a camp counselor, I want to be able to take attendance of my assigned kids, ',
#   'Benefit': 'I can make ensure everybody is accounted for',
#   'Triggers': {'Main Part': [['camp counselor', 'take']], 'Benefit': []},
#   'Targets': {'Main Part': [['take', 'attendance']],
#    'Benefit': [['accounted', 'everybody']]},
#   'Contains': {'Main Part': [['attendance', 'assigned kids']], 'Benefit': []}}]

# %%
ignored_items["#G02#"][0]
# Out:
# 'PID: #G02#; Text: As a UI designer, I want to redesign the Resources page, so that it matches the new Broker design styles.; Label Type: Contain'

# %%
df_ignored_items: pd.DataFrame = None
if True:            
    cols: list[str] =  ["PID", "Text", "Label Type"]
    df_ignored_items = pd.DataFrame(columns=cols)
    current_ignored_data: dict = {}
    curremt_pid: int = 0
    current_text: str = "" 
    for key, set in ignored_items.items():
        for item in set:
            parts = item.split('; ')
            for part in parts:
                key, value = part.split(': ', 1)
                current_ignored_data[key] = value
            df_ignored_items = pd.concat([df_ignored_items, pd.DataFrame([current_ignored_data])], ignore_index = True)               
            df_ignored_items.reset_index()
    save_to_excel(df_ignored_items, formatter_ignored_items, "Incomplete US labelling", os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))
print(f"Count of ignored Elements: {df_ignored_items.shape[0]}")
df_ignored_items.head()
# Out:
# Count of ignored Elements: 187
#      PID                                               Text Label Type
# 0  #G02#  As a UI designer, I want to redesign the Resou...    Contain
# 1  #G02#  As a UI designer, I want to track the issues t...     Target
# 2  #G02#  As a UI designer, I want to track the issues t...     Target
# 3  #G02#  As a UI designer, I want to track the issues t...     Target
# 4  #G02#  As an agency user, I want to submit my data el...    Contain

# %% [markdown]
# ### Datatransformation to panda dataframes and numpy arrarys.

# %%
def transform_2_dataframe(data: list):
    rows = []
    for entry in data:
        row = {
            "PID": entry["PID"],
            "USID": entry["USID"],
            "Text": entry["Text"],
            "Main Part": entry["Main Part"],
            "Benefit": entry["Benefit"],
            "Triggers": entry["Triggers"],
            "Targets": entry["Targets"],
            "Contains": entry["Contains"],
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
# n(n-1) / 2
def transform_pairwise(df: pd.DataFrame):
    rows = []
    for i, j in combinations(range(df.shape[0]), 2):
        row = {
            "First PID": df.iloc[i, 0],
            "First USID": df.iloc[i, 1],
            "First Text": df.iloc[i, 2],
            "First Main Part": df.iloc[i, 3],
            "First Benefit": df.iloc[i, 4],
            "First Triggers": df.iloc[i, 5],
            "First Targets": df.iloc[i, 6],
            "First Contains": df.iloc[i, 7],
            "Second PID": df.iloc[j, 0],
            "Second USID": df.iloc[j, 1],
            "Second Text": df.iloc[j, 2],
            "Second Main Part": df.iloc[j, 3],
            "Second Benefit": df.iloc[j, 4],
            "Second Triggers": df.iloc[j, 5],
            "Second Targets": df.iloc[j, 6],
            "Second Contains": df.iloc[j, 7]
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
def convert_dataframe_to_json(pair: pd.Series) -> tuple[dict, dict]:
    pair = pair.to_dict()
    us_one: dict = {
        "USID": pair["First USID"],
        "Text": pair["First Text"],
        "Main Part": pair["First Main Part"],
        "Benefit": pair["First Benefit"],
        "Triggers": pair["First Triggers"],
        "Targets": pair["First Targets"],
        "Contains": pair["First Contains"]
    }
    
    us_two: dict = {
        "USID": pair["Second USID"],
        "Text": pair["Second Text"],
        "Main Part": pair["Second Main Part"],
        "Benefit": pair["Second Benefit"],
        "Triggers": pair["Second Triggers"],
        "Targets": pair["Second Targets"],
        "Contains": pair["Second Contains"]
    }

    json_one: dict = json.loads(json.dumps(us_one))
    json_two: dict = json.loads(json.dumps(us_two))
    
    return json_one, json_two

# %%
def template_request_two_user_stories(
    current_message: list[dict],
    idx: int,
    pairs: pd.DataFrame,
) -> None:
    row = pairs.iloc[idx]
    json_us_one: dict = None
    json_us_two: dict = None
    json_us_one, json_us_two = convert_dataframe_to_json(row)
    request: dict = PromptHelperBuilder.get_instance().parsing_to_pair_requests(json_us_one, json_us_two)
    current_message.append(request)

# %%
def sort_threaded_results(to_sort: dict) -> None:
    new_list: list = None
    for _ in to_sort.values():
        new_list = sorted(_, key=lambda x: (int(x['relatedStories'][0]), int(x['relatedStories'][1])))
        _.clear()
        _ += new_list

# %%
def json_validator(json_data: dict) -> tuple[bool, str]:
    return validation(json_data, chat_gpt_schema_with_annotations)

# %% [markdown]
# ### Prepaire Prompting

# %%
# Init PromptBuilder
builder: PromptBuilder = PromptBuilder.get_instance()

# Collection of messages
message: list[dict] = []

# %%
# Actor Role
message.append(builder.get_actor_role())
message.append(builder.get_system_simulation_actor_role())

# %%
# User Story Definition
message.append(builder.get_user_story_definition())
message.append(builder.get_system_simulation_user_story_definition())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 3
#       1 # User Story Definition
#       2 message.append(builder.get_user_story_definition())
# ----> 3 message.append(builder.get_system_simulation_user_story_definition())
#
# AttributeError: 'PromptBuilder' object has no attribute 'get_system_simulation_user_story_definition'

# %%
# Redundancy Definition for User Story pair
message.append(builder.get_redundancy_definition)
message.append(builder.get_system_simulation_full_partial_definition)

# %%
# Defining the JSON output
message.append(builder.get_json_defintion)
message.append(builder.get_system_simulation_redundancy_full_partial_definition())

# %%
# Providing Examples
message.append(builder.get_input_output_examples())
message.append(builder.get_system_simulation_example_consideration)

# %%
if True:
    message_text: str = ""
    for key in message:
        message_text += key["content"]
        print(key["content"])
    enc = tiktoken.get_encoding('cl100k_base')
    token_size = enc.encode(message_text)
    print("-" * 3 + "Token" + "-" * 3)
    print(token_size)
    print("-" * 3 + "Sum of Tokens" + "-" * 3)
    # The output is not correct as the result from the online pages differs https://platform.openai.com/tokenizer
    print("The total token sum is: " + locale.format_string("%d", sum(token_size), grouping=True))
# Out:
# ---Token---
# []
# ---Sum of Tokens---
# The total token sum is: 0

# %% [markdown]
# ## Data processing for: G03

# %%
ID_G03: str = "g03"
data_g03: list = datasets[ID_G03]
df_g03: pd.DataFrame = transform_2_dataframe(data_g03)
df_g03_pairs = transform_pairwise(df_g03)

# %%
datasets[ID_G03][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g03.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g03_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G03] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g03_pairs, key=ID_G03, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g03_pairs, key=ID_G03, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G04

# %%
ID_G04: str = "g04"
data_g04: list = datasets[ID_G04]
df_g04: pd.DataFrame = transform_2_dataframe(data_g04)
df_g04_pairs = transform_pairwise(df_g04)

# %%
datasets[ID_G04][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g04.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g04_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G04] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g04_pairs, key=ID_G04, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g04_pairs, key=ID_G04, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G08

# %%
ID_G08: str = "g08"
data_g08: list = datasets[ID_G08]
df_g08: pd.DataFrame = transform_2_dataframe(data_g08)
df_g08_pairs = transform_pairwise(df_g08)

# %%
datasets[ID_G08][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g08.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g08_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G08] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g08_pairs, key=ID_G08, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g08_pairs, key=ID_G08, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G10

# %%
ID_G10: str = "g10"
data_g10: list = datasets[ID_G10]
df_g10: pd.DataFrame = transform_2_dataframe(data_g10)
df_g10_pairs = transform_pairwise(df_g10)

# %%
datasets[ID_G10][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g10.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g10_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G10] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g10_pairs, key=ID_G10, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g10_pairs, key=ID_G10, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G11

# %%
ID_G11: str = "g11"
data_g11: list = datasets[ID_G11]
df_g11: pd.DataFrame = transform_2_dataframe(data_g11)
df_g11_pairs = transform_pairwise(df_g11)

# %%
datasets[ID_G11][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g11.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g11_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G11] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g11_pairs, key=ID_G11, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g11_pairs, key=ID_G11, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G14

# %%
ID_G14: str = "g14"
data_g14: list = datasets[ID_G14]
df_g14: pd.DataFrame = transform_2_dataframe(data_g14)
df_g14_pairs = transform_pairwise(df_g14)

# %%
datasets[ID_G14][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g14.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g14_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G14] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g14_pairs, key=ID_G14, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g14_pairs, key=ID_G14, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G16

# %%
ID_G16: str = "g16"
data_g16: list = datasets[ID_G16]
df_g16: pd.DataFrame = transform_2_dataframe(data_g16)
df_g16_pairs = transform_pairwise(df_g16)

# %%
datasets[ID_G16][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g16.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g16_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G16] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g16_pairs, key=ID_G16, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g16_pairs, key=ID_G16, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G18

# %%
ID_G18: str = "g18"
data_g18: list = datasets[ID_G18]
df_g18: pd.DataFrame = transform_2_dataframe(data_g18)
df_g18_pairs = transform_pairwise(df_g18)

# %%
datasets[ID_G18][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g18.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g18_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G18] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g18_pairs, key=ID_G18, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g18_pairs, key=ID_G18, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G19

# %%
ID_G19: str = "g19"
data_g19: list = datasets[ID_G19]
df_g19: pd.DataFrame = transform_2_dataframe(data_g19)
df_g19_pairs = transform_pairwise(df_g19)

# %%
datasets[ID_G19][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g19.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g19_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G19] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g19_pairs, key=ID_G19, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g19_pairs, key=ID_G19, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G21

# %%
ID_G21: str = "g21"
data_g21: list = datasets[ID_G21]
df_g21: pd.DataFrame = transform_2_dataframe(data_g21)
df_g21_pairs = transform_pairwise(df_g21)

# %%
datasets[ID_G21][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g21.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g21_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G21] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g21_pairs, key=ID_G21, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g21_pairs, key=ID_G21, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G22

# %%
ID_G22: str = "g22"
data_g22: list = datasets[ID_G22]
df_g22: pd.DataFrame = transform_2_dataframe(data_g22)
df_g22_pairs = transform_pairwise(df_g22)

# %%
datasets[ID_G22][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g22.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g22_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G22] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g22_pairs, key=ID_G22, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g22_pairs, key=ID_G22, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G23

# %%
ID_G23: str = "g23"
data_g23: list = datasets[ID_G23]
df_g23: pd.DataFrame = transform_2_dataframe(data_g23)
df_g23_pairs = transform_pairwise(df_g23)

# %%
datasets[ID_G23][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g23.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g23_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G23] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g23_pairs, key=ID_G23, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g23_pairs, key=ID_G23, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G24

# %%
ID_G24: str = "g24"
data_g24: list = datasets[ID_G24]
df_g24: pd.DataFrame = transform_2_dataframe(data_g24)
df_g24_pairs = transform_pairwise(df_g24)

# %%
datasets[ID_G24][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g24.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g24_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G24] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g24_pairs, key=ID_G24, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g24_pairs, key=ID_G24, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G25

# %%
ID_G25: str = "g25"
data_g25: list = datasets[ID_G25]
df_g25: pd.DataFrame = transform_2_dataframe(data_g25)
df_g25_pairs = transform_pairwise(df_g25)

# %%
datasets[ID_G25][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g25.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g25_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G25] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g25_pairs, key=ID_G25, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g25_pairs, key=ID_G25, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G26

# %%
ID_G26: str = "g26"
data_g26: list = datasets[ID_G26]
df_g26: pd.DataFrame = transform_2_dataframe(data_g26)
df_g26_pairs = transform_pairwise(df_g26)

# %%
datasets[ID_G26][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g26.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g26_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G26] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g26_pairs, key=ID_G26, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g26_pairs, key=ID_G26, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G27

# %%
ID_G27: str = "g27"
data_g27: list = datasets[ID_G27]
df_g27: pd.DataFrame = transform_2_dataframe(data_g27)
df_g27_pairs = transform_pairwise(df_g27)

# %%
datasets[ID_G27][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g27.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g27_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G27] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g27_pairs, key=ID_G27, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g27_pairs, key=ID_G27, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Data processing for: G28

# %%
ID_G28: str = "g28"
data_g28: list = datasets[ID_G28]
df_g28: pd.DataFrame = transform_2_dataframe(data_g28)
df_g28_pairs = transform_pairwise(df_g28)

# %%
datasets[ID_G28][0]
# Out:
# {'PID': '#G03#',
#  'USID': '315',
#  'Text': 'As a Public User, I want to Search for Information, so that I can obtain publicly available information concerning properties, County services, processes and other general information.',
#  'Main Part': 'As a Public User, I want to Search for Information, ',
#  'Benefit': 'I can obtain publicly available information concerning properties, County services, processes and other general information',
#  'Triggers': {'Main Part': [['Public User', 'Search']], 'Benefit': []},
#  'Targets': {'Main Part': [['Search', 'Information']],
#   'Benefit': [['obtain', 'publicly available information']]},
#  'Contains': {'Main Part': [],
#   'Benefit': [['publicly available information', 'properties'],
#    ['publicly available information', 'County services'],
#    ['publicly available information', 'processes'],
#    ['publicly available information', 'other general information']]}}

# %%
display(df_g28.head(5))
# Out:
#      PID USID                                               Text  \
# 0  #G03#  315  As a Public User, I want to Search for Informa...
# 1  #G03#  316  As a ProspectiveApplicant, I want to research ...
# 2  #G03#  317  As an Applicant, I want to Request PreApplicat...
# 3  #G03#  318  As a Customer, I want to Create a Customer Por...
# 4  #G03#  319  As an Applicant, I want to Submit Application,...
#
#                                            Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a ProspectiveApplicant, I want to research ...
# 2  As an Applicant, I want to Request PreApplicat...
# 3  As a Customer, I want to Create a Customer Por...
# 4    As an Applicant, I want to Submit Application,
#
#                                              Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can find the relevant service and/or applica...
# 2  I can receive a response to a request for a me...
# 3  I can log on to the Customer Portal and perfor...
# 4  I can provide my information, plans and/or doc...
#
#                                             Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['ProspectiveApplicant', 'resea...
# 2  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 3  {'Main Part': [['Customer', 'Create']], 'Benef...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                              Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['research', 'requirements'], [...
# 2  {'Main Part': [['Request', 'PreApplication Ass...
# 3  {'Main Part': [['Create', 'Customer Portal Use...
# 4  {'Main Part': [['Submit', 'Application']], 'Be...
#
#                                             Contains
# 0  {'Main Part': [], 'Benefit': [['publicly avail...
# 1  {'Main Part': [], 'Benefit': [['online portal'...
# 2  {'Main Part': [], 'Benefit': [['request for a ...
# 3  {'Main Part': [['Customer Portal', 'Customer P...
# 4                   {'Main Part': [], 'Benefit': []}

# %%
display(df_g28_pairs.head())
# Out:
#   First PID First USID                                         First Text  \
# 0     #G03#        315  As a Public User, I want to Search for Informa...
# 1     #G03#        315  As a Public User, I want to Search for Informa...
# 2     #G03#        315  As a Public User, I want to Search for Informa...
# 3     #G03#        315  As a Public User, I want to Search for Informa...
# 4     #G03#        315  As a Public User, I want to Search for Informa...
#
#                                      First Main Part  \
# 0  As a Public User, I want to Search for Informa...
# 1  As a Public User, I want to Search for Informa...
# 2  As a Public User, I want to Search for Informa...
# 3  As a Public User, I want to Search for Informa...
# 4  As a Public User, I want to Search for Informa...
#
#                                        First Benefit  \
# 0  I can obtain publicly available information co...
# 1  I can obtain publicly available information co...
# 2  I can obtain publicly available information co...
# 3  I can obtain publicly available information co...
# 4  I can obtain publicly available information co...
#
#                                       First Triggers  \
# 0  {'Main Part': [['Public User', 'Search']], 'Be...
# 1  {'Main Part': [['Public User', 'Search']], 'Be...
# 2  {'Main Part': [['Public User', 'Search']], 'Be...
# 3  {'Main Part': [['Public User', 'Search']], 'Be...
# 4  {'Main Part': [['Public User', 'Search']], 'Be...
#
#                                        First Targets  \
# 0  {'Main Part': [['Search', 'Information']], 'Be...
# 1  {'Main Part': [['Search', 'Information']], 'Be...
# 2  {'Main Part': [['Search', 'Information']], 'Be...
# 3  {'Main Part': [['Search', 'Information']], 'Be...
# 4  {'Main Part': [['Search', 'Information']], 'Be...
#
#                                       First Contains Second PID Second USID  \
# 0  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         316
# 1  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         317
# 2  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         318
# 3  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         319
# 4  {'Main Part': [], 'Benefit': [['publicly avail...      #G03#         320
#
#                                          Second Text  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3  As an Applicant, I want to Submit Application,...
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                     Second Main Part  \
# 0  As a ProspectiveApplicant, I want to research ...
# 1  As an Applicant, I want to Request PreApplicat...
# 2  As a Customer, I want to Create a Customer Por...
# 3    As an Applicant, I want to Submit Application,
# 4  As an Applicant, I want to Submit Supporting D...
#
#                                       Second Benefit  \
# 0  I can find the relevant service and/or applica...
# 1  I can receive a response to a request for a me...
# 2  I can log on to the Customer Portal and perfor...
# 3  I can provide my information, plans and/or doc...
# 4  I can satisfy documentation requirements for m...
#
#                                      Second Triggers  \
# 0  {'Main Part': [['ProspectiveApplicant', 'resea...
# 1  {'Main Part': [['Applicant', 'Request']], 'Ben...
# 2  {'Main Part': [['Customer', 'Create']], 'Benef...
# 3  {'Main Part': [['Applicant', 'Submit']], 'Bene...
# 4  {'Main Part': [['Applicant', 'Submit']], 'Bene...
#
#                                       Second Targets  \
# 0  {'Main Part': [['research', 'requirements'], [...
# 1  {'Main Part': [['Request', 'PreApplication Ass...
# 2  {'Main Part': [['Create', 'Customer Portal Use...
# 3  {'Main Part': [['Submit', 'Application']], 'Be...
# 4  {'Main Part': [['Submit', 'Supporting Document...
#
#                                      Second Contains
# 0  {'Main Part': [], 'Benefit': [['online portal'...
# 1  {'Main Part': [], 'Benefit': [['request for a ...
# 2  {'Main Part': [['Customer Portal', 'Customer P...
# 3                   {'Main Part': [], 'Benefit': []}
# 4  {'Main Part': [], 'Benefit': [['application', ...

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G28] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g28_pairs, key=ID_G28, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g28_pairs, key=ID_G28, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Save total Speeds

# %%
SHEET_NAME = 'Time Consup. Anlys.S.'

# %%
base_path: str = os.getcwd()
path_to_file = os.path.join(base_path, "results")
path_to_file = os.path.join(path_to_file, "redundancy-model-" + MODEL_VERSION_NAME)

count_runs_per_data_set: dict[str, int] = {}
for key in time_recorders.keys():
        idx = 0
        _ =  f"{idx:02d}_{key}.json"
        while os.path.exists(os.path.join(path_to_file, f"{idx:02d}_{key}.json")):
                idx += 1
        count_runs_per_data_set[key] = idx

entries: list[tuple[int,str,str, int, float, float, float]] = []

entry: tuple[int,str,str, int, float, float, float] = None
for key, value in time_recorders.items():
        entry = (key, count_runs_per_data_set[key], MODEL_VERSION_NAME, str(THREADING).lower(), 
                 value.nanoseconds, value.milliseconds, value.seconds, value.minutes)
        entries.append(entry)

columns = ['Dataset', 'Run Count', 'Model Version', 'Threading Enabled', 
           'Nanoseconds', 'Milliseconds', 'Seconds', 'Minutes']

_file_path: str = os.path.join(base_path, os.getenv('OUTPUT_EXCEL_NAME_WITH_ANNOTATIONS_UNMODIFIED'))
check = os.path.exists(_file_path)

old_time_consuption_data: pd.DataFrame = None
if check:
        try:
                old_time_consuption_data = pd.read_excel(_file_path, SHEET_NAME)
        except ValueError:
                check = False
           
time_consumption_data: pd.DataFrame = pd.DataFrame(entries, columns=columns)

if check and not old_time_consuption_data.empty:
        # Checking if in the excel is already the data. Case: this code is executed twice for the same data
        old_time_consuption_data = old_time_consuption_data.dropna()
        for idx in range(len(old_time_consuption_data)):
                condition = time_consumption_data[
                        (time_consumption_data['Dataset'] == old_time_consuption_data.iat[idx, 0]) & 
                        (time_consumption_data['Run Count'] == old_time_consuption_data.iat[idx, 1])
                ].index
                time_consumption_data = time_consumption_data.drop(condition).reset_index(drop=True)
        time_consumption_data = pd.concat([old_time_consuption_data, time_consumption_data]).reset_index(drop=True)

# %%
def formatter_time(wb: Workbook, sheet_name: str): 
    ws = wb[sheet_name]
    header_font = Font(size=14, bold=True)
    for cell in ws["1:1"]:
        cell.font = header_font
    
    ADDITIONAL_LENGTH: int = 0
    ADJUSTED_WIDTH: int = 0
    MAX_LEN: int = 0
    for col in ws.iter_cols(min_row=1, max_row=1):
        for cell in col:
            MAX_LEN = len(str(cell.value))
            ADDITIONAL_LENGTH = (MAX_LEN + 2)
            ADJUSTED_WIDTH = 0
            ADJUSTED_WIDTH =  ADDITIONAL_LENGTH * 1.5
            ws.column_dimensions[utils_get_column_letter(cell.column)].width = ADJUSTED_WIDTH
            
    alignment = Alignment(vertical='center', horizontal='left')
    for row in ws.iter_rows():
        for cell in row:
            cell.alignment = alignment

    num_columns = ws.max_column
    header_range = f"A1:{utils_get_column_letter(num_columns)}1"
    ws.auto_filter.ref = header_range
    ws.freeze_panes = ws['A2']

    wrap_alignment = Alignment(wrap_text=True, vertical='top', horizontal='left')
    for row in ws.iter_rows(min_row=2):
        for cell in row:
            cell.alignment = wrap_alignment

# %%
save_to_excel(time_consumption_data, formatter_time, SHEET_NAME, os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))

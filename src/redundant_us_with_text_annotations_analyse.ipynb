# %% [markdown]
# # Analysing the redundancies of User Stories - Annotations and US Text

# %%
import locale
import os, json
from itertools import combinations

import pandas as pd
import tiktoken
from openpyxl import Workbook
from openpyxl.styles import Alignment, Font
from openpyxl.utils import get_column_letter as utils_get_column_letter

from prompt_structure.helper_prompt_composition import PromptHelperBuilder
from prompt_structure.prompt_builder import PromptBuilder
from support_functions.excel_helper import save_to_excel, formatter_ignored_items
from support_functions.load_data import load_datasets_with_annotations as loading
from support_functions.request_handler import process_user_stories, process_user_stories_parallel
from support_functions.data_transformations import convert_annotation_dataset
from support_functions.time_recorder import TimeRecorder
from support_functions.json_validator import validation, chat_gpt_schema_with_annotations

# %%
locale.setlocale(locale.LC_ALL, 'de_DE') 
MODEL_VERSION_NAME = os.getenv('MODEL_VERSION')
THREADING = bool(int(os.getenv('THREADING')))
print(f"Threading is used: {THREADING}")
print(MODEL_VERSION_NAME)
# Out:
# Threading is used: True
# gpt-3.5-turbo

# %%
time_recorders: dict = {}
time_recorder: TimeRecorder = None

# %% [markdown]
# ### Load all User Stories from the different packages
#
# We use here Text and it split and the annotations (formatted):
# - Text
# - Main Part
# - Benefit
# - Triggers
# - Targets
# - Contains
#
# We do not need:
# - POS
#
# Irgnored Files as they differer from the common structure [Ref](https://github.com/ace-design/nlp-stories/tree/main?tab=readme-ov-file#note):
# - g02-federal-funding
# - g13-planningpoker
# - g17-cask
# - g27-culrepo
#
# Highlighting words with #

# %%
not_processed_datasets: dict[str, list] = loading()
print(not_processed_datasets["g02"][0])
# Out:
# {'PID': '#G02#', 'Text': '#G02# As a Data user, I want to have the 12-19-2017 deletions processed.', 'Persona': ['Data user'], 'Action': {'Primary Action': ['have'], 'Secondary Action': ['processed']}, 'Entity': {'Primary Entity': ['12-19-2017 deletions'], 'Secondary Entity': ['']}, 'Benefit': '', 'Triggers': [['Data user', 'have']], 'Targets': [['processed', '12-19-2017 deletions'], ['have', '12-19-2017 deletions']], 'Contains': [], 'Persona POS': {'Persona POS tag': [['NOUN', 'NOUN']], 'Persona POS text': [['Data', 'user']]}, 'Action POS': {'Primary Action POS': {'Primary Action POS tag': [['VERB']], 'Primary Action POS text': [['have']]}, 'Secondary Action POS': {'Secondary Action POS tag': [['VERB']], 'Secondary Action POS text': [['processed']]}}, 'Entity POS': {'Primary Entity POS': {'Primary Entity POS tag': [['NUM', 'NOUN']], 'Primary Entity POS text': [['12-19-2017', 'deletions']]}, 'Secondary Entity POS': {'Secondary Entity POS tag': [[]], 'Secondary Entity POS text': [[]]}}}

# %% [markdown]
# ### Converting Data to used suited format

# %%
datasets, ignored_items = convert_annotation_dataset(not_processed_datasets)

# %%
datasets["g05"]
# Out:
# [{'PID': '#G05#',
#   'USID': '373',
#   'Text': 'As a Data Publishing User, I want to be able to edit a dataset I have published, So that I can correct or enhance existing data.',
#   'Main Part': 'As a Data Publishing User, I want to be able to edit a dataset I have published, So that I can correct or enhance existing data.',
#   'Benefit': 'I can correct or enhance existing data',
#   'Triggers': {'Main Part': [['Data Publishing User', 'edit']], 'Benefit': []},
#   'Targets': {'Main Part': [['edit', 'dataset I have published']],
#    'Benefit': [['correct', 'existing data'], ['enhance', 'existing data']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '374',
#   'Text': 'As a Data Publishing User, I want to be able to edit the model of data I have already imported, So that I can fix bugs or make enhancements in the API built for my data.',
#   'Main Part': 'As a Data Publishing User, I want to be able to edit the model of data I have already imported, So that I can fix bugs or make enhancements in the API built for my data.',
#   'Benefit': 'I can fix bugs or make enhancements in the API built for my data',
#   'Triggers': {'Main Part': [['Data Publishing User', 'edit']], 'Benefit': []},
#   'Targets': {'Main Part': [['edit', 'model']],
#    'Benefit': [['fix', 'bugs'], ['make', 'enhancements']]},
#   'Contains': {'Main Part': [['data I have already imported', 'model']],
#    'Benefit': [['API', 'enhancements'], ['data', 'API']]}},
#  {'PID': '#G05#',
#   'USID': '375',
#   'Text': 'As a Data Publishing User, I want to be able to delete a dataset I have published, So that I can remove unwanted data from OpenSpending.',
#   'Main Part': 'As a Data Publishing User, I want to be able to delete a dataset I have published, So that I can remove unwanted data from OpenSpending.',
#   'Benefit': 'I can remove unwanted data from OpenSpending',
#   'Triggers': {'Main Part': [['Data Publishing User', 'delete']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['delete', 'dataset I have published']],
#    'Benefit': [['remove', 'unwanted data']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['OpenSpending', 'unwanted data']]}},
#  {'PID': '#G05#',
#   'USID': '376',
#   'Text': 'As a Platform Administrator, I want to be able to Hide any dataset already added as Public, So that I can maintain Public/Hidden status for other users.',
#   'Main Part': 'As a Platform Administrator, I want to be able to Hide any dataset already added as Public, So that I can maintain Public/Hidden status for other users.',
#   'Benefit': 'I can maintain Public/Hidden status for other users',
#   'Triggers': {'Main Part': [['Platform Administrator', 'Hide']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['Hide', 'any dataset already added']],
#    'Benefit': [['maintain', 'Public/Hidden status']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['other users', 'Public/Hidden status']]}},
#  {'PID': '#G05#',
#   'USID': '377',
#   'Text': 'As a Platform Administrator, I want to have a view on all datasets published by all users, So that I can perform management actions on any dataset.',
#   'Main Part': 'As a Platform Administrator, I want to have a view on all datasets published by all users, So that I can perform management actions on any dataset.',
#   'Benefit': 'I can perform management actions on any dataset',
#   'Triggers': {'Main Part': [['Platform Administrator', 'have']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['have', 'view']],
#    'Benefit': [['perform', 'management actions']]},
#   'Contains': {'Main Part': [['view', 'datasets published']],
#    'Benefit': [['any dataset', 'management actions']]}},
#  {'PID': '#G05#',
#   'USID': '378',
#   'Text': 'As a Platform Administrator, I want to be able to delete any dataset published, So that I can deal with takedown requests, or clean up test datasets.',
#   'Main Part': 'As a Platform Administrator, I want to be able to delete any dataset published, So that I can deal with takedown requests, or clean up test datasets.',
#   'Benefit': 'I can deal with takedown requests, or clean up test datasets',
#   'Triggers': {'Main Part': [['Platform Administrator', 'delete']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['delete', 'any dataset published']],
#    'Benefit': [['deal', 'takedown requests'], ['clean up', 'test datasets']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '379',
#   'Text': 'As a Data Publishing User, I want to be able to edit the data source of data I have already imported, So that I can fix bugs or make enhancements in the API built for my data.',
#   'Main Part': 'As a Data Publishing User, I want to be able to edit the data source of data I have already imported, So that I can fix bugs or make enhancements in the API built for my data.',
#   'Benefit': 'I can fix bugs or make enhancements in the API built for my data',
#   'Triggers': {'Main Part': [['Data Publishing User', 'edit']], 'Benefit': []},
#   'Targets': {'Main Part': [['edit', 'data source']],
#    'Benefit': [['fix', 'bugs'], ['make', 'enhancements']]},
#   'Contains': {'Main Part': [['data I have already imported', 'data source']],
#    'Benefit': [['API', 'enhancements'], ['data', 'API']]}},
#  {'PID': '#G05#',
#   'USID': '380',
#   'Text': 'As a Data Publishing User, I want to have the Packager support Constants, So that I can model dimensions that may not exist in the source file.',
#   'Main Part': 'As a Data Publishing User, I want to have the Packager support Constants, So that I can model dimensions that may not exist in the source file.',
#   'Benefit': 'I can model dimensions that may not exist in the source file',
#   'Triggers': {'Main Part': [['Data Publishing User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'Packager support Constants']],
#    'Benefit': [['model', 'dimensions']]},
#   'Contains': {'Main Part': [], 'Benefit': [['source file', 'dimensions']]}},
#  {'PID': '#G05#',
#   'USID': '381',
#   'Text': 'As a Data Publishing User, I want to be able to import data in Excel, So that I do not have to convert data formats in order to use the data packager.',
#   'Main Part': 'As a Data Publishing User, I want to be able to import data in Excel, So that I do not have to convert data formats in order to use the data packager.',
#   'Benefit': 'I do not have to convert data formats in order to use the data packager',
#   'Triggers': {'Main Part': [['Data Publishing User', 'import']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['import', 'data']],
#    'Benefit': [['use', 'data packager']]},
#   'Contains': {'Main Part': [['Excel', 'data'], ['data', 'data formats']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '382',
#   'Text': 'As a Data Publishing User, I want to know what my data needs to be able to be visualised on a map, So that I can visualise it on a map.',
#   'Main Part': 'As a Data Publishing User, I want to know what my data needs to be able to be visualised on a map, So that I can visualise it on a map.',
#   'Benefit': 'I can visualise it on a map',
#   'Triggers': {'Main Part': [['Data Publishing User', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['know', 'what']],
#    'Benefit': [['visualised', 'data'], ['visualise', 'data']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['map', 'data'], ['map', 'data']]}},
#  {'PID': '#G05#',
#   'USID': '383',
#   'Text': 'As a Data Publishing User, I want to be able to import data in JSON, So that I do not have to convert data formats in order to use the data packager.',
#   'Main Part': 'As a Data Publishing User, I want to be able to import data in JSON, So that I do not have to convert data formats in order to use the data packager.',
#   'Benefit': 'I do not have to convert data formats in order to use the data packager',
#   'Triggers': {'Main Part': [['Data Publishing User', 'import']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['import', 'data']],
#    'Benefit': [['use', 'data packager']]},
#   'Contains': {'Main Part': [['data', 'data formats'], ['JSON', 'data']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '384',
#   'Text': 'As a Data Publishing User, I want to be able to import data from a Google Spreadsheet, So that I do not have to convert data formats in order to use the data packager.',
#   'Main Part': 'As a Data Publishing User, I want to be able to import data from a Google Spreadsheet, So that I do not have to convert data formats in order to use the data packager.',
#   'Benefit': 'I do not have to convert data formats in order to use the data packager',
#   'Triggers': {'Main Part': [['Data Publishing User', 'import']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['import', 'data']],
#    'Benefit': [['use', 'data packager']]},
#   'Contains': {'Main Part': [['Google Spreadsheet', 'data'],
#     ['data', 'data formats']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '385',
#   'Text': 'As a Data Publishing User, I want to be able to import data from Fiscal Data Package descriptor file, So that I do not have to convert data formats in order to use the data packager.',
#   'Main Part': 'As a Data Publishing User, I want to be able to import data from Fiscal Data Package descriptor file, So that I do not have to convert data formats in order to use the data packager.',
#   'Benefit': 'I do not have to convert data formats in order to use the data packager',
#   'Triggers': {'Main Part': [['Data Publishing User', 'import']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['import', 'data']],
#    'Benefit': [['use', 'data packager']]},
#   'Contains': {'Main Part': [['Fiscal Data Package descriptor file', 'data'],
#     ['data', 'data formats']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '386',
#   'Text': 'As a Data Publishing User, I want to be able to provide the Platform Administrator with additional GeoJSON sources, So that I can improve the map-based visualisations of my data.',
#   'Main Part': 'As a Data Publishing User, I want to be able to provide the Platform Administrator with additional GeoJSON sources, So that I can improve the map-based visualisations of my data.',
#   'Benefit': 'I can improve the map-based visualisations of my data',
#   'Triggers': {'Main Part': [['Data Publishing User', 'provide']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['provide', 'Platform Administrator']],
#    'Benefit': [['improve', 'map-based visualisations']]},
#   'Contains': {'Main Part': [['Platform Administrator',
#      'additional GeoJSON sources']],
#    'Benefit': [['map-based visualisations', 'data']]}},
#  {'PID': '#G05#',
#   'USID': '387',
#   'Text': 'As a Data Consuming User, I want to be able to filter, sort and aggregate data by multiple dimensions and measures, So that I can get more granular views on the data.',
#   'Main Part': 'As a Data Consuming User, I want to be able to filter, sort and aggregate data by multiple dimensions and measures, So that I can get more granular views on the data.',
#   'Benefit': 'I can get more granular views on the data',
#   'Triggers': {'Main Part': [['Data Consuming User', 'filter'],
#     ['Data Consuming User', 'sort'],
#     ['Data Consuming User', 'aggregate']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['filter', 'data'],
#     ['sort', 'data'],
#     ['aggregate', 'data']],
#    'Benefit': [['get', 'more granular views']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['data', 'multiple dimensions'],
#     ['data', 'measures'],
#     ['data', 'more granular views']]}},
#  {'PID': '#G05#',
#   'USID': '388',
#   'Text': 'As a Data Consuming User, I want to be able to download a CSV of the data that is used in any visualisation I am viewing, So that I can use the data in other tools.',
#   'Main Part': 'As a Data Consuming User, I want to be able to download a CSV of the data that is used in any visualisation I am viewing, So that I can use the data in other tools.',
#   'Benefit': 'I can use the data in other tools',
#   'Triggers': {'Main Part': [['Data Consuming User', 'download']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['download', 'CSV']],
#    'Benefit': [['use', 'data']]},
#   'Contains': {'Main Part': [['CSV', 'data']],
#    'Benefit': [['other tools', 'data'],
#     ['any visualisation I am viewing', 'data']]}},
#  {'PID': '#G05#',
#   'USID': '389',
#   'Text': 'As a Data Consuming User, I want to be able to change the display of all monetary measures across a set of currencies, So that I can understand localised amounts in non-localised figures.',
#   'Main Part': 'As a Data Consuming User, I want to be able to change the display of all monetary measures across a set of currencies, So that I can understand localised amounts in non-localised figures.',
#   'Benefit': 'I can understand localised amounts in non-localised figures',
#   'Triggers': {'Main Part': [['Data Consuming User', 'change']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['change', 'display']],
#    'Benefit': [['understand', 'localised amounts']]},
#   'Contains': {'Main Part': [['monetary measures', 'display']],
#    'Benefit': [['set of currencies', 'monetary measures'],
#     ['non-localised figures', 'localised amounts']]}},
#  {'PID': '#G05#',
#   'USID': '390',
#   'Text': 'As a Data Consuming User, I want to see textual descriptions that accompany embedded visualisations, So that I can more easily understand what I am viewing.',
#   'Main Part': 'As a Data Consuming User, I want to see textual descriptions that accompany embedded visualisations, So that I can more easily understand what I am viewing.',
#   'Benefit': 'I can more easily understand what I am viewing',
#   'Triggers': {'Main Part': [['Data Consuming User', 'see ']], 'Benefit': []},
#   'Targets': {'Main Part': [['see ', 'textual descriptions']],
#    'Benefit': [['easily understand', 'embedded visualisations']]},
#   'Contains': {'Main Part': [['embedded visualisations',
#      'textual descriptions']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '391',
#   'Text': 'As a Data Consuming User, I want to be able to share a view state as a URL to social networks, So that I can share data that I have found with others.',
#   'Main Part': 'As a Data Consuming User, I want to be able to share a view state as a URL to social networks, So that I can share data that I have found with others.',
#   'Benefit': 'I can share data that I have found with others',
#   'Triggers': {'Main Part': [['Data Consuming User', 'share']], 'Benefit': []},
#   'Targets': {'Main Part': [['share', 'view state']],
#    'Benefit': [['share', 'data']]},
#   'Contains': {'Main Part': [['view state', 'URL'],
#     ['social networks', 'view state']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '392',
#   'Text': 'As a Data Consuming User, I want to be able to download an image ofa particular view state, So that I can use it offline.',
#   'Main Part': 'As a Data Consuming User, I want to be able to download an image ofa particular view state, So that I can use it offline.',
#   'Benefit': 'I can use it offline',
#   'Triggers': {'Main Part': [['Data Consuming User', 'download']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['download', 'image'], ['use', 'image']],
#    'Benefit': []},
#   'Contains': {'Main Part': [['image', 'particular view state']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '393',
#   'Text': 'As a Data Consuming User, I want to be able to share an image of a particular view state to the social networks that support this, So that I can provide richer context in those communication channels for data I am sharing.',
#   'Main Part': 'As a Data Consuming User, I want to be able to share an image of a particular view state to the social networks that support this, So that I can provide richer context in those communication channels for data I am sharing.',
#   'Benefit': 'I can provide richer context in those communication channels for data I am sharing',
#   'Triggers': {'Main Part': [['Data Consuming User', 'share']], 'Benefit': []},
#   'Targets': {'Main Part': [['share', 'image'], ['support', 'image']],
#    'Benefit': [['provide', 'richer context']]},
#   'Contains': {'Main Part': [['social networks', 'image'],
#     ['image', 'particular view state']],
#    'Benefit': [['communication channels', 'richer context'],
#     ['data I am sharing', 'richer context']]}},
#  {'PID': '#G05#',
#   'USID': '394',
#   'Text': 'As a Data Consuming User, I want to be able to have stepped zoom on map visualisations, So that I can have better control over the navigation experience inside a map view.',
#   'Main Part': 'As a Data Consuming User, I want to be able to have stepped zoom on map visualisations, So that I can have better control over the navigation experience inside a map view.',
#   'Benefit': 'I can have better control over the navigation experience inside a map view',
#   'Triggers': {'Main Part': [['Data Consuming User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'stepped zoom']],
#    'Benefit': [['have', 'better control']]},
#   'Contains': {'Main Part': [['map visualisations', 'stepped zoom']],
#    'Benefit': [['map view', 'navigation experience'],
#     ['navigation experience', 'better control']]}},
#  {'PID': '#G05#',
#   'USID': '395',
#   'Text': 'As a Data Consuming User, I want to have consistent use of colour on map visualisations, So that I can better understand the visual logic of the map view.',
#   'Main Part': 'As a Data Consuming User, I want to have consistent use of colour on map visualisations, So that I can better understand the visual logic of the map view.',
#   'Benefit': 'I can better understand the visual logic of the map view',
#   'Triggers': {'Main Part': [['Data Consuming User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'consistent use']],
#    'Benefit': [['better understand', 'visual logic']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['map visualisations', 'colour'],
#     ['map view', 'visual logic']]}},
#  {'PID': '#G05#',
#   'USID': '396',
#   'Text': 'As a Developer, I want to be able to customise the Brand Name and Icon, and Primary Color of all frontend Javascript apps, So that I can customise the branding for my own needs.',
#   'Main Part': 'As a Developer, I want to be able to customise the Brand Name and Icon, and Primary Color of all frontend Javascript apps, So that I can customise the branding for my own needs.',
#   'Benefit': 'I can customise the branding for my own needs',
#   'Triggers': {'Main Part': [['Developer', 'customise']], 'Benefit': []},
#   'Targets': {'Main Part': [['customise', 'Brand Name'],
#     ['customise', 'Icon'],
#     ['customise', 'Primary Color']],
#    'Benefit': [['customise', 'branding']]},
#   'Contains': {'Main Part': [['frontend Javascript apps', 'Brand Name'],
#     ['frontend Javascript apps', 'Icon'],
#     ['frontend Javascript apps', 'Primary Color']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '397',
#   'Text': 'As an API User, I want to be able to understand if a user is a Publisher, So that I can offer functionality based on Dataset Publisher privileges.',
#   'Main Part': 'As an API User, I want to be able to understand if a user is a Publisher, So that I can offer functionality based on Dataset Publisher privileges.',
#   'Benefit': 'I can offer functionality based on Dataset Publisher privileges',
#   'Triggers': {'Main Part': [['API User', 'understand']], 'Benefit': []},
#   'Targets': {'Main Part': [['understand', 'user']],
#    'Benefit': [['offer', 'functionality']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '398',
#   'Text': 'As an API User, I want to be able to understand if a user is an Administrator, So that I can offer functionality based on Platform Administration privileges.',
#   'Main Part': 'As an API User, I want to be able to understand if a user is an Administrator, So that I can offer functionality based on Platform Administration privileges.',
#   'Benefit': 'I can offer functionality based on Platform Administration privileges',
#   'Triggers': {'Main Part': [['API User', 'understand']], 'Benefit': []},
#   'Targets': {'Main Part': [['understand', 'user']],
#    'Benefit': [['offer', 'functionality']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '399',
#   'Text': 'As an API User, I want to be able to get bordering regions|cities when I query a region|city, So that I can provider wider visual context for mapping visualisations.',
#   'Main Part': 'As an API User, I want to be able to get bordering regions|cities when I query a region|city, So that I can provider wider visual context for mapping visualisations.',
#   'Benefit': 'I can provider wider visual context for mapping visualisations',
#   'Triggers': {'Main Part': [['API User', 'get']], 'Benefit': []},
#   'Targets': {'Main Part': [['get', 'cities'], ['get', 'bordering regions']],
#    'Benefit': [['provider', 'wider visual context'],
#     ['query', 'city,'],
#     ['query', 'region']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['mapping visualisations', 'wider visual context']]}},
#  {'PID': '#G05#',
#   'USID': '400',
#   'Text': 'As an API User, I want to be able to dynamically request polygons based on the query made, So that I can provide maps that match the query.',
#   'Main Part': 'As an API User, I want to be able to dynamically request polygons based on the query made, So that I can provide maps that match the query.',
#   'Benefit': 'I can provide maps that match the query',
#   'Triggers': {'Main Part': [['API User', 'dynamically request']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['dynamically request', 'polygons']],
#    'Benefit': [['provide', 'maps']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '401',
#   'Text': 'As an API User, I want to have a flexible API using HASC codes for countries, regions and cities, So that I can visualise budget data on maps.',
#   'Main Part': 'As an API User, I want to have a flexible API using HASC codes for countries, regions and cities, So that I can visualise budget data on maps.',
#   'Benefit': 'I can visualise budget data on maps',
#   'Triggers': {'Main Part': [['API User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'flexible API']],
#    'Benefit': [['visualise', 'budget data'], ['using', 'HASC codes']]},
#   'Contains': {'Main Part': [['flexible API', 'HASC codes']],
#    'Benefit': [['maps', 'budget data'],
#     ['cities', 'HASC codes'],
#     ['regions', 'HASC codes'],
#     ['countries', 'HASC codes']]}},
#  {'PID': '#G05#',
#   'USID': '402',
#   'Text': 'As an API User, I want to be able to get a CSV output of any cube-based query, So that I can use work with tools that read CSV.',
#   'Main Part': 'As an API User, I want to be able to get a CSV output of any cube-based query, So that I can use work with tools that read CSV.',
#   'Benefit': 'I can use work with tools that read CSV',
#   'Triggers': {'Main Part': [['API User', 'get']], 'Benefit': []},
#   'Targets': {'Main Part': [['get', 'CSV output']],
#    'Benefit': [['use', 'work'], ['read', 'CSV']]},
#   'Contains': {'Main Part': [['any cube-based query', 'CSV output']],
#    'Benefit': [['work', 'tools']]}},
#  {'PID': '#G05#',
#   'USID': '403',
#   'Text': 'As an API User, I want to be able to get a set of monetary measures transferred to different currencies, So that I can use this in scenarios that might enable comparison by normalisation.',
#   'Main Part': 'As an API User, I want to be able to get a set of monetary measures transferred to different currencies, So that I can use this in scenarios that might enable comparison by normalisation.',
#   'Benefit': 'I can use this in scenarios that might enable comparison by normalisation',
#   'Triggers': {'Main Part': [['API User', 'get']], 'Benefit': []},
#   'Targets': {'Main Part': [['get', 'set of monetary measures']],
#    'Benefit': [['use', 'different currencies'],
#     ['transferred', 'different currencies'],
#     ['enable', 'comparison by normalisation']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['scenarios', 'different currencies']]}},
#  {'PID': '#G05#',
#   'USID': '404',
#   'Text': 'As an API User, I want to be able to use metadata to get results from multiple datasets, So that I can build user experiences based on more than one dataset more easily.',
#   'Main Part': 'As an API User, I want to be able to use metadata to get results from multiple datasets, So that I can build user experiences based on more than one dataset more easily.',
#   'Benefit': 'I can build user experiences based on more than one dataset more easily',
#   'Triggers': {'Main Part': [['API User', 'use']], 'Benefit': []},
#   'Targets': {'Main Part': [['use', 'metadata']],
#    'Benefit': [['get', 'results'], ['build', 'user experiences']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['multiple datasets', 'results']]}},
#  {'PID': '#G05#',
#   'USID': '405',
#   'Text': 'As an API User, I want to be able to use data to get results from multiple datasets, So that I can build user experiences based on more than one dataset more easily.',
#   'Main Part': 'As an API User, I want to be able to use data to get results from multiple datasets, So that I can build user experiences based on more than one dataset more easily.',
#   'Benefit': 'I can build user experiences based on more than one dataset more easily',
#   'Triggers': {'Main Part': [['API User', 'use']], 'Benefit': []},
#   'Targets': {'Main Part': [['use', 'data']],
#    'Benefit': [['get', 'results'], ['build', 'user experiences']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['multiple datasets', 'results']]}},
#  {'PID': '#G05#',
#   'USID': '406',
#   'Text': 'As an API User, I want to be able to normalise measures by population, So that I work with datasets in reference to their contextual constraints.',
#   'Main Part': 'As an API User, I want to be able to normalise measures by population, So that I work with datasets in reference to their contextual constraints.',
#   'Benefit': 'I work with datasets in reference to their contextual constraints',
#   'Triggers': {'Main Part': [['API User', 'normalise']], 'Benefit': []},
#   'Targets': {'Main Part': [['normalise', 'measures']],
#    'Benefit': [['work', 'datasets']]},
#   'Contains': {'Main Part': [['measures', 'population']],
#    'Benefit': [['datasets', 'contextual constraints']]}},
#  {'PID': '#G05#',
#   'USID': '407',
#   'Text': 'As an API User, I want to be able to normalise measures by geographical area, So that I work with datasets in reference to their contextual constraints.',
#   'Main Part': 'As an API User, I want to be able to normalise measures by geographical area, So that I work with datasets in reference to their contextual constraints.',
#   'Benefit': 'I work with datasets in reference to their contextual constraints',
#   'Triggers': {'Main Part': [['API User', 'normalise']], 'Benefit': []},
#   'Targets': {'Main Part': [['normalise', 'measures']],
#    'Benefit': [['work', 'datasets']]},
#   'Contains': {'Main Part': [['measures', 'geographical area']],
#    'Benefit': [['datasets', 'contextual constraints']]}},
#  {'PID': '#G05#',
#   'USID': '408',
#   'Text': 'As an API User, I want to be able to normalise measures by GDP, so I work with datasets in reference to their contextual constraints.',
#   'Main Part': 'As an API User, I want to be able to normalise measures by GDP, so I work with datasets in reference to their contextual constraints.',
#   'Benefit': 'I work with datasets in reference to their contextual constraints',
#   'Triggers': {'Main Part': [['API User', 'normalise']], 'Benefit': []},
#   'Targets': {'Main Part': [['normalise', 'measures']],
#    'Benefit': [['work', 'datasets']]},
#   'Contains': {'Main Part': [['measures', 'GDP']],
#    'Benefit': [['datasets', 'contextual constraints']]}},
#  {'PID': '#G05#',
#   'USID': '409',
#   'Text': 'As an API User, I want to be able to normalise measures by GINI and related socioeconomic indexes, So that I work with datasets in reference to their contextual constraints.',
#   'Main Part': 'As an API User, I want to be able to normalise measures by GINI and related socioeconomic indexes, So that I work with datasets in reference to their contextual constraints.',
#   'Benefit': 'I work with datasets in reference to their contextual constraints',
#   'Triggers': {'Main Part': [['API User', 'normalise']], 'Benefit': []},
#   'Targets': {'Main Part': [['normalise', 'measures']],
#    'Benefit': [['work', 'datasets']]},
#   'Contains': {'Main Part': [['GINI', 'measures'],
#     ['related socioeconomic indexes', 'measures']],
#    'Benefit': [['datasets', 'contextual constraints']]}},
#  {'PID': '#G05#',
#   'USID': '410',
#   'Text': 'As an API User, I want to be able to get a relative percentage of a measure to the total of the dataset it comes from, So that I can build alternative displays of the data.',
#   'Main Part': 'As an API User, I want to be able to get a relative percentage of a measure to the total of the dataset it comes from, So that I can build alternative displays of the data.',
#   'Benefit': 'I can build alternative displays of the data',
#   'Triggers': {'Main Part': [['API User', 'get']], 'Benefit': []},
#   'Targets': {'Main Part': [['get', 'relative percentage']],
#    'Benefit': [['build', 'alternative displays']]},
#   'Contains': {'Main Part': [['measure', 'relative percentage']],
#    'Benefit': [['data', 'alternative displays'],
#     ['total of the dataset', 'measure']]}},
#  {'PID': '#G05#',
#   'USID': '411',
#   'Text': 'As an API User, I want to be able to persistently store visualisation state in the database, So that such can be shared more easily and contribute to a visualisation gallery.',
#   'Main Part': 'As an API User, I want to be able to persistently store visualisation state in the database, So that such can be shared more easily and contribute to a visualisation gallery.',
#   'Benefit': 'such can be shared more easily and contribute to a visualisation gallery',
#   'Triggers': {'Main Part': [['API User', 'persistently store']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['shared more easily', 'visualisation state'],
#     ['persistently store', 'visualisation state']],
#    'Benefit': [['contribute', 'visualisation gallery']]},
#   'Contains': {'Main Part': [['database', 'visualisation state']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '412',
#   'Text': 'As a Data Publishing User, I want to have my dataset update automatically as the source file/files changes, So that OpenSpending always shows current data.',
#   'Main Part': 'As a Data Publishing User, I want to have my dataset update automatically as the source file/files changes, So that OpenSpending always shows current data.',
#   'Benefit': 'OpenSpending always shows current data',
#   'Triggers': {'Main Part': [['Data Publishing User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['update automatically', 'dataset'],
#     ['have', 'dataset']],
#    'Benefit': [['always shows', 'current data']]},
#   'Contains': {'Main Part': [['OpenSpending', 'dataset'],
#     ['dataset', 'current data']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '413',
#   'Text': 'As an OpenSpending Community Member, I want to have a blog that highlights any and all projects in the open fiscal space, So that I can relate to openspending.org as the central hub of fiscal openness.',
#   'Main Part': 'As an OpenSpending Community Member, I want to have a blog that highlights any and all projects in the open fiscal space, So that I can relate to openspending.org as the central hub of fiscal openness.',
#   'Benefit': 'I can relate to openspending.org as the central hub of fiscal openness',
#   'Triggers': {'Main Part': [['OpenSpending Community Member', 'have']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['have', 'blog']],
#    'Benefit': [['highlights', 'any and all projects'],
#     ['relate', 'openspending.org']]},
#   'Contains': {'Main Part': [['blog', 'any and all projects']],
#    'Benefit': [['open fiscal space', 'any and all projects'],
#     ['central hub', 'fiscal openness']]}},
#  {'PID': '#G05#',
#   'USID': '414',
#   'Text': 'As a User, I want to be able to set my own username, So that my data is more easily discoverable.',
#   'Main Part': 'As a User, I want to be able to set my own username, So that my data is more easily discoverable.',
#   'Benefit': 'my data is more easily discoverable',
#   'Triggers': {'Main Part': [['User', 'set']], 'Benefit': []},
#   'Targets': {'Main Part': [['set', 'own username']], 'Benefit': []},
#   'Contains': {'Main Part': [['own username', 'data']], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '415',
#   'Text': 'As a Data Publishing User, I want to be able to add a dataset in a Hidden state, So that I can work on a dataset before having it discoverable via OpenSpending user interfaces.',
#   'Main Part': 'As a Data Publishing User, I want to be able to add a dataset in a Hidden state, So that I can work on a dataset before having it discoverable via OpenSpending user interfaces.',
#   'Benefit': 'I can work on a dataset before having it discoverable via OpenSpending user interfaces',
#   'Triggers': {'Main Part': [['Data Publishing User', 'add']], 'Benefit': []},
#   'Targets': {'Main Part': [['add', 'dataset']],
#    'Benefit': [['work', 'dataset']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['dataset', 'Hidden state'],
#     ['OpenSpending user interfaces', 'dataset']]}},
#  {'PID': '#G05#',
#   'USID': '416',
#   'Text': 'As a Data Publishing User, I want to be able to Hide a dataset that I have already added as Public, So that I can fix my mistakes or have a dataset primarily for my own use.',
#   'Main Part': 'As a Data Publishing User, I want to be able to Hide a dataset that I have already added as Public, So that I can fix my mistakes or have a dataset primarily for my own use.',
#   'Benefit': 'I can fix my mistakes or have a dataset primarily for my own use',
#   'Triggers': {'Main Part': [['Data Publishing User', 'Hide']], 'Benefit': []},
#   'Targets': {'Main Part': [['Hide', 'dataset']],
#    'Benefit': [['fix', 'mistakes'], ['have', 'dataset']]},
#   'Contains': {'Main Part': [], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '417',
#   'Text': 'As a Data Publishing User, I want to have a view on all the datasets I have published, So that I can perform management actions on my own datasets.',
#   'Main Part': 'As a Data Publishing User, I want to have a view on all the datasets I have published, So that I can perform management actions on my own datasets.',
#   'Benefit': 'I can perform management actions on my own datasets',
#   'Triggers': {'Main Part': [['Data Publishing User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'view']],
#    'Benefit': [['perform', 'management actions']]},
#   'Contains': {'Main Part': [['datasets I have published', 'view']],
#    'Benefit': [['own datasets', 'management actions']]}},
#  {'PID': '#G05#',
#   'USID': '418',
#   'Text': 'As a Data Publishing User, I want to have a functioning Python Client, So that I can add data to the datastore in bulk from the command line or my own programs.',
#   'Main Part': 'As a Data Publishing User, I want to have a functioning Python Client, So that I can add data to the datastore in bulk from the command line or my own programs.',
#   'Benefit': 'I can add data to the datastore in bulk from the command line or my own programs',
#   'Triggers': {'Main Part': [['Data Publishing User', 'have']], 'Benefit': []},
#   'Targets': {'Main Part': [['have', 'functioning Python Client']],
#    'Benefit': [['add', 'data']]},
#   'Contains': {'Main Part': [], 'Benefit': [['datastore', 'data']]}},
#  {'PID': '#G05#',
#   'USID': '419',
#   'Text': 'As an OpenSpending Community Member, I want to have an app where I can find examples of use of fiscal data visualisations, So that I can find guidance in creating my own with Open Spending.',
#   'Main Part': 'As an OpenSpending Community Member, I want to have an app where I can find examples of use of fiscal data visualisations, So that I can find guidance in creating my own with Open Spending.',
#   'Benefit': 'I can find guidance in creating my own with Open Spending',
#   'Triggers': {'Main Part': [['OpenSpending Community Member', 'have']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['have', 'app']],
#    'Benefit': [['find', 'examples'],
#     ['find', 'guidance'],
#     ['creating', 'fiscal data visualisations']]},
#   'Contains': {'Main Part': [],
#    'Benefit': [['use', 'fiscal data visualisations'],
#     ['Open Spending', 'fiscal data visualisations'],
#     ['examples', 'use']]}},
#  {'PID': '#G05#',
#   'USID': '420',
#   'Text': 'As a Data Publishing User, I want to know if my CSV file is valid, So that I can fix possible data issues before publishing it on Open Spending.',
#   'Main Part': 'As a Data Publishing User, I want to know if my CSV file is valid, So that I can fix possible data issues before publishing it on Open Spending.',
#   'Benefit': 'I can fix possible data issues before publishing it on Open Spending',
#   'Triggers': {'Main Part': [['Data Publishing User', 'know']], 'Benefit': []},
#   'Targets': {'Main Part': [['publishing', 'CSV file'], ['know', 'CSV file']],
#    'Benefit': [['fix', 'possible data issues']]},
#   'Contains': {'Main Part': [['Open Spending', 'CSV file']], 'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '421',
#   'Text': "As a Data Consuming User, I want to be able to search any dataset published and publicly accessible by their title and metadata, So that I can find the datasets I'm interested in.",
#   'Main Part': "As a Data Consuming User, I want to be able to search any dataset published and publicly accessible by their title and metadata, So that I can find the datasets I'm interested in.",
#   'Benefit': "I can find the datasets I'm interested in",
#   'Triggers': {'Main Part': [['Data Consuming User', 'search']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['search',
#      'any dataset published and publicly accessible']],
#    'Benefit': [['find', 'datasets']]},
#   'Contains': {'Main Part': [['any dataset published and publicly accessible',
#      'title'],
#     ['any dataset published and publicly accessible', 'metadata']],
#    'Benefit': []}},
#  {'PID': '#G05#',
#   'USID': '422',
#   'Text': "As a Data Consuming User, I want to visualize by default in treemap, bubble tree, map and pivot table the most recent year when my dataset contain multiple years, So that I'm not confused with the amounts.",
#   'Main Part': "As a Data Consuming User, I want to visualize by default in treemap, bubble tree, map and pivot table the most recent year when my dataset contain multiple years, So that I'm not confused with the amounts.",
#   'Benefit': "I'm not confused with the amounts",
#   'Triggers': {'Main Part': [['Data Consuming User', 'visualize by default']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['visualize by default', 'bubble tree'],
#     ['visualize by default', 'treemap'],
#     ['visualize by default', 'map'],
#     ['visualize by default', 'pivot table']],
#    'Benefit': []},
#   'Contains': {'Main Part': [['treemap', 'dataset'],
#     ['bubble tree', 'dataset'],
#     ['map', 'dataset'],
#     ['pivot table', 'dataset']],
#    'Benefit': [['dataset', 'multiple years'],
#     ['most recent year', 'dataset']]}},
#  {'PID': '#G05#',
#   'USID': '423',
#   'Text': 'As an API user, I want to be able to change the colors of the embedded visualisations in my own platform, So that I can customize the visualisations.',
#   'Main Part': 'As an API user, I want to be able to change the colors of the embedded visualisations in my own platform, So that I can customize the visualisations.',
#   'Benefit': 'I can customize the visualisations',
#   'Triggers': {'Main Part': [['API user', 'change']], 'Benefit': []},
#   'Targets': {'Main Part': [['change', 'colors']],
#    'Benefit': [['customize', 'visualisations']]},
#   'Contains': {'Main Part': [['embedded visualisations', 'colors']],
#    'Benefit': [['own platform', 'embedded visualisations']]}},
#  {'PID': '#G05#',
#   'USID': '424',
#   'Text': "As an API user, I want to be able to change some of the styling of the embedded Viewer in my own platform, So that I can brand it to my own organisation's color scheme.",
#   'Main Part': "As an API user, I want to be able to change some of the styling of the embedded Viewer in my own platform, So that I can brand it to my own organisation's color scheme.",
#   'Benefit': "I can brand it to my own organisation's color scheme",
#   'Triggers': {'Main Part': [['API user', 'change']], 'Benefit': []},
#   'Targets': {'Main Part': [['change', 'styling']],
#    'Benefit': [['brand', "own organisation's color scheme"]]},
#   'Contains': {'Main Part': [['styling', "own organisation's color scheme"],
#     ['embedded Viewer', 'styling']],
#    'Benefit': [['own platform', 'embedded Viewer']]}},
#  {'PID': '#G05#',
#   'USID': '425',
#   'Text': 'As a Platform administrator, I want to be able to translate the data types hierarchies of the Viewer while in embed mode, So that my users can understand the interface in their native language.',
#   'Main Part': 'As a Platform administrator, I want to be able to translate the data types hierarchies of the Viewer while in embed mode, So that my users can understand the interface in their native language.',
#   'Benefit': 'my users can understand the interface in their native language',
#   'Triggers': {'Main Part': [['Platform administrator', 'translate']],
#    'Benefit': []},
#   'Targets': {'Main Part': [['translate', 'data types hierarchies']],
#    'Benefit': [['understand', 'interface']]},
#   'Contains': {'Main Part': [['Viewer', 'data types hierarchies']],
#    'Benefit': [['Viewer', 'embed mode'],
#     ['interface', 'native language'],
#     ['users', 'native language']]}}]

# %%
ignored_items["#G02#"][0]
# Out:
# 'PID: #G02#; Text: As a UI designer, I want to redesign the Resources page, so that it matches the new Broker design styles.; Label Type: Contain'

# %%
df_ignored_items: pd.DataFrame = None
if True:            
    cols: list[str] =  ["PID", "Text", "Label Type"]
    df_ignored_items = pd.DataFrame(columns=cols)
    current_ignored_data: dict = {}
    curremt_pid: int = 0
    current_text: str = "" 
    for key, set in ignored_items.items():
        for item in set:
            parts = item.split('; ')
            for part in parts:
                key, value = part.split(': ', 1)
                current_ignored_data[key] = value
            df_ignored_items = pd.concat([df_ignored_items, pd.DataFrame([current_ignored_data])], ignore_index = True)               
            df_ignored_items.reset_index()
    save_to_excel(df_ignored_items, formatter_ignored_items, "Incomplete US labelling", os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))
print(f"Count of ignored Elements: {df_ignored_items.shape[0]}")
df_ignored_items.head()
# Out:
# Count of ignored Elements: 187
#      PID                                               Text Label Type
# 0  #G02#  As a UI designer, I want to redesign the Resou...    Contain
# 1  #G02#  As a UI designer, I want to track the issues t...     Target
# 2  #G02#  As a UI designer, I want to track the issues t...     Target
# 3  #G02#  As a UI designer, I want to track the issues t...     Target
# 4  #G02#  As an agency user, I want to submit my data el...    Contain

# %% [markdown]
# ### Datatransformation to panda dataframes and numpy arrarys.

# %%
def transform_2_dataframe(data: list):
    rows = []
    for entry in data:
        row = {
            "PID": entry["PID"],
            "USID": entry["USID"],
            "Text": entry["Text"],
            "Main Part": entry["Main Part"],
            "Benefit": entry["Benefit"],
            "Triggers": entry["Triggers"],
            "Targets": entry["Targets"],
            "Contains": entry["Contains"],
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
# n(n-1) / 2
def transform_pairwise(df: pd.DataFrame):
    rows = []
    for i, j in combinations(range(df.shape[0]), 2):
        row = {
            "First PID": df.iloc[i, 0],
            "First USID": df.iloc[i, 1],
            "First Text": df.iloc[i, 2],
            "First Main Part": df.iloc[i, 3],
            "First Benefit": df.iloc[i, 4],
            "First Triggers": df.iloc[i, 5],
            "First Targets": df.iloc[i, 6],
            "First Contains": df.iloc[i, 7],
            "Second PID": df.iloc[j, 0],
            "Second USID": df.iloc[j, 1],
            "Second Text": df.iloc[j, 2],
            "Second Main Part": df.iloc[j, 3],
            "Second Benefit": df.iloc[j, 4],
            "Second Triggers": df.iloc[j, 5],
            "Second Targets": df.iloc[j, 6],
            "Second Contains": df.iloc[j, 7]
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
def convert_dataframe_to_json(pair: pd.Series) -> tuple[dict, dict]:
    pair = pair.to_dict()
    us_one: dict = {
        "USID": pair["First USID"],
        "Text": pair["First Text"],
        "Main Part": pair["First Main Part"],
        "Benefit": pair["First Benefit"],
        "Triggers": pair["First Triggers"],
        "Targets": pair["First Targets"],
        "Contains": pair["First Contains"]
    }
    
    us_two: dict = {
        "USID": pair["Second USID"],
        "Text": pair["Second Text"],
        "Main Part": pair["Second Main Part"],
        "Benefit": pair["Second Benefit"],
        "Triggers": pair["Second Triggers"],
        "Targets": pair["Second Targets"],
        "Contains": pair["Second Contains"]
    }

    json_one: dict = json.loads(json.dumps(us_one))
    json_two: dict = json.loads(json.dumps(us_two))
    
    return json_one, json_two

# %%
def template_request_two_user_stories(
    current_message: list[dict],
    idx: int,
    pairs: pd.DataFrame,
) -> None:
    row = pairs.iloc[idx]
    json_us_one: dict = None
    json_us_two: dict = None
    json_us_one, json_us_two = convert_dataframe_to_json(row)
    request: dict = parsing_to_pair_requests(json_us_one, json_us_two)
    current_message.append(request)

# %%
def sort_threaded_results(to_sort: dict) -> None:
    new_list: list = None
    for _ in to_sort.values():
        new_list = sorted(_, key=lambda x: (int(x['relatedStories'][0]), int(x['relatedStories'][1])))
        _.clear()
        _ += new_list

# %%
def json_validator(json_data: dict) -> tuple[bool, str]:
    return validation(json_data, chat_gpt_schema_with_annotations)

# %% [markdown]
# ### Prepaire Prompting

# %%
definition_main_part: str = None 
definition_benefit: str = None
definition_general_redundancy: str = None
definition_main_part_redundancy: str = None
definition_benefit_redundancy: str = None

# %%
definition_user_story: str = '''A user story is a semi-structured sentence containing the following:
information: the persona involved in the story, the main part containing the actions that the persona will perform on the system and 
the entities involved in the actions, and optionally a benefit that the persona will receive after having completed these actions. 
The benefit may also include actions and entities. Classically, a user story is expressed in the following form: "As a <persona>, I can <Actions over entities>, so that <benefit>."'''
print(definition_user_story)
# Out:
# A user story is a semi-structured sentence containing the following:
# information: the persona involved in the story, the main part containing the actions that the persona will perform on the system and
# the entities involved in the actions, and optionally a benefit that the persona will receive after having completed these actions.
# The benefit may also include actions and entities. Classically, a user story is expressed in the following form: "As a <persona>, I can <Actions over entities>, so that <benefit>."

# %%
definition_json_format_pair_user_stories: str = '''
    {
        "relatedStories": [1, 3], 
        "mainPartRedundancies": {
            partialRedundancy: false,
            fullRedundancy: true,
            "descriptionOfTriggersRedundancies":"awd",
            "pairsOfTriggersRedundancies": {
                [["User", "application User"], ["User", "application User"]],
                ...
            },
            "descriptionOfTargetsRedundancies":"awd"
            "pairsOfTargetsRedundancies": {
                [["User", "User"], ["User", "application User"]],
                ...
            },
            "descriptionOfContainsRedundancies":"awd",
            "pairsOfTContainsredundancies": {
                [["User", "application User"], ["User", "application User"]],
                ...
            }
        },
        "benefitRedundancies": {
            // Analog zu oben
        }
    }
'''

# %%
example1: str = None

# %%
example2: str = None

# %%
example3: str = None

# %%
exampl4: str = None

# %%
example5: str = None

# %%
#Collection of messages -> In future it can be used to create a context aware system
message: list[dict] = []

# %%
if True:
    message_text: str = ""
    for key in message:
        message_text += key["content"]
        print(key["content"])
    enc = tiktoken.get_encoding('cl100k_base')
    token_size = enc.encode(message_text)
    print("-" * 3 + "Token" + "-" * 3)
    print(token_size)
    print("-" * 3 + "Sum of Tokens" + "-" * 3)
    # The output is not correct as the result from the online pages differs https://platform.openai.com/tokenizer
    print("The total token sum is: " + locale.format_string("%d", sum(token_size), grouping=True))
# Out:
# ---Token---
# []
# ---Sum of Tokens---
# The total token sum is: 0

# %% [markdown]
# ## Data processing for: G02 federal funding

# %%
ID_G02: str = "g02"
data_g02: list = datasets[ID_G02]
df_g02: pd.DataFrame = transform_2_dataframe(data_g02)
df_g02_pairs = transform_pairwise(df_g02)

# %%
datasets[ID_G02][0]
# Out:
# {'USID': 215,
#  'PID': '#G02#',
#  'Text': '#G02# As a Data user, I want to have the 12-19-2017 deletions processed.',
#  'Persona': ['Data user'],
#  'Action': {'Primary Action': ['have'], 'Secondary Action': ['processed']},
#  'Entity': {'Primary Entity': ['12-19-2017 deletions'],
#   'Secondary Entity': ['']},
#  'Benefit': '',
#  'Triggers': [['Data user', 'have']],
#  'Targets': [['processed', '12-19-2017 deletions'],
#   ['have', '12-19-2017 deletions']],
#  'Contains': [],
#  'Persona POS': {'Persona POS tag': [['NOUN', 'NOUN']],
#   'Persona POS text': [['Data', 'user']]},
#  'Action POS': {'Primary Action POS': {'Primary Action POS tag': [['VERB']],
#    'Primary Action POS text': [['have']]},
#   'Secondary Action POS': {'Secondary Action POS tag': [['VERB']],
#    'Secondary Action POS text': [['processed']]}},
#  'Entity POS': {'Primary Entity POS': {'Primary Entity POS tag': [['NUM',
#      'NOUN']],
#    'Primary Entity POS text': [['12-19-2017', 'deletions']]},
#   'Secondary Entity POS': {'Secondary Entity POS tag': [[]],
#    'Secondary Entity POS text': [[]]}}}

# %%
display(df_g02)
# Out:
#       PID  USID                                               Text  \
# 0   #G02#   215  #G02# As a Data user, I want to have the 12-19...
# 1   #G02#   216  #G02# As a UI designer, I want to redesign the...
# 2   #G02#   217  #G02# As a UI designer, I want to report to th...
# 3   #G02#   218  #G02# As a UI designer, I want to move on to r...
# 4   #G02#   220  #G02# As a UI designer, I want to move on to r...
# ..    ...   ...                                                ...
# 90  #G02#   308  #G02# As a FABS user, I want to have my valida...
# 91  #G02#   309  #G02# As a FABS user, I want to see correct st...
# 92  #G02#   310  #G02# As an agency user, I want to know when t...
# 93  #G02#   311  #G02# As an agency user, I want a landing page...
# 94  #G02#   312  #G02# As an agency user, I want to submit my d...
#
#                                                Action  \
# 0   {'Primary Action': ['have'], 'Secondary Action...
# 1   {'Primary Action': ['redesign'], 'Secondary Ac...
# 2   {'Primary Action': ['report'], 'Secondary Acti...
# 3   {'Primary Action': ['move on'], 'Secondary Act...
# 4   {'Primary Action': ['move on'], 'Secondary Act...
# ..                                                ...
# 90  {'Primary Action': ['have'], 'Secondary Action...
# 91  {'Primary Action': ['see'], 'Secondary Action'...
# 92  {'Primary Action': ['know'], 'Secondary Action...
# 93  {'Primary Action': ['want'], 'Secondary Action...
# 94  {'Primary Action': ['submit'], 'Secondary Acti...
#
#                                                Entity  \
# 0   {'Primary Entity': ['12-19-2017 deletions'], '...
# 1   {'Primary Entity': ['Resources page'], 'Second...
# 2   {'Primary Entity': ['user testing'], 'Secondar...
# 3   {'Primary Entity': ['round 2'], 'Secondary Ent...
# 4   {'Primary Entity': ['round 3'], 'Secondary Ent...
# ..                                                ...
# 90  {'Primary Entity': ['validations'], 'Secondary...
# 91  {'Primary Entity': ['correct status labels'], ...
# 92  {'Primary Entity': ['submission periods start ...
# 93  {'Primary Entity': ['landing page'], 'Secondar...
# 94  {'Primary Entity': ['data elements surrounded ...
#
#                                               Benefit  \
# 0
# 1             it matches the new Broker design styles
# 2   they are aware of their contributions to makin...
# 3                 I can get approvals from leadership
# 4                 I can get approvals from leadership
# ..                                                ...
# 90
# 91            I can quickly see my submission history
# 92         I know when the submission starts and ends
# 93                I can access both sides of the site
# 94  Excel won't strip off leading and trailing zeroes
#
#                      Triggers  \
# 0         [[Data user, have]]
# 1   [[UI designer, redesign]]
# 2     [[UI designer, report]]
# 3    [[UI designer, move on]]
# 4    [[UI designer, move on]]
# ..                        ...
# 90        [[FABS user, have]]
# 91         [[FABS user, see]]
# 92      [[agency user, know]]
# 93      [[agency user, want]]
# 94    [[agency user, submit]]
#
#                                               Targets  \
# 0   [[processed, 12-19-2017 deletions], [have, 12-...
# 1   [[redesign, Resources page], [matches, new Bro...
# 2   [[report, user testing], [aware, contributions...
# 3              [[move on, round 2], [get, approvals]]
# 4              [[move on, round 3], [get, approvals]]
# ..                                                ...
# 90  [[have, validations], [run, reasonable amount ...
# 91  [[see, correct status labels], [quickly see, s...
# 92  [[know, submission periods start and end], [kn...
# 93  [[want, landing page], [navigate, FABS], [navi...
# 94  [[submit, data elements surrounded by quotatio...
#
#                                              Contains  \
# 0                                                  []
# 1        [[Resources page, new Broker design styles]]
# 2                                                  []
# 3   [[DABS, round 2], [FABS landing page edits, ro...
# 4                        [[Help page edits, round 3]]
# ..                                                ...
# 90                                                 []
# 91    [[Submission Dashboard, correct status labels]]
# 92                                                 []
# 93  [[landing page, FABS], [landing page, DABS pag...
# 94  [[Excel, data elements surrounded by quotation...
#
#                                           Persona POS  \
# 0   {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 1   {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 2   {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 3   {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 4   {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# ..                                                ...
# 90  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 91  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 92  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 93  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 94  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
#
#                                            Action POS  \
# 0   {'Primary Action POS': {'Primary Action POS ta...
# 1   {'Primary Action POS': {'Primary Action POS ta...
# 2   {'Primary Action POS': {'Primary Action POS ta...
# 3   {'Primary Action POS': {'Primary Action POS ta...
# 4   {'Primary Action POS': {'Primary Action POS ta...
# ..                                                ...
# 90  {'Primary Action POS': {'Primary Action POS ta...
# 91  {'Primary Action POS': {'Primary Action POS ta...
# 92  {'Primary Action POS': {'Primary Action POS ta...
# 93  {'Primary Action POS': {'Primary Action POS ta...
# 94  {'Primary Action POS': {'Primary Action POS ta...
#
#                                            Entity POS
# 0   {'Primary Entity POS': {'Primary Entity POS ta...
# 1   {'Primary Entity POS': {'Primary Entity POS ta...
# 2   {'Primary Entity POS': {'Primary Entity POS ta...
# 3   {'Primary Entity POS': {'Primary Entity POS ta...
# 4   {'Primary Entity POS': {'Primary Entity POS ta...
# ..                                                ...
# 90  {'Primary Entity POS': {'Primary Entity POS ta...
# 91  {'Primary Entity POS': {'Primary Entity POS ta...
# 92  {'Primary Entity POS': {'Primary Entity POS ta...
# 93  {'Primary Entity POS': {'Primary Entity POS ta...
# 94  {'Primary Entity POS': {'Primary Entity POS ta...
#
# [95 rows x 12 columns]

# %%
display(df_g02_pairs)
# Out:
#      First PID  First USID                                         First Text  \
# 0        #G02#         215  #G02# As a Data user, I want to have the 12-19...
# 1        #G02#         215  #G02# As a Data user, I want to have the 12-19...
# 2        #G02#         215  #G02# As a Data user, I want to have the 12-19...
# 3        #G02#         215  #G02# As a Data user, I want to have the 12-19...
# 4        #G02#         215  #G02# As a Data user, I want to have the 12-19...
# ...        ...         ...                                                ...
# 4460     #G02#         309  #G02# As a FABS user, I want to see correct st...
# 4461     #G02#         309  #G02# As a FABS user, I want to see correct st...
# 4462     #G02#         310  #G02# As an agency user, I want to know when t...
# 4463     #G02#         310  #G02# As an agency user, I want to know when t...
# 4464     #G02#         311  #G02# As an agency user, I want a landing page...
#
#                                            First Action  \
# 0     {'Primary Action': ['have'], 'Secondary Action...
# 1     {'Primary Action': ['have'], 'Secondary Action...
# 2     {'Primary Action': ['have'], 'Secondary Action...
# 3     {'Primary Action': ['have'], 'Secondary Action...
# 4     {'Primary Action': ['have'], 'Secondary Action...
# ...                                                 ...
# 4460  {'Primary Action': ['see'], 'Secondary Action'...
# 4461  {'Primary Action': ['see'], 'Secondary Action'...
# 4462  {'Primary Action': ['know'], 'Secondary Action...
# 4463  {'Primary Action': ['know'], 'Secondary Action...
# 4464  {'Primary Action': ['want'], 'Secondary Action...
#
#                                            First Entity  \
# 0     {'Primary Entity': ['12-19-2017 deletions'], '...
# 1     {'Primary Entity': ['12-19-2017 deletions'], '...
# 2     {'Primary Entity': ['12-19-2017 deletions'], '...
# 3     {'Primary Entity': ['12-19-2017 deletions'], '...
# 4     {'Primary Entity': ['12-19-2017 deletions'], '...
# ...                                                 ...
# 4460  {'Primary Entity': ['correct status labels'], ...
# 4461  {'Primary Entity': ['correct status labels'], ...
# 4462  {'Primary Entity': ['submission periods start ...
# 4463  {'Primary Entity': ['submission periods start ...
# 4464  {'Primary Entity': ['landing page'], 'Secondar...
#
#                                    First Benefit         First Triggers  \
# 0                                                   [[Data user, have]]
# 1                                                   [[Data user, have]]
# 2                                                   [[Data user, have]]
# 3                                                   [[Data user, have]]
# 4                                                   [[Data user, have]]
# ...                                          ...                    ...
# 4460     I can quickly see my submission history     [[FABS user, see]]
# 4461     I can quickly see my submission history     [[FABS user, see]]
# 4462  I know when the submission starts and ends  [[agency user, know]]
# 4463  I know when the submission starts and ends  [[agency user, know]]
# 4464         I can access both sides of the site  [[agency user, want]]
#
#                                           First Targets  \
# 0     [[processed, 12-19-2017 deletions], [have, 12-...
# 1     [[processed, 12-19-2017 deletions], [have, 12-...
# 2     [[processed, 12-19-2017 deletions], [have, 12-...
# 3     [[processed, 12-19-2017 deletions], [have, 12-...
# 4     [[processed, 12-19-2017 deletions], [have, 12-...
# ...                                                 ...
# 4460  [[see, correct status labels], [quickly see, s...
# 4461  [[see, correct status labels], [quickly see, s...
# 4462  [[know, submission periods start and end], [kn...
# 4463  [[know, submission periods start and end], [kn...
# 4464  [[want, landing page], [navigate, FABS], [navi...
#
#                                          First Contains  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 4460    [[Submission Dashboard, correct status labels]]
# 4461    [[Submission Dashboard, correct status labels]]
# 4462                                                 []
# 4463                                                 []
# 4464  [[landing page, FABS], [landing page, DABS pag...
#
#                                       First Persona POS  ...  \
# 0     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 1     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 2     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 3     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 4     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# ...                                                 ...  ...
# 4460  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 4461  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 4462  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 4463  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
# 4464  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...  ...
#
#                                             Second Text  \
# 0     #G02# As a UI designer, I want to redesign the...
# 1     #G02# As a UI designer, I want to report to th...
# 2     #G02# As a UI designer, I want to move on to r...
# 3     #G02# As a UI designer, I want to move on to r...
# 4     #G02# As a Developer , I want to be able to lo...
# ...                                                 ...
# 4460  #G02# As an agency user, I want a landing page...
# 4461  #G02# As an agency user, I want to submit my d...
# 4462  #G02# As an agency user, I want a landing page...
# 4463  #G02# As an agency user, I want to submit my d...
# 4464  #G02# As an agency user, I want to submit my d...
#
#                                           Second Action  \
# 0     {'Primary Action': ['redesign'], 'Secondary Ac...
# 1     {'Primary Action': ['report'], 'Secondary Acti...
# 2     {'Primary Action': ['move on'], 'Secondary Act...
# 3     {'Primary Action': ['move on'], 'Secondary Act...
# 4     {'Primary Action': ['log better'], 'Secondary ...
# ...                                                 ...
# 4460  {'Primary Action': ['want'], 'Secondary Action...
# 4461  {'Primary Action': ['submit'], 'Secondary Acti...
# 4462  {'Primary Action': ['want'], 'Secondary Action...
# 4463  {'Primary Action': ['submit'], 'Secondary Acti...
# 4464  {'Primary Action': ['submit'], 'Secondary Acti...
#
#                                           Second Entity  \
# 0     {'Primary Entity': ['Resources page'], 'Second...
# 1     {'Primary Entity': ['user testing'], 'Secondar...
# 2     {'Primary Entity': ['round 2'], 'Secondary Ent...
# 3     {'Primary Entity': ['round 3'], 'Secondary Ent...
# 4     {'Primary Entity': [''], 'Secondary Entity': [...
# ...                                                 ...
# 4460  {'Primary Entity': ['landing page'], 'Secondar...
# 4461  {'Primary Entity': ['data elements surrounded ...
# 4462  {'Primary Entity': ['landing page'], 'Secondar...
# 4463  {'Primary Entity': ['data elements surrounded ...
# 4464  {'Primary Entity': ['data elements surrounded ...
#
#                                          Second Benefit  \
# 0               it matches the new Broker design styles
# 1     they are aware of their contributions to makin...
# 2                   I can get approvals from leadership
# 3                   I can get approvals from leadership
# 4     I can troubleshoot issues with particular subm...
# ...                                                 ...
# 4460                I can access both sides of the site
# 4461  Excel won't strip off leading and trailing zeroes
# 4462                I can access both sides of the site
# 4463  Excel won't strip off leading and trailing zeroes
# 4464  Excel won't strip off leading and trailing zeroes
#
#                 Second Triggers  \
# 0     [[UI designer, redesign]]
# 1       [[UI designer, report]]
# 2      [[UI designer, move on]]
# 3      [[UI designer, move on]]
# 4     [[Developer, log better]]
# ...                         ...
# 4460      [[agency user, want]]
# 4461    [[agency user, submit]]
# 4462      [[agency user, want]]
# 4463    [[agency user, submit]]
# 4464    [[agency user, submit]]
#
#                                          Second Targets  \
# 0     [[redesign, Resources page], [matches, new Bro...
# 1     [[report, user testing], [aware, contributions...
# 2                [[move on, round 2], [get, approvals]]
# 3                [[move on, round 3], [get, approvals]]
# 4                              [[troubleshoot, issues]]
# ...                                                 ...
# 4460  [[want, landing page], [navigate, FABS], [navi...
# 4461  [[submit, data elements surrounded by quotatio...
# 4462  [[want, landing page], [navigate, FABS], [navi...
# 4463  [[submit, data elements surrounded by quotatio...
# 4464  [[submit, data elements surrounded by quotatio...
#
#                                         Second Contains  \
# 0          [[Resources page, new Broker design styles]]
# 1                                                    []
# 2     [[DABS, round 2], [FABS landing page edits, ro...
# 3                          [[Help page edits, round 3]]
# 4     [[functions, issues], [particular submissions,...
# ...                                                 ...
# 4460  [[landing page, FABS], [landing page, DABS pag...
# 4461  [[Excel, data elements surrounded by quotation...
# 4462  [[landing page, FABS], [landing page, DABS pag...
# 4463  [[Excel, data elements surrounded by quotation...
# 4464  [[Excel, data elements surrounded by quotation...
#
#                                      Second Persona POS  \
# 0     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 1     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 2     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 3     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 4     {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# ...                                                 ...
# 4460  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 4461  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 4462  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 4463  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
# 4464  {'Persona POS tag': [['NOUN', 'NOUN']], 'Perso...
#
#                                       Second Action POS  \
# 0     {'Primary Action POS': {'Primary Action POS ta...
# 1     {'Primary Action POS': {'Primary Action POS ta...
# 2     {'Primary Action POS': {'Primary Action POS ta...
# 3     {'Primary Action POS': {'Primary Action POS ta...
# 4     {'Primary Action POS': {'Primary Action POS ta...
# ...                                                 ...
# 4460  {'Primary Action POS': {'Primary Action POS ta...
# 4461  {'Primary Action POS': {'Primary Action POS ta...
# 4462  {'Primary Action POS': {'Primary Action POS ta...
# 4463  {'Primary Action POS': {'Primary Action POS ta...
# 4464  {'Primary Action POS': {'Primary Action POS ta...
#
#                                       Second Entity POS
# 0     {'Primary Entity POS': {'Primary Entity POS ta...
# 1     {'Primary Entity POS': {'Primary Entity POS ta...
# 2     {'Primary Entity POS': {'Primary Entity POS ta...
# 3     {'Primary Entity POS': {'Primary Entity POS ta...
# 4     {'Primary Entity POS': {'Primary Entity POS ta...
# ...                                                 ...
# 4460  {'Primary Entity POS': {'Primary Entity POS ta...
# 4461  {'Primary Entity POS': {'Primary Entity POS ta...
# 4462  {'Primary Entity POS': {'Primary Entity POS ta...
# 4463  {'Primary Entity POS': {'Primary Entity POS ta...
# 4464  {'Primary Entity POS': {'Primary Entity POS ta...
#
# [4465 rows x 24 columns]

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G02] = time_recorder

if THREADING:
    process_user_stories_parallel(index_usid1=0, index_usid2=2, message=message, pairs=df_g02_pairs, key=ID_G02, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories,
                                  sort_threaded_results=sort_threaded_results, json_schema=chat_gpt_schema_with_annotations, redundancy_prefix="text-annoations", time_recorder=time_recorder)
else:
    process_user_stories(index_usid1=0, index_usid2=2, message=message, pairs=df_g02_pairs, key=ID_G02, model_version_name=MODEL_VERSION_NAME, template_request_two_user_stories=template_request_two_user_stories, 
                         json_validation=json_validator, redundancy_prefix="text-annoations", time_recorder=time_recorder)

# %% [markdown]
# ## Save total Speeds

# %%
SHEET_NAME = 'Time Consup. Anlys.S.'

# %%
base_path: str = os.getcwd()
path_to_file = os.path.join(base_path, "results")
path_to_file = os.path.join(path_to_file, "redundancy-model-" + MODEL_VERSION_NAME)

count_runs_per_data_set: dict[str, int] = {}
for key in time_recorders.keys():
        idx = 0
        _ =  f"{idx:02d}_{key}.json"
        while os.path.exists(os.path.join(path_to_file, f"{idx:02d}_{key}.json")):
                idx += 1
        count_runs_per_data_set[key] = idx

entries: list[tuple[int,str,str, int, float, float, float]] = []

entry: tuple[int,str,str, int, float, float, float] = None
for key, value in time_recorders.items():
        entry = (key, count_runs_per_data_set[key], MODEL_VERSION_NAME, str(THREADING).lower(), 
                 value.nanoseconds, value.milliseconds, value.seconds, value.minutes)
        entries.append(entry)

columns = ['Dataset', 'Run Count', 'Model Version', 'Threading Enabled', 
           'Nanoseconds', 'Milliseconds', 'Seconds', 'Minutes']

_file_path: str = os.path.join(base_path, os.getenv('OUTPUT_EXCEL_NAME_WITH_ANNOTATIONS_UNMODIFIED'))
check = os.path.exists(_file_path)

old_time_consuption_data: pd.DataFrame = None
if check:
        try:
                old_time_consuption_data = pd.read_excel(_file_path, SHEET_NAME)
        except ValueError:
                check = False
           
time_consumption_data: pd.DataFrame = pd.DataFrame(entries, columns=columns)

if check and not old_time_consuption_data.empty:
        # Checking if in the excel is already the data. Case: this code is executed twice for the same data
        old_time_consuption_data = old_time_consuption_data.dropna()
        for idx in range(len(old_time_consuption_data)):
                condition = time_consumption_data[
                        (time_consumption_data['Dataset'] == old_time_consuption_data.iat[idx, 0]) & 
                        (time_consumption_data['Run Count'] == old_time_consuption_data.iat[idx, 1])
                ].index
                time_consumption_data = time_consumption_data.drop(condition).reset_index(drop=True)
        time_consumption_data = pd.concat([old_time_consuption_data, time_consumption_data]).reset_index(drop=True)

# %%
def formatter_time(wb: Workbook, sheet_name: str): 
    ws = wb[sheet_name]
    header_font = Font(size=14, bold=True)
    for cell in ws["1:1"]:
        cell.font = header_font
    
    ADDITIONAL_LENGTH: int = 0
    ADJUSTED_WIDTH: int = 0
    MAX_LEN: int = 0
    for col in ws.iter_cols(min_row=1, max_row=1):
        for cell in col:
            MAX_LEN = len(str(cell.value))
            ADDITIONAL_LENGTH = (MAX_LEN + 2)
            ADJUSTED_WIDTH = 0
            ADJUSTED_WIDTH =  ADDITIONAL_LENGTH * 1.5
            ws.column_dimensions[utils_get_column_letter(cell.column)].width = ADJUSTED_WIDTH
            
    alignment = Alignment(vertical='center', horizontal='left')
    for row in ws.iter_rows():
        for cell in row:
            cell.alignment = alignment

    num_columns = ws.max_column
    header_range = f"A1:{utils_get_column_letter(num_columns)}1"
    ws.auto_filter.ref = header_range
    ws.freeze_panes = ws['A2']

    wrap_alignment = Alignment(wrap_text=True, vertical='top', horizontal='left')
    for row in ws.iter_rows(min_row=2):
        for cell in row:
            cell.alignment = wrap_alignment

# %%
save_to_excel(time_consumption_data, formatter_time, SHEET_NAME, os.getenv("OUTPUT_EXCEL_NAME_WITH_TEXT_AND_ANNOTATIONS"))

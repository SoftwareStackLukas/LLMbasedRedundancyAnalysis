# %%
import locale
import os
from itertools import combinations

import pandas as pd
import tiktoken
from openpyxl import Workbook, load_workbook
from openpyxl.styles import Alignment, Font
from openpyxl.utils import get_column_letter as utils_get_column_letter
#from openpyxl.worksheet.worksheet import Worksheet

from support_functions.excel_helper import save_to_excel
from support_functions.load_data import load_datasets_with_annotations as loading
from support_functions.request_handler import process_user_stories, process_user_stories_parallel
from support_functions.data_transformations import remove_pov_and_add_usid
from support_functions.time_recorder import TimeRecorder

# %%
locale.setlocale(locale.LC_ALL, 'de_DE') 
MODEL_VERSION_NAME = os.getenv('MODEL_VERSION')
THREADING = bool(int(os.getenv('THREADING')))
print(f"Threading is used: {THREADING}")
print(MODEL_VERSION_NAME)
# Out:
# Threading is used: False
# gpt-3.5-turbo

# %%
time_recorders: dict = {}
time_recorder: TimeRecorder = None

# %% [markdown]
# ### Load all User Stories from the different packages
#
# We do not need:
# - POS
#
# Highlighting words with #

# %%
datasets: dict[str, list] = loading()
print(datasets["g02"][0])
# Out:
# {'PID': '#G02#', 'Text': '#G02# As a Data user, I want to have the 12-19-2017 deletions processed.', 'Persona': ['Data user'], 'Action': {'Primary Action': ['have'], 'Secondary Action': ['processed']}, 'Entity': {'Primary Entity': ['12-19-2017 deletions'], 'Secondary Entity': ['']}, 'Benefit': '', 'Triggers': [['Data user', 'have']], 'Targets': [['processed', '12-19-2017 deletions'], ['have', '12-19-2017 deletions']], 'Contains': [], 'Persona POS': {'Persona POS tag': [['NOUN', 'NOUN']], 'Persona POS text': [['Data', 'user']]}, 'Action POS': {'Primary Action POS': {'Primary Action POS tag': [['VERB']], 'Primary Action POS text': [['have']]}, 'Secondary Action POS': {'Secondary Action POS tag': [['VERB']], 'Secondary Action POS text': [['processed']]}}, 'Entity POS': {'Primary Entity POS': {'Primary Entity POS tag': [['NUM', 'NOUN']], 'Primary Entity POS text': [['12-19-2017', 'deletions']]}, 'Secondary Entity POS': {'Secondary Entity POS tag': [[]], 'Secondary Entity POS text': [[]]}}}

# %% [markdown]
# ### Keeping the data untouched. Just remove data load.

# %%
datasets = remove_pov_and_add_usid(datasets)
datasets["g02"][0]
# Out:
# {'usid': 215,
#  'PID': '#G02#',
#  'Text': '#G02# As a Data user, I want to have the 12-19-2017 deletions processed.',
#  'Persona': ['Data user'],
#  'Action': {'Primary Action': ['have'], 'Secondary Action': ['processed']},
#  'Entity': {'Primary Entity': ['12-19-2017 deletions'],
#   'Secondary Entity': ['']},
#  'Benefit': '',
#  'Triggers': [['Data user', 'have']],
#  'Targets': [['processed', '12-19-2017 deletions'],
#   ['have', '12-19-2017 deletions']],
#  'Contains': [],
#  'Persona POS': {'Persona POS tag': [['NOUN', 'NOUN']],
#   'Persona POS text': [['Data', 'user']]},
#  'Action POS': {'Primary Action POS': {'Primary Action POS tag': [['VERB']],
#    'Primary Action POS text': [['have']]},
#   'Secondary Action POS': {'Secondary Action POS tag': [['VERB']],
#    'Secondary Action POS text': [['processed']]}},
#  'Entity POS': {'Primary Entity POS': {'Primary Entity POS tag': [['NUM',
#      'NOUN']],
#    'Primary Entity POS text': [['12-19-2017', 'deletions']]},
#   'Secondary Entity POS': {'Secondary Entity POS tag': [[]],
#    'Secondary Entity POS text': [[]]}}}

# %% [markdown]
# ### Prepaire Prompting

# %% [markdown]
# ### Request definition to ChatGPT

# %%
def transform_2_dataframe(data: list) -> pd.DataFrame:
    rows = []
    for entry in data:
        row = {
            "PID": entry["PID"],
            "USID": entry["usid"],
            "User Story Text": entry["Text"],
            "Main Part": entry["Main Part"],
            "Benefit": entry["Benefit"],
            "Triggers Main Part": entry["Triggers"]["Main Part"],
            "Triggers Benefit": entry["Triggers"]["Benefit"],
            "Targets Main Part": entry["Targets"]["Main Part"],
            "Targets Benefit": entry["Targets"]["Benefit"],
            "Contains Main Part": entry["Contains"]["Main Part"],
            "Contains Benefit": entry["Contains"]["Benefit"]
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
def transform_pairwise(df: pd.DataFrame) -> pd.DataFrame:
    rows = []
    for i, j in combinations(range(df.shape[0]), 2):
        row = {
            "First PID": df.iloc[i, 0],
            "First USID": df.iloc[i, 1],
            "First User Story Text": df.iloc[i, 2],
            "First Main Part": df.iloc[i, 3],
            "First Benefit": df.iloc[i, 4],
            "First Triggers Main Part": df.iloc[i, 5],
            "First Triggers Benefit": df.iloc[i, 6],
            "First Targets Main Part": df.iloc[i, 7],
            "First Targets Benefit": df.iloc[i, 8],
            "First Contains Main Part": df.iloc[i, 9],
            "First Contains Benefit": df.iloc[i, 10],
            "Second PID": df.iloc[j, 0],
            "Second USID": df.iloc[j, 1],
            "Second User Story Text": df.iloc[j, 2],
            "Second Main Part": df.iloc[j, 3],
            "Second Benefit": df.iloc[j, 4],
            "Second Triggers Main Part": df.iloc[j, 5],
            "Second Triggers Benefit": df.iloc[j, 6],
            "Second Targets Main Part": df.iloc[j, 7],
            "Second Targets Benefit": df.iloc[j, 8],
            "Second Contains Main Part": df.iloc[j, 9],
            "Second Contains Benefit": df.iloc[j, 10]
        }
        rows.append(row)
    return pd.DataFrame(rows)

# %%
### Convert the data back
### Add the Type Hinting
### Use this function in processing the pairs
### Processing the pairs has to be done more abstract to use it
def convert_dataframe_to_json(pairs):
    pass

# %% [markdown]
# ## Data processing for: G02 federal funding

# %%
ID_G02: str = "g02"
data_g02: list = datasets[ID_G02]
df_g02: pd.DataFrame = transform_2_dataframe(data_g02)
df_g02_pairs = transform_pairwise(df_g02)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 3
#       1 ID_G02: str = "g02"
#       2 data_g02: list = datasets[ID_G02]
# ----> 3 df_g02: pd.DataFrame = transform_2_dataframe(data_g02)
#       4 df_g02_pairs = transform_pairwise(df_g02)
#
# Cell In[24], line 8, in transform_2_dataframe(data)
#       2 rows = []
#       3 for entry in data:
#       4     row = {
#       5         "PID": entry["PID"],
#       6         "USID": entry["usid"],
#       7         "User Story Text": entry["Text"],
# ----> 8         "Main Part": entry["Main Part"],
#       9         "Benefit": entry["Benefit"],
#      10         "Triggers Main Part": entry["Triggers"]["Main Part"],
#      11         "Triggers Benefit": entry["Triggers"]["Benefit"],
#      12         "Targets Main Part": entry["Targets"]["Main Part"],
#      13         "Targets Benefit": entry["Targets"]["Benefit"],
#      14         "Contains Main Part": entry["Contains"]["Main Part"],
#      15         "Contains Benefit": entry["Contains"]["Benefit"]
#      16     }
#      17     rows.append(row)
#      18 return pd.DataFrame(rows)
#
# KeyError: 'Main Part'

# %%
display(df_g02)
# Out:
#       PID                                    User Story Text  \
# 0   #G02#  As a Data user, I want to have the 12-19-2017 ...
# 1   #G02#  As a UI designer, I want to redesign the Resou...
# 2   #G02#  As a UI designer, I want to report to the Agen...
# 3   #G02#  As a UI designer, I want to move on to round 2...
# 4   #G02#  As a UI designer, I want to move on to round 3...
# ..    ...                                                ...
# 90  #G02#  As a FABS user, I want to have my validations ...
# 91  #G02#  As a FABS user, I want to see correct status l...
# 92  #G02#  As an agency user, I want to know when the sub...
# 93  #G02#  As an agency user, I want a landing page to na...
# 94  #G02#  As an agency user, I want to submit my data el...
#
#                                             Main Part  \
# 0   As a Data user, I want to have the 12-19-2017 ...
# 1   As a UI designer, I want to redesign the Resou...
# 2   As a UI designer, I want to report to the Agen...
# 3   As a UI designer, I want to move on to round 2...
# 4   As a UI designer, I want to move on to round 3...
# ..                                                ...
# 90  As a FABS user, I want to have my validations ...
# 91  As a FABS user, I want to see correct status l...
# 92  As an agency user, I want to know when the sub...
# 93  As an agency user, I want a landing page to na...
# 94  As an agency user, I want to submit my data el...
#
#                                               Benefit  \
# 0
# 1             it matches the new Broker design styles
# 2   they are aware of their contributions to makin...
# 3                 I can get approvals from leadership
# 4                 I can get approvals from leadership
# ..                                                ...
# 90
# 91            I can quickly see my submission history
# 92         I know when the submission starts and ends
# 93                I can access both sides of the site
# 94  Excel won't strip off leading and trailing zeroes
#
#            Triggers Main Part Triggers Benefit  \
# 0         [[Data user, have]]               []
# 1   [[UI designer, redesign]]               []
# 2     [[UI designer, report]]               []
# 3    [[UI designer, move on]]               []
# 4    [[UI designer, move on]]               []
# ..                        ...              ...
# 90        [[FABS user, have]]               []
# 91         [[FABS user, see]]               []
# 92      [[agency user, know]]               []
# 93      [[agency user, want]]               []
# 94    [[agency user, submit]]               []
#
#                                     Targets Main Part  \
# 0                      [[have, 12-19-2017 deletions]]
# 1                        [[redesign, Resources page]]
# 2                            [[report, user testing]]
# 3                                [[move on, round 2]]
# 4                                [[move on, round 3]]
# ..                                                ...
# 90                              [[have, validations]]
# 91                     [[see, correct status labels]]
# 92         [[know, submission periods start and end]]
# 93                             [[want, landing page]]
# 94  [[submit, data elements surrounded by quotatio...
#
#                                       Targets Benefit Contains Main Part  \
# 0                                                  []                 []
# 1               [[matches, new Broker design styles]]                 []
# 2          [[aware, contributions], [making, Broker]]                 []
# 3                                  [[get, approvals]]                 []
# 4                                  [[get, approvals]]                 []
# ..                                                ...                ...
# 90                 [[run, reasonable amount of time]]                 []
# 91                [[quickly see, submission history]]                 []
# 92               [[know, submission starts and ends]]                 []
# 93  [[navigate, FABS], [navigate, DABS pages], [ac...                 []
# 94                                                 []                 []
#
#    Contains Benefit
# 0                []
# 1                []
# 2                []
# 3                []
# 4                []
# ..              ...
# 90               []
# 91               []
# 92               []
# 93               []
# 94               []
#
# [95 rows x 10 columns]

# %%
display(df_g02_pairs)
# Out:
#      First PID                              First User Story Text  \
# 0        #G02#  As a Data user, I want to have the 12-19-2017 ...
# 1        #G02#  As a Data user, I want to have the 12-19-2017 ...
# 2        #G02#  As a Data user, I want to have the 12-19-2017 ...
# 3        #G02#  As a Data user, I want to have the 12-19-2017 ...
# 4        #G02#  As a Data user, I want to have the 12-19-2017 ...
# ...        ...                                                ...
# 4460     #G02#  As a FABS user, I want to see correct status l...
# 4461     #G02#  As a FABS user, I want to see correct status l...
# 4462     #G02#  As an agency user, I want to know when the sub...
# 4463     #G02#  As an agency user, I want to know when the sub...
# 4464     #G02#  As an agency user, I want a landing page to na...
#
#                                         First Main Part  \
# 0     As a Data user, I want to have the 12-19-2017 ...
# 1     As a Data user, I want to have the 12-19-2017 ...
# 2     As a Data user, I want to have the 12-19-2017 ...
# 3     As a Data user, I want to have the 12-19-2017 ...
# 4     As a Data user, I want to have the 12-19-2017 ...
# ...                                                 ...
# 4460  As a FABS user, I want to see correct status l...
# 4461  As a FABS user, I want to see correct status l...
# 4462  As an agency user, I want to know when the sub...
# 4463  As an agency user, I want to know when the sub...
# 4464  As an agency user, I want a landing page to na...
#
#                                    First Benefit First Triggers Main Part  \
# 0                                                     [[Data user, have]]
# 1                                                     [[Data user, have]]
# 2                                                     [[Data user, have]]
# 3                                                     [[Data user, have]]
# 4                                                     [[Data user, have]]
# ...                                          ...                      ...
# 4460     I can quickly see my submission history       [[FABS user, see]]
# 4461     I can quickly see my submission history       [[FABS user, see]]
# 4462  I know when the submission starts and ends    [[agency user, know]]
# 4463  I know when the submission starts and ends    [[agency user, know]]
# 4464         I can access both sides of the site    [[agency user, want]]
#
#      First Triggers Benefit                     First Targets Main Part  \
# 0                        []              [[have, 12-19-2017 deletions]]
# 1                        []              [[have, 12-19-2017 deletions]]
# 2                        []              [[have, 12-19-2017 deletions]]
# 3                        []              [[have, 12-19-2017 deletions]]
# 4                        []              [[have, 12-19-2017 deletions]]
# ...                     ...                                         ...
# 4460                     []              [[see, correct status labels]]
# 4461                     []              [[see, correct status labels]]
# 4462                     []  [[know, submission periods start and end]]
# 4463                     []  [[know, submission periods start and end]]
# 4464                     []                      [[want, landing page]]
#
#                                   First Targets Benefit  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 4460                [[quickly see, submission history]]
# 4461                [[quickly see, submission history]]
# 4462               [[know, submission starts and ends]]
# 4463               [[know, submission starts and ends]]
# 4464  [[navigate, FABS], [navigate, DABS pages], [ac...
#
#      First Contains Main Part First Contains Benefit Second PID  \
# 0                          []                     []      #G02#
# 1                          []                     []      #G02#
# 2                          []                     []      #G02#
# 3                          []                     []      #G02#
# 4                          []                     []      #G02#
# ...                       ...                    ...        ...
# 4460                       []                     []      #G02#
# 4461                       []                     []      #G02#
# 4462                       []                     []      #G02#
# 4463                       []                     []      #G02#
# 4464                       []                     []      #G02#
#
#                                  Second User Story Text  \
# 0     As a UI designer, I want to redesign the Resou...
# 1     As a UI designer, I want to report to the Agen...
# 2     As a UI designer, I want to move on to round 2...
# 3     As a UI designer, I want to move on to round 3...
# 4     As a Developer , I want to be able to log bett...
# ...                                                 ...
# 4460  As an agency user, I want a landing page to na...
# 4461  As an agency user, I want to submit my data el...
# 4462  As an agency user, I want a landing page to na...
# 4463  As an agency user, I want to submit my data el...
# 4464  As an agency user, I want to submit my data el...
#
#                                        Second Main Part  \
# 0     As a UI designer, I want to redesign the Resou...
# 1     As a UI designer, I want to report to the Agen...
# 2     As a UI designer, I want to move on to round 2...
# 3     As a UI designer, I want to move on to round 3...
# 4      As a Developer , I want to be able to log better
# ...                                                 ...
# 4460  As an agency user, I want a landing page to na...
# 4461  As an agency user, I want to submit my data el...
# 4462  As an agency user, I want a landing page to na...
# 4463  As an agency user, I want to submit my data el...
# 4464  As an agency user, I want to submit my data el...
#
#                                          Second Benefit  \
# 0               it matches the new Broker design styles
# 1     they are aware of their contributions to makin...
# 2                   I can get approvals from leadership
# 3                   I can get approvals from leadership
# 4     I can troubleshoot issues with particular subm...
# ...                                                 ...
# 4460                I can access both sides of the site
# 4461  Excel won't strip off leading and trailing zeroes
# 4462                I can access both sides of the site
# 4463  Excel won't strip off leading and trailing zeroes
# 4464  Excel won't strip off leading and trailing zeroes
#
#       Second Triggers Main Part  \
# 0     [[UI designer, redesign]]
# 1       [[UI designer, report]]
# 2      [[UI designer, move on]]
# 3      [[UI designer, move on]]
# 4     [[Developer, log better]]
# ...                         ...
# 4460      [[agency user, want]]
# 4461    [[agency user, submit]]
# 4462      [[agency user, want]]
# 4463    [[agency user, submit]]
# 4464    [[agency user, submit]]
#
#                                 Second Triggers Benefit  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3                                                    []
# 4     [[functions, issues], [particular submissions,...
# ...                                                 ...
# 4460                                                 []
# 4461                                                 []
# 4462                                                 []
# 4463                                                 []
# 4464                                                 []
#
#                                Second Targets Main Part  \
# 0                          [[redesign, Resources page]]
# 1                              [[report, user testing]]
# 2                                  [[move on, round 2]]
# 3                                  [[move on, round 3]]
# 4                                                    []
# ...                                                 ...
# 4460                             [[want, landing page]]
# 4461  [[submit, data elements surrounded by quotatio...
# 4462                             [[want, landing page]]
# 4463  [[submit, data elements surrounded by quotatio...
# 4464  [[submit, data elements surrounded by quotatio...
#
#                                  Second Targets Benefit  \
# 0                 [[matches, new Broker design styles]]
# 1            [[aware, contributions], [making, Broker]]
# 2                                    [[get, approvals]]
# 3                                    [[get, approvals]]
# 4                              [[troubleshoot, issues]]
# ...                                                 ...
# 4460  [[navigate, FABS], [navigate, DABS pages], [ac...
# 4461                                                 []
# 4462  [[navigate, FABS], [navigate, DABS pages], [ac...
# 4463                                                 []
# 4464                                                 []
#
#      Second Contains Main Part Second Contains Benefit
# 0                           []                      []
# 1                           []                      []
# 2                           []                      []
# 3                           []                      []
# 4                           []                      []
# ...                        ...                     ...
# 4460                        []                      []
# 4461                        []                      []
# 4462                        []                      []
# 4463                        []                      []
# 4464                        []                      []
#
# [4465 rows x 20 columns]

# %% [markdown]
# ### Process and Store the User Stories persistently

# %%
time_recorder = TimeRecorder()
time_recorders[ID_G02] = time_recorder
if THREADING:
    process_user_stories_parallel(message, df_g02_pairs, ID_G02, MODEL_VERSION_NAME, time_recorder=time_recorder)
    print(time_recorder.milliseconds)
else:
    process_user_stories(message, df_g02_pairs, ID_G02, MODEL_VERSION_NAME, time_recorder=time_recorder)

# %% [markdown]
# ### Process and Store the User Stories persistently

# %% [markdown]
# ## Save total Speeds

# %%
SHEET_NAME = 'Time Consup. Anlys.S.'

# %%
base_path: str = os.getcwd()
path_to_file = os.path.join(base_path, "results")
path_to_file = os.path.join(path_to_file, "redundancy-model-" + MODEL_VERSION_NAME)

count_runs_per_data_set: dict[str, int] = {}
for key in time_recorders.keys():
        idx = 0
        _ =  f"{idx:02d}_{key}.json"
        while os.path.exists(os.path.join(path_to_file, f"{idx:02d}_{key}.json")):
                idx += 1
        count_runs_per_data_set[key] = idx

entries: list[tuple[int,str,str, int, float, float, float]] = []

entry: tuple[int,str,str, int, float, float, float] = None
for key, value in time_recorders.items():
        entry = (key, count_runs_per_data_set[key], MODEL_VERSION_NAME, str(THREADING).lower(), 
                 value.nanoseconds, value.milliseconds, value.seconds, value.minutes)
        entries.append(entry)

columns = ['Dataset', 'Run Count', 'Model Version', 'Threading Enabled', 
           'Nanoseconds', 'Milliseconds', 'Seconds', 'Minutes']

_file_path: str = os.path.join(base_path, os.getenv('OUTPUT_EXCEL_NAME_WITHOUT_ANNOTATIONS'))
check = os.path.exists(_file_path)

old_time_consuption_data: pd.DataFrame = None
if check:
        try:
                old_time_consuption_data = pd.read_excel(_file_path, SHEET_NAME)
        except ValueError:
                check = False
           
time_consumption_data: pd.DataFrame = pd.DataFrame(entries, columns=columns)

if check and not old_time_consuption_data.empty:
        # Checking if in the excel is already the data. Case: this code is executed twice for the same data
        old_time_consuption_data = old_time_consuption_data.dropna()
        for idx in range(len(old_time_consuption_data)):
                condition = time_consumption_data[
                        (time_consumption_data['Dataset'] == old_time_consuption_data.iat[idx, 0]) & 
                        (time_consumption_data['Run Count'] == old_time_consuption_data.iat[idx, 1])
                ].index
                time_consumption_data = time_consumption_data.drop(condition).reset_index(drop=True)
        time_consumption_data = pd.concat([old_time_consuption_data, time_consumption_data]).reset_index(drop=True)

# %%
def formatter_time(wb: Workbook, sheet_name: str): 
    ws = wb[sheet_name]
    header_font = Font(size=14, bold=True)
    for cell in ws["1:1"]:
        cell.font = header_font
    
    ADDITIONAL_LENGTH: int = 0
    ADJUSTED_WIDTH: int = 0
    MAX_LEN: int = 0
    for col in ws.iter_cols(min_row=1, max_row=1):
        for cell in col:
            MAX_LEN = len(str(cell.value))
            ADDITIONAL_LENGTH = (MAX_LEN + 2)
            ADJUSTED_WIDTH = 0
            ADJUSTED_WIDTH =  ADDITIONAL_LENGTH * 1.5
            ws.column_dimensions[utils_get_column_letter(cell.column)].width = ADJUSTED_WIDTH
            
    alignment = Alignment(vertical='center', horizontal='left')
    for row in ws.iter_rows():
        for cell in row:
            cell.alignment = alignment

    num_columns = ws.max_column
    header_range = f"A1:{utils_get_column_letter(num_columns)}1"
    ws.auto_filter.ref = header_range
    ws.freeze_panes = ws['A2']

    wrap_alignment = Alignment(wrap_text=True, vertical='top', horizontal='left')
    for row in ws.iter_rows(min_row=2):
        for cell in row:
            cell.alignment = wrap_alignment

# %%
save_to_excel(time_consumption_data, formatter_time, SHEET_NAME, os.getenv('OUTPUT_EXCEL_NAME_WITHOUT_ANNOTATIONS'))
